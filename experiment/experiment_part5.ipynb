# %%
def extract_sql_from_file(file_path):
    with open(file_path, 'r') as file:
        sql_commands = file.read().split(';')  # 将文件内容按分号分割成多个 SQL 语句
        # 去除空白项并去除换行符
        sql_commands = [sql.strip() for sql in sql_commands if sql.strip()]
    return sql_commands


# 调用函数提取 SQL 语句
queries_list = extract_sql_from_file('/home/ubuntu/project/mayang/LOGER/experiment/tpch/first_100_queries.sql')
len(queries_list)
# Out:
# 16

# %%
# def extract_sql_from_file(file_path):
#     with open(file_path, 'r') as file:
#         sql_commands = file.read().split(';')  # 将文件内容按分号分割成多个 SQL 语句
#         # 去除空白项并去除换行符
#         sql_commands = [sql.strip() for sql in sql_commands if sql.strip()]
#     return sql_commands

# def save_queries_to_file(queries, output_file_path):
#     with open(output_file_path, 'w') as file:
#         for query in queries:
#             file.write(query + ';\n')  # 在每个查询后添加分号

# # 提取 SQL 语句
# queries_list = extract_sql_from_file('/home/ubuntu/project/index_selection_evaluation/queries/tpch/tpch_queries.sql')

# # 提取前10个查询
# first_10_queries = queries_list[:16]

# # 保存到新的 SQL 文件
# save_queries_to_file(first_10_queries, '/home/ubuntu/project/mayang/LOGER/experiment/tpch/first_100_queries.sql')

# %%
index_configs_workload_50_tpcds1_rainbow="[I(C customer_address.ca_city), I(C catalog_sales.cs_item_sk), I(C catalog_sales.cs_sold_date_sk), I(C item.i_item_sk), I(C store_returns.sr_cdemo_sk), I(C time_dim.t_hour), I(C web_sales.ws_sold_date_sk), I(C catalog_sales.cs_item_sk,C catalog_sales.cs_sold_date_sk), I(C date_dim.d_date,C date_dim.d_date_sk), I(C date_dim.d_date,C date_dim.d_month_seq), I(C date_dim.d_date_sk,C date_dim.d_date), I(C date_dim.d_date_sk,C date_dim.d_month_seq), I(C date_dim.d_month_seq,C date_dim.d_date_sk), I(C date_dim.d_month_seq,C date_dim.d_year), I(C date_dim.d_year,C date_dim.d_date), I(C item.i_item_id,C item.i_item_sk), I(C item.i_item_id,C item.i_manufact_id), I(C item.i_manufact_id,C item.i_current_price), I(C inventory.inv_date_sk,C inventory.inv_item_sk), I(C store.s_store_sk,C store.s_city), I(C store_sales.ss_item_sk,C store_sales.ss_sales_price), I(C store_sales.ss_store_sk,C store_sales.ss_sold_time_sk), I(C store_sales.ss_ticket_number,C store_sales.ss_item_sk)]"
index_configs_workload_50_tpcds1_whatif="[I(C customer_address.ca_zip), I(C customer_demographics.cd_demo_sk), I(C catalog_page.cp_catalog_page_sk), I(C catalog_returns.cr_order_number), I(C catalog_returns.cr_returned_date_sk), I(C catalog_sales.cs_order_number), I(C catalog_sales.cs_ship_date_sk), I(C date_dim.d_quarter_name), I(C date_dim.d_week_seq), I(C household_demographics.hd_demo_sk), I(C item.i_item_id), I(C inventory.inv_date_sk), I(C store.s_store_sk), I(C store_returns.sr_return_amt), I(C store_sales.ss_item_sk), I(C store_sales.ss_net_profit), I(C store_sales.ss_quantity), I(C store_sales.ss_sales_price), I(C store_sales.ss_store_sk), I(C customer_address.ca_address_sk,C customer_address.ca_zip), I(C catalog_returns.cr_order_number,C catalog_returns.cr_item_sk), I(C catalog_returns.cr_order_number,C catalog_returns.cr_returned_date_sk), I(C catalog_sales.cs_ship_date_sk,C catalog_sales.cs_order_number), I(C date_dim.d_date_sk,C date_dim.d_year), I(C date_dim.d_dom,C date_dim.d_moy), I(C household_demographics.hd_buy_potential,C household_demographics.hd_vehicle_count), I(C item.i_category,C item.i_manufact_id), I(C item.i_manufact_id,C item.i_current_price), I(C inventory.inv_date_sk,C inventory.inv_item_sk), I(C promotion.p_promo_sk,C promotion.p_channel_email), I(C store_returns.sr_returned_date_sk,C store_returns.sr_ticket_number), I(C store_returns.sr_ticket_number,C store_returns.sr_item_sk), I(C store_sales.ss_customer_sk,C store_sales.ss_item_sk), I(C store_sales.ss_hdemo_sk,C store_sales.ss_store_sk), I(C store_sales.ss_item_sk,C store_sales.ss_sold_date_sk), I(C store_sales.ss_item_sk,C store_sales.ss_ticket_number), I(C warehouse.w_warehouse_sk,C warehouse.w_state), I(C web_sales.ws_item_sk,C web_sales.ws_order_number)]"

# %%
# tpcds 10 -part 1
# index_configs_workload_50_tpcds10_whatif="[I(C catalog_sales.cs_item_sk), I(C catalog_sales.cs_sold_date_sk), I(C date_dim.d_date_sk), I(C date_dim.d_month_seq), I(C date_dim.d_year), I(C household_demographics.hd_dep_count), I(C item.i_item_id), I(C item.i_item_sk), I(C promotion.p_promo_sk), I(C store_sales.ss_item_sk), I(C time_dim.t_hour), I(C web_sales.ws_sold_date_sk), I(C catalog_sales.cs_item_sk,C catalog_sales.cs_sold_date_sk), I(C date_dim.d_date_sk,C date_dim.d_date), I(C item.i_item_id,C item.i_manufact_id), I(C item.i_item_sk,C item.i_manufact_id), I(C item.i_manufact_id,C item.i_current_price), I(C store.s_store_sk,C store.s_street_name), I(C store_sales.ss_item_sk,C store_sales.ss_customer_sk), I(C store_sales.ss_item_sk,C store_sales.ss_sold_date_sk)]"
index_configs_workload_50_tpcds10_whatif="[I(C item.i_item_id,C item.i_manufact_id), I(C item.i_item_sk), I(C catalog_sales.cs_sold_date_sk), I(C date_dim.d_date_sk), I(C item.i_manufact_id,C item.i_current_price), I(C date_dim.d_month_seq), I(C item.i_item_sk,C item.i_manufact_id), I(C catalog_sales.cs_item_sk), I(C household_demographics.hd_dep_count), I(C promotion.p_promo_sk), I(C item.i_item_id), I(C store_sales.ss_item_sk,C store_sales.ss_customer_sk), I(C store_sales.ss_item_sk), I(C time_dim.t_hour), I(C date_dim.d_year), I(C web_sales.ws_sold_date_sk), I(C store_sales.ss_item_sk,C store_sales.ss_sold_date_sk), I(C date_dim.d_date_sk,C date_dim.d_date), I(C store.s_store_sk,C store.s_county)]"
index_configs_workload_50_tpcds10_rainbow="[I(C date_dim.d_date_sk,C date_dim.d_date), I(C store_sales.ss_item_sk,C store_sales.ss_sales_price), I(C item.i_manufact_id,C item.i_current_price), I(C date_dim.d_month_seq,C date_dim.d_date_sk), I(C date_dim.d_month_seq,C date_dim.d_year), I(C catalog_sales.cs_item_sk), I(C store_returns.sr_cdemo_sk), I(C household_demographics.hd_dep_count,C household_demographics.hd_demo_sk), I(C customer_address.ca_address_sk), I(C web_sales.ws_sold_date_sk), I(C date_dim.d_year,C date_dim.d_date_sk), I(C catalog_sales.cs_sold_date_sk), I(C time_dim.t_hour), I(C store_sales.ss_item_sk,C store_sales.ss_ticket_number)]"

# %%
# tpcds 10 -part 2
index_configs_workload_50_tpcds10_whatif="[I(C promotion.p_promo_sk), I(C time_dim.t_hour), I(C customer.c_customer_id), I(C store_sales.ss_item_sk,C store_sales.ss_sold_date_sk), I(C web_sales.ws_sold_date_sk), I(C household_demographics.hd_demo_sk), I(C date_dim.d_year), I(C catalog_sales.cs_ship_date_sk), I(C customer_address.ca_address_sk), I(C date_dim.d_month_seq), I(C date_dim.d_date_sk,C date_dim.d_month_seq), I(C income_band.ib_income_band_sk,C income_band.ib_lower_bound), I(C customer.c_customer_sk), I(C store.s_store_sk,C store.s_store_name), I(C household_demographics.hd_dep_count), I(C catalog_returns.cr_returned_date_sk), I(C customer_demographics.cd_demo_sk), I(C catalog_sales.cs_sold_date_sk), I(C store_sales.ss_item_sk), I(C store_returns.sr_cdemo_sk), I(C store_sales.ss_ticket_number,C store_sales.ss_item_sk)]"
index_configs_workload_50_tpcds10_rainbow="[I(C date_dim.d_date_sk,C date_dim.d_date), I(C catalog_sales.cs_ship_date_sk), I(C customer.c_customer_id), I(C store_sales.ss_item_sk,C store_sales.ss_customer_sk), I(C item.i_manufact_id,C item.i_current_price), I(C catalog_sales.cs_ship_date_sk,C catalog_sales.cs_item_sk), I(C store_returns.sr_cdemo_sk), I(C catalog_returns.cr_returned_date_sk), I(C store.s_store_sk), I(C catalog_sales.cs_sold_date_sk,C catalog_sales.cs_item_sk), I(C household_demographics.hd_demo_sk,C household_demographics.hd_dep_count), I(C customer.c_customer_id,C customer.c_customer_sk), I(C catalog_sales.cs_sold_date_sk), I(C income_band.ib_income_band_sk,C income_band.ib_upper_bound), I(C time_dim.t_hour), I(C store_sales.ss_item_sk), I(C customer_address.ca_address_sk), I(C web_sales.ws_sold_date_sk), I(C catalog_sales.cs_item_sk,C catalog_sales.cs_ship_date_sk)]"
index_configs_workload_50_tpcds10_lib="[I(C catalog_returns.cr_returned_date_sk), I(C catalog_sales.cs_sold_date_sk), I(C catalog_sales.cs_sold_date_sk,C catalog_sales.cs_item_sk), I(C income_band.ib_income_band_sk,C income_band.ib_lower_bound), I(C promotion.p_promo_sk), I(C item.i_category_id,C item.i_category), I(C household_demographics.hd_dep_count), I(C store_sales.ss_item_sk,C store_sales.ss_sales_price), I(C date_dim.d_month_seq,C date_dim.d_date_sk), I(C web_sales.ws_sold_date_sk)]"
index_configs_workload_50_tpcds10_tree_model="[I(C store_returns.sr_cdemo_sk), I(C web_sales.ws_sold_date_sk), I(C store_sales.ss_item_sk,C store_sales.ss_customer_sk), I(C promotion.p_promo_sk), I(C catalog_sales.cs_sold_date_sk), I(C time_dim.t_hour), I(C store.s_store_sk,C store.s_zip), I(C date_dim.d_month_seq,C date_dim.d_date_sk)]"

# %%
index_configs_workload_50_job_rainbow="[I(C cast_info.role_id,C cast_info.note), I(C cast_info.movie_id,C cast_info.role_id), I(C movie_info.movie_id), I(C movie_keyword.movie_id,C movie_keyword.keyword_id), I(C keyword.id,C keyword.keyword), I(C movie_companies.movie_id), I(C cast_info.person_id,C cast_info.note)]"
index_configs_workload_50_job_whatif="[I(C aka_name.person_id), I(C cast_info.role_id,C cast_info.note), I(C cast_info.note,C cast_info.person_id), I(C movie_info.movie_id), I(C name.gender)]"
# index_configs_workload_50_job_whatif="[I(C movie_companies.company_id,C movie_companies.movie_id), I(C aka_name.person_id), I(C cast_info.role_id,C cast_info.note), I(C name.gender), I(C cast_info.note,C cast_info.person_id)]"
index_configs_workload_50_job_lib="[I(C movie_companies.company_id,C movie_companies.movie_id), I(C name.id,C name.gender), I(C cast_info.movie_id), I(C movie_companies.movie_id), I(C aka_name.person_id), I(C name.gender), I(C char_name.id), I(C movie_info_idx.movie_id), I(C title.id), I(C movie_companies.movie_id,C movie_companies.note), I(C movie_info.movie_id), I(C movie_companies.movie_id,C movie_companies.company_id), I(C name.gender,C name.id), I(C name.id), I(C movie_info_idx.movie_id,C movie_info_idx.info), I(C cast_info.movie_id,C cast_info.role_id)]"
index_configs_workload_50_job_tree_model="[I(C aka_name.person_id), I(C cast_info.person_id,C cast_info.note), I(C name.gender), I(C movie_info.movie_id), I(C cast_info.role_id,C cast_info.note), I(C company_type.id), I(C role_type.role,C role_type.id)]"

# %%
# index_configs_workload_50_tpch_whatif="[I(C supplier.s_suppkey), I(C lineitem.l_orderkey), I(C part.p_type), I(C lineitem.l_suppkey,C lineitem.l_partkey), I(C orders.o_orderkey), I(C customer.c_custkey), I(C orders.o_orderdate)]"
# index_configs_workload_50_tpch_rainbow="[I(C orders.o_orderdate), I(C part.p_type), I(C supplier.s_suppkey,C supplier.s_nationkey), I(C lineitem.l_orderkey,C lineitem.l_shipdate), I(C supplier.s_suppkey), I(C lineitem.l_partkey,C lineitem.l_shipdate), I(C lineitem.l_partkey,C lineitem.l_suppkey), I(C supplier.s_nationkey), I(C partsupp.ps_suppkey), I(C orders.o_custkey,C orders.o_orderdate)]"

# %%
#tpcds 1
index_configs_workload_50_tpcds1_whatif="[I(C store_sales.ss_item_sk,C store_sales.ss_customer_sk), I(C store.s_store_sk,C store.s_store_name), I(C web_sales.ws_sold_date_sk), I(C customer_demographics.cd_demo_sk), I(C store_returns.sr_cdemo_sk), I(C promotion.p_promo_sk,C promotion.p_channel_event), I(C household_demographics.hd_demo_sk), I(C household_demographics.hd_dep_count), I(C date_dim.d_year)]"
index_configs_workload_50_tpcds1_rainbow="[I(C web_sales.ws_sold_date_sk), I(C household_demographics.hd_dep_count), I(C date_dim.d_date_sk,C date_dim.d_date), I(C store_sales.ss_item_sk,C store_sales.ss_ticket_number), I(C catalog_returns.cr_returned_date_sk), I(C customer.c_customer_sk), I(C store_returns.sr_cdemo_sk), I(C store_sales.ss_store_sk,C store_sales.ss_sold_time_sk), I(C catalog_sales.cs_sold_date_sk), I(C date_dim.d_month_seq), I(C customer_address.ca_address_sk), I(C item.i_item_sk,C item.i_manufact_id), I(C customer_address.ca_city,C customer_address.ca_address_sk)]"
index_configs_workload_50_tpcds1_lib="[I(C store_sales.ss_item_sk,C store_sales.ss_sales_price), I(C promotion.p_promo_sk,C promotion.p_channel_email), I(C income_band.ib_income_band_sk), I(C catalog_returns.cr_returned_date_sk), I(C item.i_manufact_id,C item.i_current_price), I(C date_dim.d_month_seq,C date_dim.d_date_sk), I(C catalog_sales.cs_item_sk,C catalog_sales.cs_ship_date_sk), I(C store.s_store_sk,C store.s_company_id), I(C time_dim.t_hour), I(C household_demographics.hd_dep_count)]"
index_configs_workload_50_tpcds1_tree_model="[I(C customer.c_customer_sk), I(C time_dim.t_hour), I(C store_sales.ss_item_sk,C store_sales.ss_sold_date_sk), I(C income_band.ib_income_band_sk,C income_band.ib_upper_bound), I(C customer_address.ca_address_sk,C customer_address.ca_city), I(C store.s_store_sk,C store.s_company_id), I(C household_demographics.hd_demo_sk), I(C customer_demographics.cd_demo_sk), I(C household_demographics.hd_dep_count), I(C promotion.p_promo_sk), I(C customer_address.ca_city), I(C store_returns.sr_cdemo_sk), I(C date_dim.d_month_seq,C date_dim.d_year), I(C date_dim.d_year,C date_dim.d_month_seq)]"

# %%
index_configs_workload_50_tpch10_whatif="[I(C customer.c_custkey), I(C part.p_size), I(C lineitem.l_partkey), I(C partsupp.ps_suppkey), I(C part.p_brand,C part.p_container)]"
index_configs_workload_50_tpch10_rainbow=""
index_configs_workload_50_tpch10_lib="[I(C orders.o_orderkey), I(C customer.c_custkey), I(C supplier.s_suppkey), I(C partsupp.ps_partkey), I(C part.p_brand,C part.p_type), I(C orders.o_orderkey,C orders.o_custkey)]"
index_configs_workload_50_tpch10_tree_model="[I(C orders.o_orderdate), I(C customer.c_custkey), I(C lineitem.l_shipdate)]"

# %%
import psycopg2
import re
import json
import time

class RealIndex:
    def __init__(self, index_config):
        self.index_config = index_config.strip()
    
    def index_idx(self):
        match = re.match(r'I\(C\s+(.*?)\)', self.index_config)
        if match:
            column_names = match.group(1).split(',')
            cleaned_column_names = [name.split('.')[-1].strip() for name in column_names]
            columns = "_".join(self._column_names())
            return f"{self.table()}_{columns}_idx"
        else:
            print('errot in index_idx')
            return None
        
    def table(self):
        start = self.index_config.find('(') + 1
        end = self.index_config.find('.')
        if start != -1 and end != -1:
            return self.index_config[start:end].strip().split()[-1]
        else:
            return self.index_config.strip()

    def joined_column_names(self):
        match = re.match(r'I\(C\s+(.*?)\)', self.index_config)
        if match:
            column_names = match.group(1).split(',')
            cleaned_column_names = [name.split('.')[-1].strip() for name in column_names]
            return ','.join(cleaned_column_names)
        else:
            return None
        
    def joined_column_drop_names(self):
        match = re.match(r'I\(C\s+(.*?)\)', self.index_config)
        if match:
            column_names = match.group(1).split(',')
            cleaned_column_names = [name.split('.')[-1].strip() for name in column_names]
            return '_'.join(cleaned_column_names)
        else:
            return None

class QueryExecutor:
    def __init__(self, dbname, user, password, host, port):
        self.conn = psycopg2.connect(
            dbname=dbname,
            user=user,
            password=password,
            host=host,
            port=port
        )
        self.cursor = self.conn.cursor()
        
    def exec_query(self, query):
        query_text = query  # 直接使用传入的查询
        start_time = time.time()
        self.cursor.execute(query_text)
        execution_time = time.time() - start_time
        return execution_time

    def exec_fetch(self, query):
        with self.conn.cursor() as cur:
            cur.execute(query)
            # 如果是 DDL 语句（如 CREATE INDEX），则不返回结果
            if query.startswith("CREATE") or query.startswith("DROP"):
                return
            return cur.fetchall()

    def create_index(self, index):
        print(f"CREATEING INDEX ON {index.table()} ({index.joined_column_names()})")
        create_statement = f"CREATE INDEX ON {index.table()} ({index.joined_column_names()})"
        self.exec_fetch(create_statement)

    def drop_index(self, index):
        print(f"DROPING INDEX IF EXISTS {index.index_config}")
        drop_statement = f"DROP INDEX IF EXISTS "+f"{index.table()}_{index.joined_column_drop_names()}_idx"
        self.exec_fetch(drop_statement)
        
    def execute_workload_and_measure_time(self, query_list):
        exe_list=[]
        total_execution_time = 0
        for index, query in enumerate(query_list, start=1):
            execution_time = self.exec_query(query)
            total_execution_time += execution_time
            exe_list.append(execution_time)
            print(f"Query {index}: executed in {execution_time:.4f} seconds")
        return total_execution_time,exe_list

    def extract_execution_time(self, explain_result):
        # 解析 EXPLAIN ANALYZE 的返回结果，提取执行时间
        execution_time = 0
        for line in explain_result:
            plan = json.loads(line[0])
            execution_time = plan['Total Time']  # 假设提取总时间
        return execution_time

    def close(self):
        self.conn.close()

def parse_index_configs(index_configs):
    indexes = re.findall(r'I\(C\s*[^()]*\)', index_configs)
    parsed_indexes = []
    for index in indexes:
        parsed_indexes.append(RealIndex(index.strip()))
    return parsed_indexes

# 示例：使用提供的索引配置
parsed_indexes = parse_index_configs(index_configs_workload_50_tpch10_tree_model)

# 数据库连接信息
db_params = {
    'dbname': 'indexselection_tpch___10',
    'user': 'postgres',
    'password': 'password',
    'host': 'localhost',
    'port': 5432
}


# 测试工作负载
query_list = queries_list.copy()
# 执行查询并测量时间
executor = QueryExecutor(**db_params)

# # no index 
# total_execution_time, exe_list= executor.execute_workload_and_measure_time(query_list)
# print(f"Total execution time for workload: {total_execution_time:.4f} s")

# 创建索引
for idx in parsed_indexes:
    executor.create_index(idx)

# 执行工作负载
total_execution_time, exe_list= executor.execute_workload_and_measure_time(query_list)
print(f"Total execution time for workload: {total_execution_time:.4f} s")

# 清理：删除索引
for idx in parsed_indexes:
    executor.drop_index(idx)

executor.close()
print('exe_list',exe_list)
# Out:
# CREATEING INDEX ON orders (o_orderdate)
# CREATEING INDEX ON customer (c_custkey)
# CREATEING INDEX ON lineitem (l_shipdate)
# Query 1: executed in 19.9882 seconds
# Query 2: executed in 7.0310 seconds
# Query 3: executed in 9.3202 seconds
# Query 4: executed in 7.0094 seconds
# Query 5: executed in 4.9503 seconds
# Query 6: executed in 6.5348 seconds
whatif=170.9662
exe_list_whatif=[19.05151867866516, 6.99236798286438, 8.655571460723877, 5.994517087936401, 2.811271905899048, 5.551562786102295, 4.999118328094482, 20.070071697235107, 8.424728870391846, 1.1769258975982666, 7.74394416809082, 4.747687816619873, 4.841948747634888, 44.75519633293152, 0.4367256164550781, 24.713005542755127]
lib=183.6464
exe_list_lib=[20.9546537399292, 8.070940494537354, 9.76323914527893, 6.807253837585449, 3.849627733230591, 6.763085842132568, 7.348547697067261, 18.379640340805054, 8.601769924163818, 1.82212495803833, 7.8722546100616455, 4.945090293884277, 5.162890911102295, 45.644519567489624, 5.264846086502075, 22.39594006538391]
tree_model=181.0099
exe_list_tree_model=[19.988238096237183, 7.031023740768433, 9.320241212844849, 7.009415864944458, 4.950334548950195, 6.534795761108398, 8.302945852279663, 20.87278985977173, 8.691076517105103, 1.7128398418426514, 7.957862615585327, 2.113158941268921, 4.871729850769043, 43.19474196434021, 5.204153776168823, 23.254599571228027]

# %%
import pandas as pd

# 计算提升比率
def calculate_ratios(no_index_exe_list, exe_list):
    ratios = []
    for i in range(len(no_index_exe_list)):
        no_index_time = no_index_exe_list[i]
        exe_time = exe_list[i]
        ratio = ((no_index_time - exe_time) / no_index_time) * 100
        ratios.append(ratio)
    return ratios

# 计算每个方法的提升比率
ratios_whatif = calculate_ratios(no_index_exe_list, exe_list_whatif)
ratios_rainbow = calculate_ratios(no_index_exe_list, exe_list_rainbow)
ratios_lib = calculate_ratios(no_index_exe_list, exe_list_lib)
ratios_tree_model = calculate_ratios(no_index_exe_list, exe_list_tree_model)

# 创建DataFrame来存储结果
data = {
    'Query Index': list(range(1, len(no_index_exe_list) + 1)),
    'No_index_exe_list' : no_index_exe_list,
    'Exe_list_whatif' : exe_list_whatif,
    'Exe_list_rainbow' : exe_list_rainbow,
    'Exe_list_lib' : exe_list_lib,
    'Exe_list_AIMEETAI' : exe_list_tree_model,
    'Whatif Ratio (%)': ratios_whatif,
    'Rainbow Ratio (%)': ratios_rainbow,
    'Lib Ratio (%)': ratios_lib,
    'Tree Model Ratio (%)': ratios_tree_model
}

df = pd.DataFrame(data)
df.head()
# Out:
#    Query Index  No_index_exe_list  Exe_list_whatif  Exe_list_rainbow  \
# 0            1           0.178698         0.031849          0.148830
# 1            2           0.132417         0.028544          0.126839
# 2            3           0.172218         0.050863          0.157209
# 3            4           0.164249         0.043602          0.147773
# 4            5           0.161236         0.050847          0.151845
#
#    Exe_list_lib  Exe_list_AIMEETAI  Whatif Ratio (%)  Rainbow Ratio (%)  \
# 0      0.221425           0.027435         82.177337          16.713808
# 1      0.128057           0.023928         78.443489           4.212130
# 2      0.150847           0.037460         70.465960           8.715473
# 3      0.155953           0.034248         73.453503          10.031180
# 4      0.157251           0.031187         68.464067           5.824719
#
#    Lib Ratio (%)  Tree Model Ratio (%)
# 0     -23.910224             84.647210
# ...

# %%
df.to_csv('./tpcds1_query_improvement.csv')
