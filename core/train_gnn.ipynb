# %%
import pandas as pd
import numpy as np
import torch
from torch import nn
from torch_geometric.data import Data
from torch_geometric.nn import TransformerConv, TopKPooling
from torch_geometric.nn import global_mean_pool as gap, global_max_pool as gmp
from torch_geometric.loader import DataLoader
import gpytorch
from gpytorch.mlls import DeepApproximateMLL, VariationalELBO
from gpytorch.likelihoods import GaussianLikelihood
import os
import sys
import random
loger_dir = os.path.abspath('/home/ubuntu/project/mayang/LOGER')

# 将 QPE 目录添加到 sys.path
sys.path.append(loger_dir)
from core.models.DGP import DeepGPModel
from core.models.DKL import DKLGPModel
from sql import Sql, _global
from core import database, Sql, Plan, load
import ast
import re
import torch.nn as nn
import torch.nn.functional as F


# 获取 QPE 目录的绝对路径
qpe_dir = os.path.abspath('/home/ubuntu/project/mayang')

# 将 QPE 目录添加到 sys.path
sys.path.append(qpe_dir)

# 现在尝试导入 TreeBuilder 类
from QPE.sql2fea import TreeBuilder

def parse_attribute_config(index_str):
    '''处理输入的configuration，转化成cols/attribute的形式'''
    # 将字符串转换为列表
    index_list = ast.literal_eval(index_str)
    
    table_cols_list = []
    for index in index_list:
        # 去掉 I() 的部分，提取表名和列名
        index_content = index[4:-1]  # 去掉前面的 'I(' 和后面的 ')'
        table_cols = index_content.split(',')
        table_cols_list.append(table_cols)
    
    return table_cols_list

def swap_join_condition(condition: str) -> str:
    '''防止同一个连接条件，左右连接条件不一样而无法识别'''
    # 找到等号的位置
    equal_index = condition.find('=')

    # 如果没有找到等号，返回原字符串
    if equal_index == -1:
        return condition

    # 拆分等号两边的条件，并去掉左右空格
    left_side = condition[:equal_index].strip()
    right_side = condition[equal_index + 1:].strip()

    # 交换等式两边的条件
    swapped_condition = f"{right_side} = {left_side}"

    return swapped_condition


def has_text_expression(cmp: str) -> bool:
    '''判断cmp中有没有文本'''
    # 使用正则表达式查找被引号包围的文本
    pattern = r"'[^']*'"

    # 查找匹配的内容
    match = re.search(pattern, cmp)

    # 如果找到了匹配内容，返回 True；否则返回 False
    return match is not None


def convert_between_expression(cmp: str) -> str:
    '''转换 BETWEEN 表达式'''
    match = re.match(r"([\w\.]+)\.(\w+)\s*BETWEEN\s*(.*)\s*AND\s*(.*)", cmp)

    if not match:
        raise ValueError("The input string is not a valid BETWEEN expression.")

    table_name, column, lower_bound, upper_bound = match.groups()

    # 检查值是否是数字
    if lower_bound.strip().isdigit() and upper_bound.strip().isdigit():
        new_expression = f"(({column} >= {lower_bound.strip()}) AND ({column} <= {upper_bound.strip()}))"
    else:
        new_expression = f"(({column})::text >= {lower_bound.strip()}::text) AND (({column})::text <= {upper_bound.strip()}::text)"

    return table_name, new_expression[:-1]


def convert_to_text_comparison(cmp: str):
    '''转化cmp与plan中的谓词表示, 处理 IN 语句。'''
    match_eq = re.match(r"([\w\.]+)\.(\w+)\s*(=|<>|<|>|<=|>=)\s*'(.*)'", cmp)
    match_in = re.match(r"([\w\.]+)\.(\w+)\s*IN\s*\((.*)\)", cmp, re.DOTALL)

    if match_eq:
        # 处理 '=' 比较
        table_name, column, operator, value = match_eq.groups()
        new_expression = f"(({column})::text {operator} '{value}'::text)"
        return table_name, new_expression
    elif match_in:
        # 处理 'IN' 比较
        table_name, column, values = match_in.groups()

        # 使用正则提取引号中的值，允许多行
        value_list = re.findall(r"'(.*?)'", values)
        if not value_list:
            raise ValueError("在 IN 表达式中未找到有效值。")

        # 检查是否存在嵌套括号
        if '(' in values or ')' in values:
            new_expression = f"(({column})::text = ANY ("
            return table_name, new_expression

        # 检查是否有值包含两个单词
        if len(value_list) > 1 and any(len(value.split()) > 1 for value in value_list):
            new_expression = f"(({column})::text = ANY ("
            return table_name, new_expression

        # 检查是否只有一个值
        if len(value_list) == 1:
            new_expression = f"(({column})::text = '{value_list[0]}'::text)"
        else:
            formatted_values = ','.join(value_list)  # 拼接多个值
            new_expression = f"(({column})::text = ANY ('{{{formatted_values}}}'::text[]))"

        return table_name, new_expression

    raise ValueError("输入字符串不是有效的比较表达式。")


def trim_parentheses_and_spaces(input_str: str) -> str:
    # 去除开头的空格
    trimmed_str = input_str.lstrip()
    # 如果开头是 '('，则去除它
    if trimmed_str.startswith('('):
        trimmed_str = trimmed_str[1:].lstrip()  # 去掉 '(' 以及后面的空格
    return trimmed_str


def transform_sql_like_condition(sql_condition):
    '''处理LIKE和NOT LIKE条件'''
    # 匹配 `AND` 和 `OR`
    sql_condition = trim_parentheses_and_spaces(sql_condition)
    conditions = re.split(r"(?i) AND | OR ", sql_condition)
    # print(conditions)

    # 转换每个 LIKE 和 NOT LIKE 条件为 Postgres 的格式
    transformed_clauses = []
    for condition in conditions:
        condition = condition.strip()
        table_name = condition.split('.')[0]
        col_name = condition.split()[0][len(table_name) + 1:]
        if 'not like' in condition.lower():
            transformed_clause = f"(({col_name})::text !~~ {condition.split('not like')[1].strip().rstrip(')')}::text)"
        elif 'like' in condition.lower():
            transformed_clause = f"(({col_name})::text ~~ {condition.split('like')[1].strip().rstrip(')')}::text)"
            # print("condition.split('like')[1].strip()",condition.split('like')[1].strip())
        else:
            continue

        transformed_clauses.append(transformed_clause)

    # 返回表名和第一个转换后的条件
    return table_name, transformed_clauses[0]


def delete_left_table_cond(sql_condition):
    # 使用正则表达式匹配表名和列名
    match = re.match(r"[\w\.]+\.(\w+)\s*=\s*(.*)", sql_condition)

    if not match:
        raise ValueError("The input string is not a valid comparison expression.")

    # 提取列名和右侧表达式
    column = match.group(1)
    right_side = match.group(2)

    return f"{column} = {right_side.strip()}"


def dgl_node_and_edge_vectorization(sql_query, config_index, plan,attribute_dict):
    sql_instance = Sql(sql_query)

    # 构建异构图
    g, data_dict, node_indexes, edge_list = sql_instance.to_hetero_graph_dgl()
    # 构建 node feature
    filter_features = g.ndata['filter']
    edge_features = g.ndata['edge']
    onehot_features = g.ndata['onehot']
    others_features = g.ndata['others'].view(g.ndata['filter'].shape[0], -1)

    # 假设两个特征的维度是相同的
    combined_features = torch.cat((filter_features, edge_features, onehot_features, others_features), dim=1)
    g.ndata['feature'] = combined_features

    # 构建 edge feature
    tree_builder = TreeBuilder()
    tree_builder.set_configruations(config_index)
    tree_builder.set_table_to_alias_dict(sql_query)
    # 准备您的 SQL 执行计划数据，这里是一个示例
    execution_plan = ast.literal_eval(plan)[0]['Plan']

    # 特征化执行计划
    features = tree_builder.plan_to_feature_tree(execution_plan, current_height=0)

    # 提取对应operator vector
    operator_vector_dict = tree_builder.get_operator_vector()
    # 建立cmp与plan_operator的映射关系
    tables = []
    operator_vectors_cmp1 = []
    operator_vectors_cmp2 = []
    get_keys = []
    for cmp, table_num in edge_list:
        flag = False
        # print('cmp:',cmp)
        if table_num == 1:
            if 'like' in cmp and has_text_expression(cmp):
                try:
                    table, cmp_in_op = transform_sql_like_condition(cmp)
                except:
                    print('error process like_cmp:', cmp)
            elif 'BETWEEN' in cmp:
                table, cmp_in_op = convert_between_expression(cmp)
            elif has_text_expression(cmp):
                table, cmp_in_op = convert_to_text_comparison(cmp)
            else:
                table, cmp_in_op = cmp.split('.')

        for key in operator_vector_dict:
            if table_num == 1:
                table_op, key_op = key.split('_47_')
                if cmp_in_op in key and table == table_op:
                    tables.append(table)
                    operator_vectors_cmp1.append(operator_vector_dict[key])
                    flag = True
                    break
            # print(key)
            elif cmp in key or swap_join_condition(cmp) in key or delete_left_table_cond(
                    cmp) in key or delete_left_table_cond(swap_join_condition(cmp)) in key:
                get_keys.append(cmp)
                operator_vectors_cmp2.append(operator_vector_dict[key])
                operator_vectors_cmp2.append(operator_vector_dict[key])
                flag = True
                break
        if not flag:
            # 存在plan中不存在的cmp
            print('error cmp', cmp)
            if table_num == 2:
                print('add edge vector:', table_num)
                operator_vectors_cmp2.append(torch.zeros((1, num_edge_features)))
                operator_vectors_cmp2.append(torch.zeros((1, num_edge_features)))
    # print('cmp',len(edge_list))
    # print(len(operator_vectors_cmp1),len(operator_vectors_cmp2))
    # 合并每一条边的向量
    vector_cmp1 = torch.cat(operator_vectors_cmp1, dim=0)
    vector_cmp2 = torch.cat(operator_vectors_cmp2, dim=0)
    vector_edge = torch.cat((vector_cmp2, vector_cmp1), dim=0)
    # 添加自环
    for t in tables:
        new_u = torch.tensor([node_indexes['~' + t]])  # 自环的起点
        new_v = torch.tensor([node_indexes['~' + t]])  # 自环的终点
        g.add_edges(new_u, new_v)
    g.edata['feature'] = vector_edge
    
    #构建configuration特征
    configuration_vector=[0]*len(attribute_dict)
    for attrs in parse_attribute_config(config_index):
        for p in range(len(attrs)):
            #获得在indexed_attribute中的位置
            attr=attrs[p]
            if attr[:2]=='C ':
                attr=attr[2:]
            attr_p=attribute_dict[attr]
            configuration_vector[attr_p]+=1/(p+1)
    g.global_data = {"configuration_vector": torch.tensor(configuration_vector)}
    return g


def dgl_to_pyg(dgl_graph,label):
    """将 DGL 图转换为 PyG 格式."""
    x = dgl_graph.ndata['feature']  # 节点特征
    edge_index = torch.stack(dgl_graph.edges()).long()  # 边索引 (转换为 PyG 格式)
    edge_attr = dgl_graph.edata['feature']  # 边特征
    configuration_vector = dgl_graph.global_data['configuration_vector'] # configuration_vector
    batch = torch.zeros(dgl_graph.number_of_nodes(), dtype=torch.long)  # 所有节点归为同一批次
    label_tensor = torch.tensor(label, dtype=torch.float32)  # 根据需要使用 float32 或其他类型
    return Data(x=x, edge_index=edge_index, edge_attr=edge_attr, configuration_vector=configuration_vector,y=label_tensor, batch=batch)


# class GraphEncoder(nn.Module):
#     """图编码模块，基于 TransformerConv."""

#     def __init__(self, in_feats, edge_feats, embedding_size, num_layers=3, top_k_every_n=3, top_k_ratio=0.5, n_heads=4,
#                  dropout_rate=0.5):
#         super(GraphEncoder, self).__init__()
#         self.embedding_size = embedding_size
#         self.top_k_every_n = top_k_every_n
#         self.edge_dim = edge_feats
#         self.n_heads = n_heads

#         # 第一层 TransformerConv
#         self.conv1 = TransformerConv(in_feats, self.embedding_size, heads=n_heads, dropout=dropout_rate,
#                                      edge_dim=edge_feats, beta=True)
#         self.transf1 = nn.Linear(self.embedding_size * n_heads, self.embedding_size)
#         self.bn1 = nn.BatchNorm1d(self.embedding_size)

#         # 其他 TransformerConv 层及 TopKPooling
#         # TopKPooling 需要对图进行下采样，类似于卷积神经网络（CNN）中的池化操作，用来减小图的大小，保留最重要的信息。
#         self.conv_layers = nn.ModuleList()
#         self.transf_layers = nn.ModuleList()
#         self.bn_layers = nn.ModuleList()
#         self.pooling_layers = nn.ModuleList()

#         for _ in range(num_layers):
#             self.conv_layers.append(
#                 TransformerConv(self.embedding_size, self.embedding_size, heads=n_heads, dropout=dropout_rate,
#                                 edge_dim=edge_feats, beta=True))
#             self.transf_layers.append(nn.Linear(self.embedding_size * n_heads, self.embedding_size))
#             self.bn_layers.append(nn.BatchNorm1d(self.embedding_size))
#             self.pooling_layers.append(TopKPooling(self.embedding_size, ratio=top_k_ratio))

#     def forward(self, x, edge_attr, edge_index, batch_index):
#         # print('x',x.shape)
#         x = self.conv1(x, edge_index, edge_attr)

#         # 调整线性层输入的形状
#         x = torch.relu(self.transf1(x.view(-1, self.embedding_size * self.n_heads)))
#         x = self.bn1(x)

#         global_representation = []

#         for i, conv_layer in enumerate(self.conv_layers):
#             x = conv_layer(x, edge_index, edge_attr)
#             x = torch.relu(self.transf_layers[i](x.view(-1, self.embedding_size * self.n_heads)))  # 确保形状匹配
#             x = self.bn_layers[i](x)

#             if i % self.top_k_every_n == 0 or i == len(self.conv_layers) - 1:
#                 # print('edge_index', edge_index.shape)
#                 x, edge_index, edge_attr, batch_index, _, _ = self.pooling_layers[i](
#                     x, edge_index, edge_attr, batch_index
#                 )
#                 global_representation.append(torch.cat([
#                     gmp(x, batch_index),
#                     gap(x, batch_index)
#                 ], dim=1))

#         x = sum(global_representation)

#         return x

class GraphEncoder(nn.Module):
    """图编码模块，基于 TransformerConv,添加了残差连接。"""

    def __init__(self, in_feats, edge_feats, embedding_size, num_layers=3, top_k_every_n=3, top_k_ratio=0.5, n_heads=4,
                 dropout_rate=0.5):
        super(GraphEncoder, self).__init__()
        self.embedding_size = embedding_size
        self.top_k_every_n = top_k_every_n
        self.edge_dim = edge_feats
        self.n_heads = n_heads

        # 第一层 TransformerConv
        self.conv1 = TransformerConv(in_feats, self.embedding_size, heads=n_heads, dropout=dropout_rate,
                                     edge_dim=edge_feats, beta=True)
        self.transf1 = nn.Linear(self.embedding_size * n_heads, self.embedding_size)
        self.bn1 = nn.BatchNorm1d(self.embedding_size)

        # 其他 TransformerConv 层及 TopKPooling
        self.conv_layers = nn.ModuleList()
        self.transf_layers = nn.ModuleList()
        self.bn_layers = nn.ModuleList()
        self.pooling_layers = nn.ModuleList()

        for _ in range(num_layers):
            self.conv_layers.append(
                TransformerConv(self.embedding_size, self.embedding_size, heads=n_heads, dropout=dropout_rate,
                                edge_dim=edge_feats, beta=True))
            self.transf_layers.append(nn.Linear(self.embedding_size * n_heads, self.embedding_size))
            self.bn_layers.append(nn.BatchNorm1d(self.embedding_size))
            self.pooling_layers.append(TopKPooling(self.embedding_size, ratio=top_k_ratio))

    def forward(self, x, edge_attr, edge_index, batch_index):
        # 残差连接的初始输入
        residual = x

        # 第一个 TransformerConv 层及线性变换
        x = self.conv1(x, edge_index, edge_attr)
        x = torch.relu(self.transf1(x.view(-1, self.embedding_size * self.n_heads)))
        x = self.bn1(x)

        # 添加残差连接，将初始输入加入 x
        if residual.shape == x.shape:
            x = x + residual  # 进行残差连接

        global_representation = []

        for i, conv_layer in enumerate(self.conv_layers):
            # 每一层的残差输入
            residual = x

            # TransformerConv 和线性变换
            x = conv_layer(x, edge_index, edge_attr)
            x = torch.relu(self.transf_layers[i](x.view(-1, self.embedding_size * self.n_heads)))  # 确保形状匹配
            x = self.bn_layers[i](x)

            # 残差连接
            if residual.shape == x.shape:
                x = x + residual  # 进行残差连接

            if i % self.top_k_every_n == 0 or i == len(self.conv_layers) - 1:
                x, edge_index, edge_attr, batch_index, _, _ = self.pooling_layers[i](
                    x, edge_index, edge_attr, batch_index
                )
                global_representation.append(torch.cat([
                    gmp(x, batch_index),
                    gap(x, batch_index)
                ], dim=1))

        # 将全局表示相加作为最终输出
        x = sum(global_representation)

        return x



class ImprovementPredictionModelGNN(nn.Module):
    """使用图卷积神经网络进行预测，基于图编码，并增加多层线性层，融合配置向量."""
    
    def __init__(self, in_feats, edge_feats, graph_embedding_size, config_vector_size, hidden_dim=128, num_layers=3):
        print('start ImprovementPredictionModelGNN')
        super(ImprovementPredictionModelGNN, self).__init__()
        
        # 图编码器
        self.graph_encoder = GraphEncoder(in_feats, edge_feats, graph_embedding_size)
        
        # 定义多个全连接层
        self.layers = nn.ModuleList()
        self.batch_norms = nn.ModuleList()  # 批归一化层列表
        
        # 第一层，从 (图嵌入维度 + 配置向量维度) 到隐藏层维度
        input_dim = graph_embedding_size * 2 + config_vector_size  # 2 * graph_embedding_size 因为全局池化时合并了 mean 和 max
        self.layers.append(nn.Linear(input_dim, hidden_dim))
        self.batch_norms.append(nn.BatchNorm1d(hidden_dim))  # 添加批归一化层

        # 中间的隐藏层
        for _ in range(num_layers - 2):
            self.layers.append(nn.Linear(hidden_dim, hidden_dim))
            self.batch_norms.append(nn.BatchNorm1d(hidden_dim))
        
        # 最后一层，隐藏层到输出维度
        self.layers.append(nn.Linear(hidden_dim, 1))  # 输出为单个值
        
    def forward(self, x, edge_attr, edge_index, configuration_vector, batch_index):
        # 通过图编码器获取图的嵌入表示
        graph_embedding = self.graph_encoder(x, edge_attr, edge_index, batch_index)
        
        # 拼接 graph_embedding 和 configuration_vector
        configuration_vector = configuration_vector.view(graph_embedding.size(0), -1)  # 调整 configuration_vector 的形状
        graph_embedding = torch.cat([graph_embedding, configuration_vector], dim=1)
        
        # 将拼接后的向量输入到多层全连接网络
        for i, layer in enumerate(self.layers[:-1]):
            graph_embedding = layer(graph_embedding)  # 全连接层
            graph_embedding = self.batch_norms[i](graph_embedding)  # 批归一化层
            graph_embedding = F.relu(graph_embedding)  # ReLU 激活函数
        
        # 最后一层输出预测值
        output = self.layers[-1](graph_embedding)
        prediction = F.sigmoid(output)  # 使用 ReLU 激活函数保证输出非负数
        
        return prediction
    
    def predict(self, x, edge_attr, edge_index, configuration_vector, batch_index):
        """在预测时调用"""
        self.eval()  # 设置为评估模式
        with torch.no_grad():
            graph_embedding = self.graph_encoder(x, edge_attr, edge_index, batch_index)
            
            # 拼接 graph_embedding 和 configuration_vector
            configuration_vector = configuration_vector.view(graph_embedding.size(0), -1)
            graph_embedding = torch.cat([graph_embedding, configuration_vector], dim=1)
            
            # 通过多层全连接网络计算预测值
            for i, layer in enumerate(self.layers[:-1]):
                graph_embedding = layer(graph_embedding)
                graph_embedding = self.batch_norms[i](graph_embedding)
                graph_embedding = F.relu(graph_embedding)
                
            output = self.layers[-1](graph_embedding)
            prediction = F.sigmoid(output)  # 保证预测值为非负数
            
        return prediction




def load_sql_graphs_pyg(csv_path, dbname, user, password, host, port, start_idx=0, end_idx=8877):
    """
    从指定的 CSV 文件加载 SQL 查询，并将它们转换为 PyG 图数据。

    参数:
    - csv_path (str): CSV 文件路径。
    - dbname (str): 数据库名称。
    - user (str): 数据库用户。
    - password (str): 数据库密码。
    - host (str): 数据库主机地址。
    - port (str): 数据库端口。
    - start_idx (int): SQL 查询的起始索引。
    - end_idx (int): SQL 查询的结束索引。

    返回:
    - sql_graphs_pyg (list): PyG 数据列表。
    """
    print('start load_sql_graphs_pyg')
    # 读取 CSV 数据
    df = pd.read_csv(csv_path).iloc[start_idx:, :]
    # df = pd.read_csv(csv_path).iloc[start_idx:, :].sample(n=3200, random_state=42)
    # 设置数据库连接
    database.setup(dbname=dbname, user=user, password=password, host=host, port=port, cache=False)
    sql_graphs_pyg = []
    #创建index的vector
    attribute_num=0
    attribute_dict={}
    for x in df['index'].values:
        for attrs in parse_attribute_config(x):
            for attr in attrs:
                if attr[:2]=='C ':
                    attr=attr[2:]
                if attr not in attribute_dict:
                    attribute_dict[attr]=attribute_num
                    attribute_num+=1


    query_list = df['query'].values
    quey_config_list = df['index'].values
    query_plans = df['query_plan_no_index'].values
    for i in range(df.shape[0]):
        # if cnt % 50 == 0:
        #     print(cnt)
        print(i)
        g = dgl_node_and_edge_vectorization(query_list[i], quey_config_list[i], query_plans[i], attribute_dict)
        # 转换为 PyG 数据
        pyg_data = dgl_to_pyg(g,df['label'].values[i])
        sql_graphs_pyg.append(pyg_data)

    return sql_graphs_pyg, df['label'].values, len(attribute_dict)

num_edge_features = 15

    # 读取数据并设置数据库
sql_graphs_pyg, label_list, config_vector_size = load_sql_graphs_pyg(
        csv_path='/home/ubuntu/project/mayang/Classification/process_data/job/job_train_8935.csv',
        dbname='imdbload',
        user='postgres',
        password='password',
        host='127.0.0.1',
        port='5432',
        start_idx=7
    )
print('len(label_list) 需要是batch_size的倍数', len(label_list))

# 设置随机种子
seed = 47
torch.manual_seed(seed)  # PyTorch 随机种子
np.random.seed(seed)  # NumPy 随机种子
random.seed(seed)  # Python 随机种子
# 创建 PyG DataLoader
data_loader = DataLoader(sql_graphs_pyg, batch_size=32, shuffle=True)
# Out:
# start load_sql_graphs_pyg
# {'dbname': 'imdbload', 'user': 'postgres', 'password': 'password', 'host': '127.0.0.1', 'port': '5432', 'cache': False}
# <connection object at 0x7fbf3b459180; dsn: 'user=postgres password=xxx dbname=imdbload host=127.0.0.1 port=5432', closed: 0>
# <cursor object at 0x7fbf3b45f400; closed: 0>
# 0
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 1
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 2
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 3
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 4
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 5
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 6
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 7
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 8
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 9
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 10
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 11
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 12
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 13
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 14
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 15
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 16
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 17
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 18
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 19
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 20
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 21
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 22
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 23
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 24
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 25
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 26
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 27
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 28
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 29
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 30
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 31
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 32
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 33
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 34
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 35
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 36
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 37
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 38
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 39
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 40
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 41
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 42
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 43
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 44
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 45
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 46
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 47
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 48
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 49
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 50
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 51
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 52
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 53
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 54
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 55
# error cmp mc.movie_id = t.id
# add edge vector: 2
# 56
# error cmp n1.id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 57
# error cmp n1.id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 58
# error cmp n1.id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 59
# error cmp n1.id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 60
# error cmp n1.id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 61
# error cmp n1.id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 62
# error cmp n1.id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 63
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 64
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 65
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 66
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 67
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 68
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 69
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 70
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 71
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 72
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 73
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 74
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 75
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 76
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 77
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 78
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 79
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 80
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 81
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 82
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 83
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 84
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 85
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 86
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 87
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 88
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 89
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 90
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 91
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 92
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 93
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 94
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 95
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 96
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 97
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 98
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 99
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 100
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 101
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 102
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 103
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 104
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 105
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 106
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 107
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 108
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 109
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 110
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 111
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 112
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 113
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 114
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 115
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 116
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 117
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 118
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 119
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 120
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 121
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 122
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 123
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 124
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 125
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 126
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 127
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 128
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 129
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 130
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 131
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 132
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 133
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 134
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 135
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 136
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 137
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 138
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 139
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 140
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 141
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 142
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 143
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 144
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 145
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 146
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 147
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 148
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 149
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 150
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 151
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 152
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 153
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 154
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 155
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 156
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 157
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 158
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 159
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 160
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 161
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 162
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 163
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 164
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 165
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 166
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 167
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 168
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 169
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 170
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 171
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 172
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 173
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 174
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 175
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 176
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 177
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 178
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 179
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 180
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 181
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 182
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 183
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 184
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 185
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 186
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 187
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 188
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 189
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 190
# error cmp ml.movie_id = mc.movie_id
# add edge vector: 2
# 191
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 192
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 193
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 194
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 195
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 196
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 197
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 198
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 199
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 200
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 201
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 202
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 203
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 204
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 205
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 206
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 207
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 208
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 209
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 210
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 211
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 212
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 213
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 214
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 215
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 216
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 217
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 218
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 219
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 220
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 221
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 222
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 223
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 224
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 225
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 226
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 227
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 228
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 229
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 230
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 231
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 232
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 233
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 234
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
# 235
# error cmp an.person_id = ci.person_id
# add edge vector: 2
# error cmp ci.movie_id = mc.movie_id
# add edge vector: 2
#
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 786
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 787
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 788
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 789
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 790
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 791
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 792
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 793
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 794
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 795
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 796
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 797
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 798
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 799
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 800
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 801
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 802
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 803
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 804
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 805
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 806
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 807
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 808
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 809
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 810
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 811
# error cmp mc.movie_id = at.movie_id
# add edge vector: 2
# 812
# error cmp mc.movie_id = at.movie_id
# ...
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8803
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8804
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8805
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8806
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8807
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8808
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8809
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8810
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8811
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8812
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8813
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8814
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8815
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8816
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8817
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8818
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8819
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8820
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8821
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8822
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8823
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8824
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8825
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8826
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8827
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8828
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8829
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8830
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8831
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8832
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8833
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8834
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8835
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8836
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8837
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8838
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8839
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8840
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8841
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8842
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8843
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8844
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8845
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8846
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8847
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8848
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8849
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8850
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8851
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8852
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8853
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8854
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8855
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8856
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8857
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8858
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8859
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8860
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8861
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8862
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8863
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8864
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8865
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8866
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8867
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8868
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8869
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8870
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8871
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8872
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8873
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8874
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8875
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8876
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8877
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8878
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8879
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8880
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8881
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8882
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8883
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8884
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8885
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8886
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8887
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8888
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8889
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8890
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8891
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8892
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8893
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8894
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8895
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8896
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8897
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8898
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8899
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8900
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8901
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8902
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8903
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8904
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8905
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8906
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8907
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8908
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8909
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8910
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8911
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8912
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8913
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8914
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8915
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8916
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8917
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8918
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8919
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8920
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8921
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8922
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8923
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8924
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8925
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8926
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# 8927
# error cmp mi_idx1.movie_id = mc1.movie_id
# add edge vector: 2
# error cmp mi_idx2.movie_id = mc2.movie_id
# add edge vector: 2
# len(label_list) 需要是batch_size的倍数 8928

# %%
class ImprovementPredictionModelGNN(nn.Module):
    """使用图卷积神经网络进行预测，基于图编码，并增加多层线性层，融合配置向量。"""
    
    def __init__(self, in_feats, edge_feats, graph_embedding_size, config_vector_size, hidden_dim=128, num_layers=3, dropout_prob=0.1):
        print('start ImprovementPredictionModelGNN')
        super(ImprovementPredictionModelGNN, self).__init__()
        
        # 图编码器
        self.graph_encoder = GraphEncoder(in_feats, edge_feats, graph_embedding_size)
        
        # 定义多个全连接层
        self.layers = nn.ModuleList()
        self.batch_norms = nn.ModuleList()  # 批归一化层列表
        self.dropouts = nn.ModuleList()  # Dropout 层列表
        
        # 第一层，从 (图嵌入维度 + 配置向量维度) 到隐藏层维度
        input_dim = graph_embedding_size * 2 + config_vector_size  # 2 * graph_embedding_size 因为全局池化时合并了 mean 和 max
        self.layers.append(nn.Linear(input_dim, hidden_dim))
        self.batch_norms.append(nn.BatchNorm1d(hidden_dim))  # 添加批归一化层
        self.dropouts.append(nn.Dropout(dropout_prob))  # 添加 Dropout 层
        
        # 中间的隐藏层
        for _ in range(num_layers - 2):
            self.layers.append(nn.Linear(hidden_dim, hidden_dim))
            self.batch_norms.append(nn.BatchNorm1d(hidden_dim))
            self.dropouts.append(nn.Dropout(dropout_prob))  # 添加 Dropout 层
        
        # 最后一层，隐藏层到输出维度
        self.layers.append(nn.Linear(hidden_dim, 1))  # 输出为单个值
        
    def forward(self, x, edge_attr, edge_index, configuration_vector, batch_index):
        # 通过图编码器获取图的嵌入表示
        graph_embedding = self.graph_encoder(x, edge_attr, edge_index, batch_index)
        
        # 拼接 graph_embedding 和 configuration_vector
        configuration_vector = configuration_vector.view(graph_embedding.size(0), -1)  # 调整 configuration_vector 的形状
        graph_embedding = torch.cat([graph_embedding, configuration_vector], dim=1)
        
        # 将拼接后的向量输入到多层全连接网络
        for i, layer in enumerate(self.layers[:-1]):
            graph_embedding = layer(graph_embedding)  # 全连接层
            graph_embedding = self.batch_norms[i](graph_embedding)  # 批归一化层
            graph_embedding = F.relu(graph_embedding)  # ReLU 激活函数
            graph_embedding = self.dropouts[i](graph_embedding)  # Dropout 层
        
        # 最后一层输出预测值
        output = self.layers[-1](graph_embedding)
        prediction = torch.sigmoid(output)  # 使用 Sigmoid 激活函数
        
        return prediction
    
    def predict(self, x, edge_attr, edge_index, configuration_vector, batch_index):
        """在预测时调用"""
        self.eval()  # 设置为评估模式
        with torch.no_grad():
            graph_embedding = self.graph_encoder(x, edge_attr, edge_index, batch_index)
            
            # 拼接 graph_embedding 和 configuration_vector
            configuration_vector = configuration_vector.view(graph_embedding.size(0), -1)
            graph_embedding = torch.cat([graph_embedding, configuration_vector], dim=1)
            
            # 通过多层全连接网络计算预测值
            for i, layer in enumerate(self.layers[:-1]):
                graph_embedding = layer(graph_embedding)
                graph_embedding = self.batch_norms[i](graph_embedding)
                graph_embedding = F.relu(graph_embedding)
                graph_embedding = self.dropouts[i](graph_embedding)  # Dropout 层
                
            output = self.layers[-1](graph_embedding)
            prediction = torch.sigmoid(output)  # 保证预测值为非负数
            
        return prediction

# %%
import numpy as np
import random

class EarlyStopping:
    def __init__(self, patience=5, threshold=0.0):
        self.patience = patience  # 容忍度
        self.threshold = threshold  # 最小变化量
        self.best_loss = float('inf')  # 最佳验证损失
        self.counter = 0  # 计数器

    def check(self, loss):
        if loss < self.best_loss - self.threshold:
            self.best_loss = loss
            self.counter = 0  # 重置计数器
            return False  # 继续训练
        else:
            self.counter += 1
            if self.counter >= self.patience:
                return True  # 停止训练
            return False  # 继续训练

# 初始化模型、优化器和损失函数
model = ImprovementPredictionModelGNN(sql_graphs_pyg[0].x.shape[1], sql_graphs_pyg[0].edge_attr.shape[1],
                                       graph_embedding_size=32, config_vector_size=config_vector_size)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.MSELoss()

early_stopping = EarlyStopping(patience=3, threshold=1)  # 初始化早停策略

for epoch in range(100):
    total_loss = 0
    for batch_idx, batch in enumerate(data_loader):
        # 前向传播
        pred_time = model(batch.x, batch.edge_attr, batch.edge_index, batch.configuration_vector, batch.batch)

        target = batch.y.view(-1, 1)

        loss = criterion(pred_time, target)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        print("Epoch %d batch_idx%d loss:" % (epoch + 1, batch_idx), loss.item())

    print(f'Epoch {epoch + 1}, Loss: {total_loss:.4f}')

    # 随机抽取 20 个样本进行预测
    sample_indices = random.sample(range(len(sql_graphs_pyg)), 50)
    min_diff = []
    for idx in sample_indices:
        sample_batch = sql_graphs_pyg[idx]
        sample_x = sample_batch.x
        sample_edge_attr = sample_batch.edge_attr
        sample_edge_index = sample_batch.edge_index
        sample_configuration_vector = sample_batch.configuration_vector

        target_value = label_list[idx]
        model.eval()
        with torch.no_grad():
            pred_mean = model.predict(sample_x, sample_edge_attr, sample_edge_index, sample_configuration_vector, sample_batch.batch)

        print(f'Sample Index: {idx}, Predicted Mean: {pred_mean}, Target Value: {target_value}, difference: {pred_mean - target_value}')
        if abs(pred_mean - target_value) < 0.1:
            min_diff.append(pred_mean - target_value)

    print('the number of samples < 0.1:', len(min_diff))

    # 检查早停条件
    if early_stopping.check(total_loss):
        print("Early stopping triggered.")
        break
# Out:
# start ImprovementPredictionModelGNN
# Epoch 1 batch_idx0 loss: 0.14141400158405304
# Epoch 1 batch_idx1 loss: 0.11997506022453308
# Epoch 1 batch_idx2 loss: 0.17384910583496094
# Epoch 1 batch_idx3 loss: 0.10877621918916702
# Epoch 1 batch_idx4 loss: 0.15070609748363495
# Epoch 1 batch_idx5 loss: 0.09635663032531738
# Epoch 1 batch_idx6 loss: 0.11403903365135193
# Epoch 1 batch_idx7 loss: 0.11945731192827225
# Epoch 1 batch_idx8 loss: 0.13488440215587616
# Epoch 1 batch_idx9 loss: 0.10515175759792328
# Epoch 1 batch_idx10 loss: 0.14447146654129028
# Epoch 1 batch_idx11 loss: 0.1617114543914795
# Epoch 1 batch_idx12 loss: 0.10994482785463333
# Epoch 1 batch_idx13 loss: 0.14407864212989807
# Epoch 1 batch_idx14 loss: 0.15810687839984894
# Epoch 1 batch_idx15 loss: 0.10002416372299194
# Epoch 1 batch_idx16 loss: 0.10884798318147659
# Epoch 1 batch_idx17 loss: 0.08829224109649658
# Epoch 1 batch_idx18 loss: 0.07629759609699249
# Epoch 1 batch_idx19 loss: 0.08521468937397003
# Epoch 1 batch_idx20 loss: 0.14177419245243073
# Epoch 1 batch_idx21 loss: 0.06881710886955261
# Epoch 1 batch_idx22 loss: 0.12673074007034302
# Epoch 1 batch_idx23 loss: 0.09519942104816437
# Epoch 1 batch_idx24 loss: 0.11166062206029892
# Epoch 1 batch_idx25 loss: 0.10415010154247284
# Epoch 1 batch_idx26 loss: 0.13800887763500214
# Epoch 1 batch_idx27 loss: 0.11047886312007904
# Epoch 1 batch_idx28 loss: 0.060442931950092316
# Epoch 1 batch_idx29 loss: 0.10331794619560242
# Epoch 1 batch_idx30 loss: 0.09281358867883682
# Epoch 1 batch_idx31 loss: 0.10181858390569687
# Epoch 1 batch_idx32 loss: 0.1443016231060028
# Epoch 1 batch_idx33 loss: 0.08407200127840042
# Epoch 1 batch_idx34 loss: 0.0958644300699234
# Epoch 1 batch_idx35 loss: 0.08274617791175842
# Epoch 1 batch_idx36 loss: 0.10088181495666504
# Epoch 1 batch_idx37 loss: 0.06955919414758682
# Epoch 1 batch_idx38 loss: 0.09211809188127518
# Epoch 1 batch_idx39 loss: 0.0751943364739418
# Epoch 1 batch_idx40 loss: 0.08730688691139221
# Epoch 1 batch_idx41 loss: 0.09150637686252594
# Epoch 1 batch_idx42 loss: 0.0780366063117981
# Epoch 1 batch_idx43 loss: 0.13075947761535645
# Epoch 1 batch_idx44 loss: 0.09764357656240463
# Epoch 1 batch_idx45 loss: 0.09731064736843109
# Epoch 1 batch_idx46 loss: 0.09850343316793442
# Epoch 1 batch_idx47 loss: 0.08069699257612228
# Epoch 1 batch_idx48 loss: 0.0727321207523346
# Epoch 1 batch_idx269 loss: 0.057462427765131
# Epoch 1 batch_idx270 loss: 0.06132429093122482
# Epoch 1 batch_idx271 loss: 0.08766229450702667
# Epoch 1 batch_idx272 loss: 0.0840822234749794
# Epoch 1 batch_idx273 loss: 0.06149208918213844
# Epoch 1 batch_idx274 loss: 0.04238424450159073
# Epoch 1 batch_idx275 loss: 0.06468535214662552
# Epoch 1 batch_idx276 loss: 0.06479315459728241
# Epoch 1 batch_idx277 loss: 0.06851553171873093
# Epoch 1 batch_idx278 loss: 0.07229139655828476
# Epoch 1, Loss: 22.3512
# Sample Index: 5764, Predicted Mean: tensor([[0.5230]]), Target Value: 0.6063611818854938, difference: tensor([[-0.0833]])
# Sample Index: 1024, Predicted Mean: tensor([[0.3772]]), Target Value: 0.6767650734145579, difference: tensor([[-0.2995]])
# Sample Index: 7048, Predicted Mean: tensor([[0.4698]]), Target Value: 0.4261127072004866, difference: tensor([[0.0437]])
# Sample Index: 7432, Predicted Mean: tensor([[0.6002]]), Target Value: 0.6368923637863633, difference: tensor([[-0.0367]])
# Sample Index: 5627, Predicted Mean: tensor([[0.1665]]), Target Value: 0.0835170136024229, difference: tensor([[0.0830]])
# Sample Index: 4217, Predicted Mean: tensor([[0.4743]]), Target Value: 0.2855180082867339, difference: tensor([[0.1888]])
# Sample Index: 8395, Predicted Mean: tensor([[0.1838]]), Target Value: 0.0, difference: tensor([[0.1838]])
# Sample Index: 6333, Predicted Mean: tensor([[0.5350]]), Target Value: 0.0, difference: tensor([[0.5350]])
# Sample Index: 6429, Predicted Mean: tensor([[0.5817]]), Target Value: 0.7098282200972615, difference: tensor([[-0.1282]])
# Sample Index: 670, Predicted Mean: tensor([[0.5304]]), Target Value: 0.4460813193145306, difference: tensor([[0.0843]])
# Sample Index: 6857, Predicted Mean: tensor([[0.5352]]), Target Value: 0.0, difference: tensor([[0.5352]])
# Sample Index: 387, Predicted Mean: tensor([[0.4460]]), Target Value: 0.0855891606755972, difference: tensor([[0.3604]])
# Sample Index: 1678, Predicted Mean: tensor([[0.5757]]), Target Value: 0.0, difference: tensor([[0.5757]])
# Sample Index: 10, Predicted Mean: tensor([[0.7447]]), Target Value: 0.8229300148255805, difference: tensor([[-0.0782]])
# Sample Index: 4322, Predicted Mean: tensor([[0.2209]]), Target Value: 0.2629729969355568, difference: tensor([[-0.0421]])
# Sample Index: 7889, Predicted Mean: tensor([[0.7119]]), Target Value: 0.7558891433423118, difference: tensor([[-0.0439]])
# Sample Index: 149, Predicted Mean: tensor([[0.1532]]), Target Value: 0.0619155727207767, difference: tensor([[0.0913]])
# Sample Index: 5170, Predicted Mean: tensor([[0.7100]]), Target Value: 0.2383099864580668, difference: tensor([[0.4717]])
# Sample Index: 7007, Predicted Mean: tensor([[0.4004]]), Target Value: 0.2176607586423408, difference: tensor([[0.1828]])
# Sample Index: 3769, Predicted Mean: tensor([[0.3018]]), Target Value: 0.0861946488721036, difference: tensor([[0.2156]])
# Sample Index: 3895, Predicted Mean: tensor([[0.7138]]), Target Value: 0.9481563208807255, difference: tensor([[-0.2344]])
# Sample Index: 8573, Predicted Mean: tensor([[0.4832]]), Target Value: 0.0, difference: tensor([[0.4832]])
# Sample Index: 8420, Predicted Mean: tensor([[0.5114]]), Target Value: 0.4240637354334165, difference: tensor([[0.0873]])
# Sample Index: 5883, Predicted Mean: tensor([[0.7251]]), Target Value: 0.7570411959553043, difference: tensor([[-0.0320]])
# Sample Index: 7245, Predicted Mean: tensor([[0.4890]]), Target Value: 0.4173571637012285, difference: tensor([[0.0716]])
# Sample Index: 3965, Predicted Mean: tensor([[0.5320]]), Target Value: 0.941500354995261, difference: tensor([[-0.4095]])
# Sample Index: 544, Predicted Mean: tensor([[0.1462]]), Target Value: 0.1095357917570498, difference: tensor([[0.0366]])
# Sample Index: 6130, Predicted Mean: tensor([[0.8619]]), Target Value: 0.7884420110050118, difference: tensor([[0.0735]])
# Sample Index: 5790, Predicted Mean: tensor([[0.7266]]), Target Value: 0.7308455431412618, difference: tensor([[-0.0042]])
# Sample Index: 5601, Predicted Mean: tensor([[0.5653]]), Target Value: 0.6840976877433641, difference: tensor([[-0.1188]])
# Sample Index: 3210, Predicted Mean: tensor([[0.5075]]), Target Value: 0.1874811625103256, difference: tensor([[0.3200]])
# Sample Index: 3909, Predicted Mean: tensor([[0.7954]]), Target Value: 0.9479327579054786, difference: tensor([[-0.1525]])
# Sample Index: 578, Predicted Mean: tensor([[0.4707]]), Target Value: 0.0, difference: tensor([[0.4707]])
# Sample Index: 2056, Predicted Mean: tensor([[0.8439]]), Target Value: 0.7929200853632888, difference: tensor([[0.0510]])
# Sample Index: 5471, Predicted Mean: tensor([[0.1492]]), Target Value: 0.0034469030967451, difference: tensor([[0.1458]])
# Sample Index: 1604, Predicted Mean: tensor([[0.6088]]), Target Value: 0.0, difference: tensor([[0.6088]])
# Sample Index: 5944, Predicted Mean: tensor([[0.7122]]), Target Value: 0.709734670572092, difference: tensor([[0.0025]])
# Sample Index: 6284, Predicted Mean: tensor([[0.1848]]), Target Value: 0.0331737109513544, difference: tensor([[0.1516]])
# Sample Index: 8328, Predicted Mean: tensor([[0.5324]]), Target Value: 0.2314076670083857, difference: tensor([[0.3010]])
# Sample Index: 8849, Predicted Mean: tensor([[0.3179]]), Target Value: 0.0, difference: tensor([[0.3179]])
# Sample Index: 4142, Predicted Mean: tensor([[0.5366]]), Target Value: 0.6303454915131331, difference: tensor([[-0.0938]])
# Sample Index: 1590, Predicted Mean: tensor([[0.0771]]), Target Value: 0.0, difference: tensor([[0.0771]])
# Sample Index: 3718, Predicted Mean: tensor([[0.7280]]), Target Value: 0.7966945536241975, difference: tensor([[-0.0687]])
# Sample Index: 5486, Predicted Mean: tensor([[0.5013]]), Target Value: 0.8923168132323483, difference: tensor([[-0.3910]])
# Sample Index: 3580, Predicted Mean: tensor([[0.2758]]), Target Value: 0.027025002492435, difference: tensor([[0.2488]])
# Sample Index: 7717, Predicted Mean: tensor([[0.7331]]), Target Value: 0.5792839706464308, difference: tensor([[0.1538]])
# Epoch 2 batch_idx267 loss: 0.034000251442193985
# Epoch 2 batch_idx268 loss: 0.030364584177732468
# Epoch 2 batch_idx269 loss: 0.03656560555100441
# Epoch 2 batch_idx270 loss: 0.05658882111310959
# Epoch 2 batch_idx271 loss: 0.025137536227703094
# Epoch 2 batch_idx272 loss: 0.022886285558342934
# Epoch 2 batch_idx273 loss: 0.07944506406784058
# Epoch 2 batch_idx274 loss: 0.03740233927965164
# Epoch 2 batch_idx275 loss: 0.054512906819581985
# Epoch 2 batch_idx276 loss: 0.0433523990213871
# Epoch 2 batch_idx277 loss: 0.05316096916794777
# Epoch 2 batch_idx278 loss: 0.046022679656744
# Epoch 2, Loss: 14.0478
# Sample Index: 3915, Predicted Mean: tensor([[0.8759]]), Target Value: 0.9481661306591253, difference: tensor([[-0.0723]])
# Sample Index: 4285, Predicted Mean: tensor([[0.3214]]), Target Value: 0.412094560675726, difference: tensor([[-0.0907]])
# Sample Index: 5848, Predicted Mean: tensor([[0.5279]]), Target Value: 0.6083846540555906, difference: tensor([[-0.0805]])
# Sample Index: 8727, Predicted Mean: tensor([[0.8284]]), Target Value: 0.6746152290307932, difference: tensor([[0.1538]])
# Sample Index: 657, Predicted Mean: tensor([[0.5830]]), Target Value: 0.5644030168020079, difference: tensor([[0.0186]])
# Sample Index: 7928, Predicted Mean: tensor([[0.7469]]), Target Value: 0.7352417556982491, difference: tensor([[0.0117]])
# Sample Index: 5115, Predicted Mean: tensor([[0.2460]]), Target Value: 0.0, difference: tensor([[0.2460]])
# Sample Index: 6479, Predicted Mean: tensor([[0.1579]]), Target Value: 0.0, difference: tensor([[0.1579]])
# Sample Index: 4263, Predicted Mean: tensor([[0.3064]]), Target Value: 0.3784965122290515, difference: tensor([[-0.0721]])
# Sample Index: 8509, Predicted Mean: tensor([[0.2856]]), Target Value: 0.6157965414431757, difference: tensor([[-0.3302]])
# Sample Index: 3619, Predicted Mean: tensor([[0.0605]]), Target Value: 0.0611378476298146, difference: tensor([[-0.0007]])
# Sample Index: 1866, Predicted Mean: tensor([[0.1926]]), Target Value: 0.0171022672572095, difference: tensor([[0.1755]])
# Sample Index: 3392, Predicted Mean: tensor([[0.3574]]), Target Value: 0.3132702440222366, difference: tensor([[0.0442]])
# Sample Index: 6223, Predicted Mean: tensor([[0.8619]]), Target Value: 0.8170959396937151, difference: tensor([[0.0448]])
# Sample Index: 7952, Predicted Mean: tensor([[0.1337]]), Target Value: 0.0, difference: tensor([[0.1337]])
# Sample Index: 4147, Predicted Mean: tensor([[0.6995]]), Target Value: 0.6988127294407779, difference: tensor([[0.0007]])
# Sample Index: 2444, Predicted Mean: tensor([[0.2921]]), Target Value: 0.4357133000323957, difference: tensor([[-0.1436]])
# Sample Index: 7272, Predicted Mean: tensor([[0.5546]]), Target Value: 0.3894074466817096, difference: tensor([[0.1652]])
# Sample Index: 248, Predicted Mean: tensor([[0.7487]]), Target Value: 0.6500431596151156, difference: tensor([[0.0987]])
# Sample Index: 2790, Predicted Mean: tensor([[0.8110]]), Target Value: 0.7459758953959023, difference: tensor([[0.0650]])
# Sample Index: 1356, Predicted Mean: tensor([[0.2163]]), Target Value: 0.6065229797175656, difference: tensor([[-0.3903]])
# Sample Index: 1222, Predicted Mean: tensor([[0.6238]]), Target Value: 0.666786507865373, difference: tensor([[-0.0430]])
# Sample Index: 4354, Predicted Mean: tensor([[0.2437]]), Target Value: 0.3626352612456281, difference: tensor([[-0.1189]])
# Sample Index: 8376, Predicted Mean: tensor([[0.2870]]), Target Value: 0.0, difference: tensor([[0.2870]])
# Sample Index: 7807, Predicted Mean: tensor([[0.3519]]), Target Value: 0.4700494807479982, difference: tensor([[-0.1181]])
# Sample Index: 7137, Predicted Mean: tensor([[0.5135]]), Target Value: 0.3404153805474381, difference: tensor([[0.1731]])
# Sample Index: 5989, Predicted Mean: tensor([[0.7047]]), Target Value: 0.6745845042560106, difference: tensor([[0.0301]])
# Sample Index: 543, Predicted Mean: tensor([[0.1703]]), Target Value: 0.0, difference: tensor([[0.1703]])
# Sample Index: 4341, Predicted Mean: tensor([[0.3660]]), Target Value: 0.4642444161948457, difference: tensor([[-0.0983]])
# Sample Index: 8469, Predicted Mean: tensor([[0.0661]]), Target Value: 0.0, difference: tensor([[0.0661]])
# Sample Index: 7730, Predicted Mean: tensor([[0.0306]]), Target Value: 0.0904900528631145, difference: tensor([[-0.0599]])
# Sample Index: 5160, Predicted Mean: tensor([[0.1898]]), Target Value: 0.0009774870931806, difference: tensor([[0.1888]])
# Sample Index: 364, Predicted Mean: tensor([[0.2921]]), Target Value: 0.4040319862000811, difference: tensor([[-0.1119]])
# Sample Index: 3981, Predicted Mean: tensor([[0.1097]]), Target Value: 0.011626649331476, difference: tensor([[0.0981]])
# Sample Index: 3462, Predicted Mean: tensor([[0.4236]]), Target Value: 0.1200685487021822, difference: tensor([[0.3035]])
# Sample Index: 5668, Predicted Mean: tensor([[0.4465]]), Target Value: 0.7431159383433923, difference: tensor([[-0.2966]])
# Sample Index: 7071, Predicted Mean: tensor([[0.6710]]), Target Value: 0.4664447896929617, difference: tensor([[0.2046]])
# Sample Index: 3014, Predicted Mean: tensor([[0.2444]]), Target Value: 0.2858347881394075, difference: tensor([[-0.0414]])
# Sample Index: 2894, Predicted Mean: tensor([[0.0477]]), Target Value: 0.1147465814687591, difference: tensor([[-0.0670]])
# Sample Index: 7697, Predicted Mean: tensor([[0.3525]]), Target Value: 0.5468354940332286, difference: tensor([[-0.1944]])
# Sample Index: 3255, Predicted Mean: tensor([[0.3203]]), Target Value: 0.0, difference: tensor([[0.3203]])
# Sample Index: 2095, Predicted Mean: tensor([[0.3915]]), Target Value: 0.0, difference: tensor([[0.3915]])
# Sample Index: 1612, Predicted Mean: tensor([[0.2998]]), Target Value: 0.0, difference: tensor([[0.2998]])
# Sample Index: 2239, Predicted Mean: tensor([[0.0410]]), Target Value: 0.1163266529433092, difference: tensor([[-0.0753]])
# Sample Index: 5636, Predicted Mean: tensor([[0.4867]]), Target Value: 0.6024263998470952, difference: tensor([[-0.1158]])
# Sample Index: 8640, Predicted Mean: tensor([[0.3097]]), Target Value: 0.0229021717278818, difference: tensor([[0.2868]])
# Sample Index: 6428, Predicted Mean: tensor([[0.7211]]), Target Value: 0.7456332533165905, difference: tensor([[-0.0246]])
# Sample Index: 1770, Predicted Mean: tensor([[0.8866]]), Target Value: 0.7565220804670649, difference: tensor([[0.1301]])
# Sample Index: 4372, Predicted Mean: tensor([[0.2605]]), Target Value: 0.1773951137640515, difference: tensor([[0.0831]])
# Sample Index: 7273, Predicted Mean: tensor([[0.4882]]), Target Value: 0.3759242590514707, difference: tensor([[0.1122]])
# the number of samples < 0.1: 23
# Epoch 3 batch_idx0 loss: 0.047682490199804306
# Epoch 3 batch_idx1 loss: 0.026999251917004585
# Epoch 3 batch_idx2 loss: 0.07440339773893356
# Epoch 3 batch_idx3 loss: 0.025910699740052223
# Epoch 3 batch_idx4 loss: 0.017920641228556633
# Epoch 3 batch_idx5 loss: 0.03419717773795128
# Epoch 3 batch_idx6 loss: 0.05142974853515625
# Epoch 3 batch_idx7 loss: 0.02469317801296711
# Epoch 3 batch_idx8 loss: 0.06112051382660866
# Epoch 3 batch_idx9 loss: 0.03385008126497269
# Epoch 3 batch_idx10 loss: 0.034686509519815445
# Epoch 3 batch_idx11 loss: 0.0397375151515007
# Epoch 3 batch_idx12 loss: 0.020946696400642395
# Epoch 3 batch_idx13 loss: 0.033022746443748474
# Epoch 3 batch_idx14 loss: 0.03347083181142807
# Epoch 3 batch_idx15 loss: 0.06436796486377716
# Epoch 3 batch_idx16 loss: 0.031218431890010834
# Epoch 3 batch_idx17 loss: 0.04221443831920624
# Epoch 3 batch_idx18 loss: 0.03631224483251572
# Epoch 3 batch_idx19 loss: 0.046803250908851624
# Epoch 3 batch_idx20 loss: 0.03876727819442749
# Epoch 3 batch_idx21 loss: 0.027966957539319992
# Epoch 3 batch_idx22 loss: 0.021119873970746994
# Epoch 3 batch_idx23 loss: 0.07910666614770889
# Epoch 3 batch_idx24 loss: 0.021922703832387924
# Epoch 3 batch_idx25 loss: 0.017267806455492973
# Epoch 3 batch_idx26 loss: 0.029834140092134476
# Epoch 3 batch_idx27 loss: 0.043802231550216675
# Epoch 3 batch_idx28 loss: 0.04327165707945824
# Epoch 3 batch_idx29 loss: 0.026402050629258156
# Epoch 3 batch_idx30 loss: 0.06487999111413956
# Epoch 3 batch_idx31 loss: 0.0904155746102333
# Epoch 3 batch_idx32 loss: 0.061168354004621506
# Epoch 3 batch_idx33 loss: 0.052487947046756744
# Epoch 3 batch_idx34 loss: 0.040802791714668274
# Epoch 3 batch_idx35 loss: 0.0442902073264122
# Epoch 3 batch_idx36 loss: 0.05787883326411247
# Epoch 3 batch_idx37 loss: 0.06439431011676788
# Epoch 3 batch_idx38 loss: 0.04977843910455704
# Epoch 3 batch_idx39 loss: 0.04356294125318527
# Epoch 3 batch_idx40 loss: 0.03376570716500282
# Epoch 3 batch_idx41 loss: 0.06692122668027878
# Epoch 3 batch_idx42 loss: 0.07176878303289413
# Epoch 3 batch_idx43 loss: 0.03128048777580261
# Sample Index: 4303, Predicted Mean: tensor([[0.0031]]), Target Value: 0.1010067457710933, difference: tensor([[-0.0979]])
# Sample Index: 2417, Predicted Mean: tensor([[0.2836]]), Target Value: 0.2717270907235316, difference: tensor([[0.0119]])
# Sample Index: 1230, Predicted Mean: tensor([[0.4943]]), Target Value: 0.515133435092446, difference: tensor([[-0.0209]])
# Sample Index: 649, Predicted Mean: tensor([[0.6160]]), Target Value: 0.6241746281087814, difference: tensor([[-0.0082]])
# Sample Index: 3956, Predicted Mean: tensor([[0.9329]]), Target Value: 0.9482613542405328, difference: tensor([[-0.0153]])
# Sample Index: 2101, Predicted Mean: tensor([[0.4365]]), Target Value: 0.5717670762167779, difference: tensor([[-0.1353]])
# Sample Index: 1155, Predicted Mean: tensor([[0.0897]]), Target Value: 0.0, difference: tensor([[0.0897]])
# Sample Index: 287, Predicted Mean: tensor([[0.0983]]), Target Value: 0.1932316623773735, difference: tensor([[-0.0950]])
# Sample Index: 2244, Predicted Mean: tensor([[0.0525]]), Target Value: 0.0033650978374015, difference: tensor([[0.0492]])
# Sample Index: 2009, Predicted Mean: tensor([[0.8027]]), Target Value: 0.7249763081849574, difference: tensor([[0.0777]])
# Sample Index: 8495, Predicted Mean: tensor([[0.2276]]), Target Value: 0.3218130396119603, difference: tensor([[-0.0942]])
# Sample Index: 2085, Predicted Mean: tensor([[0.8873]]), Target Value: 0.8483820279584567, difference: tensor([[0.0389]])
# Sample Index: 4786, Predicted Mean: tensor([[0.0049]]), Target Value: 0.0, difference: tensor([[0.0049]])
# Sample Index: 6853, Predicted Mean: tensor([[2.4862e-05]]), Target Value: 0.0, difference: tensor([[2.4862e-05]])
# Sample Index: 7996, Predicted Mean: tensor([[0.0641]]), Target Value: 0.0115520028937146, difference: tensor([[0.0525]])
# Sample Index: 384, Predicted Mean: tensor([[0.0470]]), Target Value: 0.1682801118916992, difference: tensor([[-0.1213]])
# Sample Index: 2742, Predicted Mean: tensor([[0.0031]]), Target Value: 0.0815452671401327, difference: tensor([[-0.0784]])
# Sample Index: 8879, Predicted Mean: tensor([[0.9547]]), Target Value: 0.9259338489709164, difference: tensor([[0.0287]])
# Sample Index: 2389, Predicted Mean: tensor([[0.1875]]), Target Value: 0.233386269325478, difference: tensor([[-0.0459]])
# Sample Index: 3788, Predicted Mean: tensor([[0.9156]]), Target Value: 0.9478334104681831, difference: tensor([[-0.0322]])
# Sample Index: 1921, Predicted Mean: tensor([[0.8705]]), Target Value: 0.8464364312351942, difference: tensor([[0.0240]])
# Sample Index: 2482, Predicted Mean: tensor([[0.1138]]), Target Value: 0.2241613842892536, difference: tensor([[-0.1103]])
# Sample Index: 4671, Predicted Mean: tensor([[0.7049]]), Target Value: 0.8098602121554351, difference: tensor([[-0.1050]])
# Sample Index: 7935, Predicted Mean: tensor([[0.5265]]), Target Value: 0.6783834550176024, difference: tensor([[-0.1519]])
# Sample Index: 8029, Predicted Mean: tensor([[0.3262]]), Target Value: 0.6165629387897873, difference: tensor([[-0.2903]])
# Sample Index: 7546, Predicted Mean: tensor([[0.6895]]), Target Value: 0.636418758716222, difference: tensor([[0.0531]])
# Sample Index: 5066, Predicted Mean: tensor([[0.9162]]), Target Value: 0.9910714170751108, difference: tensor([[-0.0749]])
# Sample Index: 6712, Predicted Mean: tensor([[0.0007]]), Target Value: 0.0, difference: tensor([[0.0007]])
# Sample Index: 7368, Predicted Mean: tensor([[0.8106]]), Target Value: 0.828764168396255, difference: tensor([[-0.0181]])
# Sample Index: 3006, Predicted Mean: tensor([[0.5999]]), Target Value: 0.532306729689407, difference: tensor([[0.0676]])
# Sample Index: 209, Predicted Mean: tensor([[0.6466]]), Target Value: 0.5446609991680961, difference: tensor([[0.1020]])
# Sample Index: 7011, Predicted Mean: tensor([[0.0298]]), Target Value: 0.0343421154606512, difference: tensor([[-0.0046]])
# Sample Index: 7984, Predicted Mean: tensor([[0.0129]]), Target Value: 0.000719453771617, difference: tensor([[0.0122]])
# Sample Index: 8022, Predicted Mean: tensor([[0.0485]]), Target Value: 0.3391469305458806, difference: tensor([[-0.2907]])
# Sample Index: 6685, Predicted Mean: tensor([[0.0087]]), Target Value: 0.0, difference: tensor([[0.0087]])
# Sample Index: 5627, Predicted Mean: tensor([[0.0134]]), Target Value: 0.0835170136024229, difference: tensor([[-0.0701]])
# Sample Index: 6143, Predicted Mean: tensor([[0.6539]]), Target Value: 0.7689062065430193, difference: tensor([[-0.1150]])
# Sample Index: 4946, Predicted Mean: tensor([[0.0035]]), Target Value: 0.0014648623099722, difference: tensor([[0.0020]])
# Sample Index: 5034, Predicted Mean: tensor([[0.9332]]), Target Value: 0.9866891127517268, difference: tensor([[-0.0535]])
# Sample Index: 6463, Predicted Mean: tensor([[0.7301]]), Target Value: 0.7516792831259648, difference: tensor([[-0.0215]])
# Sample Index: 6168, Predicted Mean: tensor([[0.1378]]), Target Value: 0.1610155093322977, difference: tensor([[-0.0232]])
# Sample Index: 582, Predicted Mean: tensor([[0.0865]]), Target Value: 0.0, difference: tensor([[0.0865]])
# Sample Index: 8623, Predicted Mean: tensor([[0.2710]]), Target Value: 0.0, difference: tensor([[0.2710]])
# Sample Index: 4402, Predicted Mean: tensor([[0.8594]]), Target Value: 0.9304633715335544, difference: tensor([[-0.0711]])
# Sample Index: 2320, Predicted Mean: tensor([[0.1198]]), Target Value: 0.2582350573435144, difference: tensor([[-0.1385]])
# the number of samples < 0.1: 38
# Early stopping triggered.

# %%
diff_list=[]
for idx in range(8928):
    sample_batch = sql_graphs_pyg[idx]
    sample_x = sample_batch.x
    sample_edge_attr = sample_batch.edge_attr
    sample_edge_index = sample_batch.edge_index
    sample_configuration_vector= sample_batch.configuration_vector

    # 获取对应的 target 值
    target_value = label_list[idx]
    model.eval()
    with torch.no_grad():
        with gpytorch.settings.num_likelihood_samples(32):
            pred_mean = model.predict(sample_x, sample_edge_attr, sample_edge_index, sample_configuration_vector, sample_batch.batch)
    print(
            f'Sample Index: {idx}, Predicted Mean: {pred_mean}, Target Value: {target_value}, difference: {pred_mean-target_value}')
    diff_list.append(pred_mean-target_value)
# Out:
# Sample Index: 0, Predicted Mean: tensor([[0.3120]]), Target Value: 0.7762723471220767, difference: tensor([[-0.4642]])
# Sample Index: 1, Predicted Mean: tensor([[0.6867]]), Target Value: 0.8062924517534559, difference: tensor([[-0.1196]])
# Sample Index: 2, Predicted Mean: tensor([[0.5278]]), Target Value: 0.7784686092591014, difference: tensor([[-0.2507]])
# Sample Index: 3, Predicted Mean: tensor([[0.4803]]), Target Value: 0.7749570081760407, difference: tensor([[-0.2947]])
# Sample Index: 4, Predicted Mean: tensor([[0.5195]]), Target Value: 0.7777587391149067, difference: tensor([[-0.2582]])
# Sample Index: 5, Predicted Mean: tensor([[0.6870]]), Target Value: 0.8174958364803653, difference: tensor([[-0.1305]])
# Sample Index: 6, Predicted Mean: tensor([[0.6678]]), Target Value: 0.8145510698040941, difference: tensor([[-0.1467]])
# Sample Index: 7, Predicted Mean: tensor([[0.7050]]), Target Value: 0.813642424222763, difference: tensor([[-0.1087]])
# Sample Index: 8, Predicted Mean: tensor([[0.7164]]), Target Value: 0.8187984939074149, difference: tensor([[-0.1024]])
# Sample Index: 9, Predicted Mean: tensor([[0.6922]]), Target Value: 0.8155673608372871, difference: tensor([[-0.1234]])
# Sample Index: 10, Predicted Mean: tensor([[0.7137]]), Target Value: 0.8229300148255805, difference: tensor([[-0.1092]])
# Sample Index: 11, Predicted Mean: tensor([[0.7296]]), Target Value: 0.8136194205371596, difference: tensor([[-0.0840]])
# Sample Index: 12, Predicted Mean: tensor([[0.7108]]), Target Value: 0.8158967854118884, difference: tensor([[-0.1051]])
# Sample Index: 13, Predicted Mean: tensor([[0.7421]]), Target Value: 0.8177715857885589, difference: tensor([[-0.0756]])
# Sample Index: 14, Predicted Mean: tensor([[0.7160]]), Target Value: 0.817915801202149, difference: tensor([[-0.1019]])
# Sample Index: 15, Predicted Mean: tensor([[0.0023]]), Target Value: 0.0707631708634137, difference: tensor([[-0.0684]])
# Sample Index: 16, Predicted Mean: tensor([[0.0041]]), Target Value: 0.1312708268143936, difference: tensor([[-0.1272]])
# Sample Index: 17, Predicted Mean: tensor([[0.0016]]), Target Value: 0.0965756654627088, difference: tensor([[-0.0949]])
# Sample Index: 18, Predicted Mean: tensor([[0.3733]]), Target Value: 0.7784081508546311, difference: tensor([[-0.4051]])
# Sample Index: 19, Predicted Mean: tensor([[0.0011]]), Target Value: 0.0701143489617817, difference: tensor([[-0.0690]])
# Sample Index: 20, Predicted Mean: tensor([[0.0026]]), Target Value: 0.0920725465463357, difference: tensor([[-0.0895]])
# Sample Index: 21, Predicted Mean: tensor([[0.6580]]), Target Value: 0.8105484285091165, difference: tensor([[-0.1525]])
# Sample Index: 22, Predicted Mean: tensor([[0.4197]]), Target Value: 0.7776446054440286, difference: tensor([[-0.3579]])
# Sample Index: 23, Predicted Mean: tensor([[0.2954]]), Target Value: 0.7748045350291572, difference: tensor([[-0.4794]])
# Sample Index: 24, Predicted Mean: tensor([[0.3302]]), Target Value: 0.7773541101835252, difference: tensor([[-0.4471]])
# Sample Index: 25, Predicted Mean: tensor([[0.6489]]), Target Value: 0.8210903098154072, difference: tensor([[-0.1722]])
# Sample Index: 26, Predicted Mean: tensor([[0.6667]]), Target Value: 0.8143475756622186, difference: tensor([[-0.1477]])
# Sample Index: 27, Predicted Mean: tensor([[0.6692]]), Target Value: 0.8178175931597655, difference: tensor([[-0.1486]])
# Sample Index: 28, Predicted Mean: tensor([[0.6667]]), Target Value: 0.8207859533597325, difference: tensor([[-0.1541]])
# Sample Index: 29, Predicted Mean: tensor([[0.6739]]), Target Value: 0.8162335829626447, difference: tensor([[-0.1423]])
# Sample Index: 30, Predicted Mean: tensor([[0.6832]]), Target Value: 0.8161162051822586, difference: tensor([[-0.1329]])
# Sample Index: 31, Predicted Mean: tensor([[0.0149]]), Target Value: 0.1273289388429323, difference: tensor([[-0.1125]])
# Sample Index: 32, Predicted Mean: tensor([[0.0117]]), Target Value: 0.0197616405284831, difference: tensor([[-0.0081]])
# Sample Index: 33, Predicted Mean: tensor([[0.6417]]), Target Value: 0.818504459618357, difference: tensor([[-0.1768]])
# Sample Index: 34, Predicted Mean: tensor([[0.0081]]), Target Value: 0.1415440368695995, difference: tensor([[-0.1334]])
# Sample Index: 35, Predicted Mean: tensor([[0.0142]]), Target Value: 0.1362304804142787, difference: tensor([[-0.1220]])
# Sample Index: 36, Predicted Mean: tensor([[0.6385]]), Target Value: 0.818579369056091, difference: tensor([[-0.1801]])
# Sample Index: 37, Predicted Mean: tensor([[0.6581]]), Target Value: 0.8132973689387132, difference: tensor([[-0.1552]])
# Sample Index: 38, Predicted Mean: tensor([[0.6596]]), Target Value: 0.8227681042692186, difference: tensor([[-0.1631]])
# Sample Index: 39, Predicted Mean: tensor([[0.6566]]), Target Value: 0.8219800805777818, difference: tensor([[-0.1654]])
# Sample Index: 40, Predicted Mean: tensor([[0.6842]]), Target Value: 0.8134109127714988, difference: tensor([[-0.1292]])
# Sample Index: 41, Predicted Mean: tensor([[0.6781]]), Target Value: 0.8214934641515577, difference: tensor([[-0.1434]])
# Sample Index: 42, Predicted Mean: tensor([[0.0074]]), Target Value: 0.0766202631208746, difference: tensor([[-0.0692]])
# Sample Index: 43, Predicted Mean: tensor([[0.4493]]), Target Value: 0.7736463879347438, difference: tensor([[-0.3244]])
# Sample Index: 44, Predicted Mean: tensor([[0.0029]]), Target Value: 0.0897423911623379, difference: tensor([[-0.0868]])
# Sample Index: 45, Predicted Mean: tensor([[0.0078]]), Target Value: 0.0796576343776514, difference: tensor([[-0.0718]])
# Sample Index: 46, Predicted Mean: tensor([[0.4585]]), Target Value: 0.7715683883352439, difference: tensor([[-0.3131]])
# Sample Index: 47, Predicted Mean: tensor([[0.5267]]), Target Value: 0.779455998225767, difference: tensor([[-0.2528]])
# Sample Index: 48, Predicted Mean: tensor([[0.6355]]), Target Value: 0.8180010328064997, difference: tensor([[-0.1825]])
# Sample Index: 49, Predicted Mean: tensor([[0.4436]]), Target Value: 0.772985769271264, difference: tensor([[-0.3294]])
# Sample Index: 50, Predicted Mean: tensor([[0.4565]]), Target Value: 0.7750773351468888, difference: tensor([[-0.3186]])
# Sample Index: 51, Predicted Mean: tensor([[0.4849]]), Target Value: 0.7756978448200862, difference: tensor([[-0.2908]])
# Sample Index: 52, Predicted Mean: tensor([[0.0048]]), Target Value: 0.0988848815944267, difference: tensor([[-0.0940]])
# Sample Index: 53, Predicted Mean: tensor([[0.0052]]), Target Value: 0.0446911475034659, difference: tensor([[-0.0395]])
# Sample Index: 54, Predicted Mean: tensor([[0.5007]]), Target Value: 0.77603405253275, difference: tensor([[-0.2754]])
# Sample Index: 55, Predicted Mean: tensor([[0.0102]]), Target Value: 0.078275643727175, difference: tensor([[-0.0681]])
# Sample Index: 56, Predicted Mean: tensor([[0.0990]]), Target Value: 0.1722298143719394, difference: tensor([[-0.0732]])
# Sample Index: 57, Predicted Mean: tensor([[0.1150]]), Target Value: 0.1995384095425975, difference: tensor([[-0.0845]])
# Sample Index: 58, Predicted Mean: tensor([[0.1154]]), Target Value: 0.1897162495270213, difference: tensor([[-0.0743]])
# Sample Index: 59, Predicted Mean: tensor([[0.1296]]), Target Value: 0.1630806616925841, difference: tensor([[-0.0334]])
# Sample Index: 60, Predicted Mean: tensor([[0.0159]]), Target Value: 0.0650436609835752, difference: tensor([[-0.0491]])
# Sample Index: 61, Predicted Mean: tensor([[0.0200]]), Target Value: 0.0599277766144645, difference: tensor([[-0.0399]])
# Sample Index: 62, Predicted Mean: tensor([[0.0170]]), Target Value: 0.0847504325688529, difference: tensor([[-0.0678]])
# Sample Index: 63, Predicted Mean: tensor([[0.4201]]), Target Value: 0.1105308774463144, difference: tensor([[0.3095]])
# Sample Index: 64, Predicted Mean: tensor([[0.5654]]), Target Value: 0.2295873767166034, difference: tensor([[0.3358]])
# Sample Index: 65, Predicted Mean: tensor([[0.4561]]), Target Value: 0.0474570247261122, difference: tensor([[0.4087]])
# Sample Index: 66, Predicted Mean: tensor([[0.4201]]), Target Value: 0.0573345939449143, difference: tensor([[0.3627]])
# Sample Index: 67, Predicted Mean: tensor([[0.5171]]), Target Value: 0.0717809047140453, difference: tensor([[0.4453]])
# Sample Index: 68, Predicted Mean: tensor([[0.3861]]), Target Value: 0.1142036412662655, difference: tensor([[0.2719]])
# Sample Index: 69, Predicted Mean: tensor([[0.4074]]), Target Value: 0.0491968389650286, difference: tensor([[0.3582]])
# Sample Index: 70, Predicted Mean: tensor([[0.4182]]), Target Value: 0.0722805027477891, difference: tensor([[0.3459]])
# Sample Index: 71, Predicted Mean: tensor([[0.2712]]), Target Value: 0.0309005906323506, difference: tensor([[0.2403]])
# Sample Index: 72, Predicted Mean: tensor([[0.5654]]), Target Value: 0.1967639455156154, difference: tensor([[0.3686]])
# Sample Index: 73, Predicted Mean: tensor([[0.4561]]), Target Value: 0.053756003556244, difference: tensor([[0.4024]])
# Sample Index: 74, Predicted Mean: tensor([[0.5171]]), Target Value: 0.1855227237297361, difference: tensor([[0.3316]])
# Sample Index: 75, Predicted Mean: tensor([[0.3861]]), Target Value: 0.0688439705859662, difference: tensor([[0.3172]])
# Sample Index: 76, Predicted Mean: tensor([[0.4074]]), Target Value: 0.0651983414835028, difference: tensor([[0.3422]])
# Sample Index: 77, Predicted Mean: tensor([[0.4182]]), Target Value: 0.0544716152233213, difference: tensor([[0.3637]])
# Sample Index: 78, Predicted Mean: tensor([[0.2712]]), Target Value: 0.0474474477669989, difference: tensor([[0.2237]])
# Sample Index: 79, Predicted Mean: tensor([[0.5720]]), Target Value: 0.2585438446489538, difference: tensor([[0.3135]])
# Sample Index: 80, Predicted Mean: tensor([[0.5976]]), Target Value: 0.2644001551467376, difference: tensor([[0.3332]])
# Sample Index: 81, Predicted Mean: tensor([[0.5768]]), Target Value: 0.2256038937787541, difference: tensor([[0.3512]])
# Sample Index: 82, Predicted Mean: tensor([[0.5042]]), Target Value: 0.2161658005725957, difference: tensor([[0.2880]])
# Sample Index: 83, Predicted Mean: tensor([[0.5979]]), Target Value: 0.2760771285722722, difference: tensor([[0.3218]])
# Sample Index: 84, Predicted Mean: tensor([[0.5308]]), Target Value: 0.2228350884884418, difference: tensor([[0.3080]])
# Sample Index: 85, Predicted Mean: tensor([[0.6148]]), Target Value: 0.2916295781189894, difference: tensor([[0.3232]])
# Sample Index: 86, Predicted Mean: tensor([[0.6142]]), Target Value: 0.2908527803242439, difference: tensor([[0.3234]])
# Sample Index: 87, Predicted Mean: tensor([[0.6124]]), Target Value: 0.3358389495991244, difference: tensor([[0.2766]])
# Sample Index: 88, Predicted Mean: tensor([[0.5980]]), Target Value: 0.2781202131831098, difference: tensor([[0.3198]])
# Sample Index: 89, Predicted Mean: tensor([[0.6139]]), Target Value: 0.27432348094797, difference: tensor([[0.3396]])
# Sample Index: 90, Predicted Mean: tensor([[0.6151]]), Target Value: 0.2879483014464932, difference: tensor([[0.3271]])
# Sample Index: 91, Predicted Mean: tensor([[0.6003]]), Target Value: 0.34226774943057, difference: tensor([[0.2580]])
# Sample Index: 92, Predicted Mean: tensor([[0.6047]]), Target Value: 0.2757030951135694, difference: tensor([[0.3290]])
# Sample Index: 93, Predicted Mean: tensor([[0.6137]]), Target Value: 0.2924760748939485, difference: tensor([[0.3213]])
# Sample Index: 94, Predicted Mean: tensor([[0.6160]]), Target Value: 0.2918588930844246, difference: tensor([[0.3241]])
# Sample Index: 95, Predicted Mean: tensor([[0.6016]]), Target Value: 0.2975758056217814, difference: tensor([[0.3040]])
# Sample Index: 96, Predicted Mean: tensor([[0.6074]]), Target Value: 0.2954401437395151, difference: tensor([[0.3120]])
# Sample Index: 97, Predicted Mean: tensor([[0.6113]]), Target Value: 0.2661756169556868, difference: tensor([[0.3451]])
# Sample Index: 98, Predicted Mean: tensor([[0.5989]]), Target Value: 0.3507577236845115, difference: tensor([[0.2482]])
# Sample Index: 99, Predicted Mean: tensor([[0.6000]]), Target Value: 0.2860291852508445, difference: tensor([[0.3139]])
# Sample Index: 100, Predicted Mean: tensor([[0.0104]]), Target Value: 0.0220232815876044, difference: tensor([[-0.0116]])
# Sample Index: 101, Predicted Mean: tensor([[0.5243]]), Target Value: 0.3006680993088095, difference: tensor([[0.2236]])
# Sample Index: 102, Predicted Mean: tensor([[0.0104]]), Target Value: 0.1157168008061671, difference: tensor([[-0.1053]])
# Sample Index: 103, Predicted Mean: tensor([[0.4528]]), Target Value: 0.1553526422564167, difference: tensor([[0.2974]])
# Sample Index: 104, Predicted Mean: tensor([[0.0094]]), Target Value: 0.0650110587275094, difference: tensor([[-0.0556]])
# Sample Index: 105, Predicted Mean: tensor([[0.0186]]), Target Value: 0.0547881869273443, difference: tensor([[-0.0362]])
# Sample Index: 106, Predicted Mean: tensor([[0.0120]]), Target Value: 0.049832642639495, difference: tensor([[-0.0378]])
# Sample Index: 107, Predicted Mean: tensor([[0.0028]]), Target Value: 0.034605277649346, difference: tensor([[-0.0318]])
# Sample Index: 108, Predicted Mean: tensor([[0.5243]]), Target Value: 0.2971730412857387, difference: tensor([[0.2271]])
# Sample Index: 109, Predicted Mean: tensor([[0.4528]]), Target Value: 0.1764538755027238, difference: tensor([[0.2763]])
# Sample Index: 110, Predicted Mean: tensor([[0.0094]]), Target Value: 0.1023947186262809, difference: tensor([[-0.0930]])
# Sample Index: 111, Predicted Mean: tensor([[0.0186]]), Target Value: 0.0615058916920411, difference: tensor([[-0.0429]])
# Sample Index: 112, Predicted Mean: tensor([[0.0120]]), Target Value: 0.0498874441277544, difference: tensor([[-0.0379]])
# Sample Index: 113, Predicted Mean: tensor([[0.0028]]), Target Value: 0.0221280960845666, difference: tensor([[-0.0193]])
# Sample Index: 114, Predicted Mean: tensor([[0.5824]]), Target Value: 0.3466444197453486, difference: tensor([[0.2358]])
# Sample Index: 115, Predicted Mean: tensor([[0.5468]]), Target Value: 0.2955082465598765, difference: tensor([[0.2512]])
# Sample Index: 116, Predicted Mean: tensor([[0.5294]]), Target Value: 0.2798089503067553, difference: tensor([[0.2496]])
# Sample Index: 117, Predicted Mean: tensor([[0.5735]]), Target Value: 0.3081141850194013, difference: tensor([[0.2654]])
# Sample Index: 118, Predicted Mean: tensor([[0.4982]]), Target Value: 0.3047691660224388, difference: tensor([[0.1934]])
# Sample Index: 119, Predicted Mean: tensor([[0.5953]]), Target Value: 0.3600319444791757, difference: tensor([[0.2353]])
# Sample Index: 120, Predicted Mean: tensor([[0.5886]]), Target Value: 0.3280507536268742, difference: tensor([[0.2606]])
# Sample Index: 121, Predicted Mean: tensor([[0.6034]]), Target Value: 0.3518590739825411, difference: tensor([[0.2515]])
# Sample Index: 122, Predicted Mean: tensor([[0.5840]]), Target Value: 0.3516297590171061, difference: tensor([[0.2324]])
# Sample Index: 123, Predicted Mean: tensor([[0.5949]]), Target Value: 0.335446294275479, difference: tensor([[0.2595]])
# Sample Index: 124, Predicted Mean: tensor([[0.6114]]), Target Value: 0.3558446851335268, difference: tensor([[0.2555]])
# Sample Index: 125, Predicted Mean: tensor([[0.5924]]), Target Value: 0.322117827456184, difference: tensor([[0.2703]])
# Sample Index: 126, Predicted Mean: tensor([[0.6037]]), Target Value: 0.3489843900886986, difference: tensor([[0.2547]])
# Sample Index: 127, Predicted Mean: tensor([[0.6079]]), Target Value: 0.2893396207843423, difference: tensor([[0.3185]])
# Sample Index: 128, Predicted Mean: tensor([[0.6042]]), Target Value: 0.2703251005181666, difference: tensor([[0.3339]])
# Sample Index: 129, Predicted Mean: tensor([[0.4923]]), Target Value: 0.2666980932806458, difference: tensor([[0.2256]])
# Sample Index: 130, Predicted Mean: tensor([[0.4923]]), Target Value: 0.2991027985470688, difference: tensor([[0.1932]])
# Sample Index: 131, Predicted Mean: tensor([[0.5781]]), Target Value: 0.3417426128391906, difference: tensor([[0.2364]])
# Sample Index: 132, Predicted Mean: tensor([[0.5078]]), Target Value: 0.2995481271458373, difference: tensor([[0.2082]])
# Sample Index: 133, Predicted Mean: tensor([[0.4606]]), Target Value: 0.2958226900507631, difference: tensor([[0.1648]])
# Sample Index: 134, Predicted Mean: tensor([[0.5642]]), Target Value: 0.2912555446602866, difference: tensor([[0.2730]])
# Sample Index: 135, Predicted Mean: tensor([[0.4503]]), Target Value: 0.2882606167242437, difference: tensor([[0.1620]])
# Sample Index: 136, Predicted Mean: tensor([[0.5781]]), Target Value: 0.353682952640341, difference: tensor([[0.2244]])
# Sample Index: 137, Predicted Mean: tensor([[0.5078]]), Target Value: 0.286040890423094, difference: tensor([[0.2217]])
# Sample Index: 138, Predicted Mean: tensor([[0.4606]]), Target Value: 0.2992331516016666, difference: tensor([[0.1614]])
# Sample Index: 139, Predicted Mean: tensor([[0.5642]]), Target Value: 0.2597335157921395, difference: tensor([[0.3045]])
# Sample Index: 140, Predicted Mean: tensor([[0.4503]]), Target Value: 0.3058263558978903, difference: tensor([[0.1445]])
# Sample Index: 141, Predicted Mean: tensor([[0.5926]]), Target Value: 0.3516973297841832, difference: tensor([[0.2409]])
# Sample Index: 142, Predicted Mean: tensor([[0.5873]]), Target Value: 0.3623293505597998, difference: tensor([[0.2250]])
# Sample Index: 143, Predicted Mean: tensor([[0.5907]]), Target Value: 0.3544384683037237, difference: tensor([[0.2362]])
# Sample Index: 144, Predicted Mean: tensor([[0.5828]]), Target Value: 0.3472408514767937, difference: tensor([[0.2356]])
# Sample Index: 145, Predicted Mean: tensor([[0.5925]]), Target Value: 0.3526943976385347, difference: tensor([[0.2398]])
# Sample Index: 146, Predicted Mean: tensor([[0.6093]]), Target Value: 0.3455542425662845, difference: tensor([[0.2638]])
# Sample Index: 147, Predicted Mean: tensor([[0.5867]]), Target Value: 0.3696919039047922, difference: tensor([[0.2170]])
# Sample Index: 148, Predicted Mean: tensor([[0.4597]]), Target Value: 0.0289490191863734, difference: tensor([[0.4307]])
# Sample Index: 149, Predicted Mean: tensor([[0.0087]]), Target Value: 0.0619155727207767, difference: tensor([[-0.0532]])
# Sample Index: 150, Predicted Mean: tensor([[0.0152]]), Target Value: 0.0642182993342417, difference: tensor([[-0.0490]])
# Sample Index: 151, Predicted Mean: tensor([[0.0151]]), Target Value: 0.0490308383403981, difference: tensor([[-0.0340]])
# Sample Index: 152, Predicted Mean: tensor([[0.0031]]), Target Value: 0.0285084790671615, difference: tensor([[-0.0254]])
# Sample Index: 153, Predicted Mean: tensor([[0.4597]]), Target Value: 0.172885926179735, difference: tensor([[0.2868]])
# Sample Index: 154, Predicted Mean: tensor([[0.4160]]), Target Value: 0.1688263596222634, difference: tensor([[0.2472]])
# Sample Index: 155, Predicted Mean: tensor([[0.4449]]), Target Value: 0.188120207862577, difference: tensor([[0.2568]])
# Sample Index: 156, Predicted Mean: tensor([[0.4256]]), Target Value: 0.1712195352940206, difference: tensor([[0.2544]])
# Sample Index: 157, Predicted Mean: tensor([[0.2770]]), Target Value: 0.1707891041872061, difference: tensor([[0.1063]])
# Sample Index: 158, Predicted Mean: tensor([[0.4160]]), Target Value: 0.1793828288315418, difference: tensor([[0.2366]])
# Sample Index: 159, Predicted Mean: tensor([[0.4449]]), Target Value: 0.1878057643716902, difference: tensor([[0.2571]])
# Sample Index: 160, Predicted Mean: tensor([[0.4256]]), Target Value: 0.1892497569846624, difference: tensor([[0.2364]])
# Sample Index: 161, Predicted Mean: tensor([[0.2770]]), Target Value: 0.1696723243439384, difference: tensor([[0.1074]])
# Sample Index: 162, Predicted Mean: tensor([[0.0087]]), Target Value: 0.0420556197862102, difference: tensor([[-0.0334]])
# Sample Index: 163, Predicted Mean: tensor([[0.0104]]), Target Value: 0.0544455446124017, difference: tensor([[-0.0441]])
# Sample Index: 164, Predicted Mean: tensor([[0.0111]]), Target Value: 0.0543327493161784, difference: tensor([[-0.0432]])
# Sample Index: 165, Predicted Mean: tensor([[0.0024]]), Target Value: 0.0950225883221752, difference: tensor([[-0.0927]])
# Sample Index: 166, Predicted Mean: tensor([[0.0104]]), Target Value: 0.048323207472582, difference: tensor([[-0.0380]])
# Sample Index: 167, Predicted Mean: tensor([[0.0111]]), Target Value: 0.0331724581553393, difference: tensor([[-0.0221]])
# Sample Index: 168, Predicted Mean: tensor([[0.0024]]), Target Value: 0.1038424356122417, difference: tensor([[-0.1015]])
# Sample Index: 169, Predicted Mean: tensor([[0.4788]]), Target Value: 0.2869198424483815, difference: tensor([[0.1919]])
# Sample Index: 170, Predicted Mean: tensor([[0.5743]]), Target Value: 0.3017364623032267, difference: tensor([[0.2725]])
# Sample Index: 171, Predicted Mean: tensor([[0.4619]]), Target Value: 0.3018790525833581, difference: tensor([[0.1600]])
# Sample Index: 172, Predicted Mean: tensor([[0.6130]]), Target Value: 0.3487774213611944, difference: tensor([[0.2643]])
# Sample Index: 173, Predicted Mean: tensor([[0.5869]]), Target Value: 0.3528981740463344, difference: tensor([[0.2340]])
# Sample Index: 174, Predicted Mean: tensor([[0.6167]]), Target Value: 0.3570088177190769, difference: tensor([[0.2597]])
# Sample Index: 175, Predicted Mean: tensor([[0.5866]]), Target Value: 0.3511578277541338, difference: tensor([[0.2354]])
# Sample Index: 176, Predicted Mean: tensor([[0.6054]]), Target Value: 0.3417910296880411, difference: tensor([[0.2636]])
# Sample Index: 177, Predicted Mean: tensor([[0.0152]]), Target Value: 0.0652137710287409, difference: tensor([[-0.0500]])
# Sample Index: 178, Predicted Mean: tensor([[0.0157]]), Target Value: 0.1055258522030464, difference: tensor([[-0.0898]])
# Sample Index: 179, Predicted Mean: tensor([[0.0053]]), Target Value: 0.0460593207488543, difference: tensor([[-0.0408]])
# Sample Index: 180, Predicted Mean: tensor([[0.0157]]), Target Value: 0.0455974984982796, difference: tensor([[-0.0299]])
# Sample Index: 181, Predicted Mean: tensor([[0.0053]]), Target Value: 0.0381056562052575, difference: tensor([[-0.0328]])
# Sample Index: 182, Predicted Mean: tensor([[0.5265]]), Target Value: 0.2205445991005107, difference: tensor([[0.3059]])
# Sample Index: 183, Predicted Mean: tensor([[0.3951]]), Target Value: 0.2934534567767893, difference: tensor([[0.1016]])
# Sample Index: 184, Predicted Mean: tensor([[0.0151]]), Target Value: 0.070056520020367, difference: tensor([[-0.0550]])
# Sample Index: 185, Predicted Mean: tensor([[0.0039]]), Target Value: 0.0340508781273427, difference: tensor([[-0.0302]])
# Sample Index: 186, Predicted Mean: tensor([[0.0039]]), Target Value: 0.1065032340858872, difference: tensor([[-0.1026]])
# Sample Index: 187, Predicted Mean: tensor([[0.5031]]), Target Value: 0.2938775032441949, difference: tensor([[0.2092]])
# Sample Index: 188, Predicted Mean: tensor([[0.5996]]), Target Value: 0.3565480595750703, difference: tensor([[0.2430]])
# Sample Index: 189, Predicted Mean: tensor([[0.6070]]), Target Value: 0.3524001721724427, difference: tensor([[0.2546]])
# Sample Index: 190, Predicted Mean: tensor([[0.0031]]), Target Value: 0.0491941786986083, difference: tensor([[-0.0461]])
# Sample Index: 191, Predicted Mean: tensor([[0.2160]]), Target Value: 0.1848057449220733, difference: tensor([[0.0312]])
# Sample Index: 192, Predicted Mean: tensor([[0.3514]]), Target Value: 0.1890004638048191, difference: tensor([[0.1624]])
# Sample Index: 193, Predicted Mean: tensor([[0.1724]]), Target Value: 0.202714684575913, difference: tensor([[-0.0303]])
# Sample Index: 194, Predicted Mean: tensor([[0.3599]]), Target Value: 0.2087733650880124, difference: tensor([[0.1511]])
# Sample Index: 195, Predicted Mean: tensor([[0.2583]]), Target Value: 0.190527844853607, difference: tensor([[0.0678]])
# Sample Index: 196, Predicted Mean: tensor([[0.2647]]), Target Value: 0.2044316366420531, difference: tensor([[0.0603]])
# Sample Index: 197, Predicted Mean: tensor([[0.2771]]), Target Value: 0.1927882031612347, difference: tensor([[0.0843]])
# Sample Index: 198, Predicted Mean: tensor([[0.6842]]), Target Value: 0.776212334263397, difference: tensor([[-0.0920]])
# Sample Index: 199, Predicted Mean: tensor([[0.6279]]), Target Value: 0.5468047160851929, difference: tensor([[0.0811]])
# Sample Index: 200, Predicted Mean: tensor([[0.6669]]), Target Value: 0.7461595764652184, difference: tensor([[-0.0793]])
# Sample Index: 201, Predicted Mean: tensor([[0.6386]]), Target Value: 0.7739949975337362, difference: tensor([[-0.1353]])
# Sample Index: 202, Predicted Mean: tensor([[0.7017]]), Target Value: 0.7787653313259665, difference: tensor([[-0.0770]])
# Sample Index: 203, Predicted Mean: tensor([[0.7118]]), Target Value: 0.782740571142506, difference: tensor([[-0.0709]])
# Sample Index: 204, Predicted Mean: tensor([[0.6781]]), Target Value: 0.7722741344150538, difference: tensor([[-0.0942]])
# Sample Index: 205, Predicted Mean: tensor([[0.6247]]), Target Value: 0.5184201372273306, difference: tensor([[0.1063]])
# Sample Index: 206, Predicted Mean: tensor([[0.6016]]), Target Value: 0.5601501476077242, difference: tensor([[0.0415]])
# Sample Index: 207, Predicted Mean: tensor([[0.6221]]), Target Value: 0.5427415926174052, difference: tensor([[0.0794]])
# Sample Index: 208, Predicted Mean: tensor([[0.6366]]), Target Value: 0.5390348350548099, difference: tensor([[0.0976]])
# Sample Index: 209, Predicted Mean: tensor([[0.6466]]), Target Value: 0.5446609991680961, difference: tensor([[0.1020]])
# Sample Index: 210, Predicted Mean: tensor([[0.5938]]), Target Value: 0.5489976662519418, difference: tensor([[0.0448]])
# Sample Index: 211, Predicted Mean: tensor([[0.6020]]), Target Value: 0.5507275017852804, difference: tensor([[0.0513]])
# Sample Index: 212, Predicted Mean: tensor([[0.6278]]), Target Value: 0.5320142656791796, difference: tensor([[0.0958]])
# Sample Index: 213, Predicted Mean: tensor([[0.5773]]), Target Value: 0.5275646381954311, difference: tensor([[0.0497]])
# Sample Index: 214, Predicted Mean: tensor([[0.6149]]), Target Value: 0.5562232207931799, difference: tensor([[0.0587]])
# Sample Index: 215, Predicted Mean: tensor([[0.6335]]), Target Value: 0.5547209164930467, difference: tensor([[0.0788]])
# Sample Index: 216, Predicted Mean: tensor([[0.6106]]), Target Value: 0.5629529919091826, difference: tensor([[0.0476]])
# Sample Index: 217, Predicted Mean: tensor([[0.5834]]), Target Value: 0.5653088259112292, difference: tensor([[0.0181]])
# Sample Index: 218, Predicted Mean: tensor([[0.6222]]), Target Value: 0.5616487709172292, difference: tensor([[0.0606]])
# Sample Index: 219, Predicted Mean: tensor([[0.6079]]), Target Value: 0.5380375166564826, difference: tensor([[0.0699]])
# Sample Index: 220, Predicted Mean: tensor([[0.0515]]), Target Value: 0.0358926494298145, difference: tensor([[0.0156]])
# Sample Index: 221, Predicted Mean: tensor([[0.1486]]), Target Value: 0.133443502315343, difference: tensor([[0.0151]])
# Sample Index: 222, Predicted Mean: tensor([[0.1445]]), Target Value: 0.0749415182613944, difference: tensor([[0.0695]])
# Sample Index: 223, Predicted Mean: tensor([[0.0589]]), Target Value: 0.0291573568278695, difference: tensor([[0.0297]])
# Sample Index: 224, Predicted Mean: tensor([[0.0783]]), Target Value: 0.0251273622757357, difference: tensor([[0.0532]])
# Sample Index: 225, Predicted Mean: tensor([[0.0695]]), Target Value: 0.0339479360685548, difference: tensor([[0.0356]])
# Sample Index: 226, Predicted Mean: tensor([[0.5907]]), Target Value: 0.5930460105423572, difference: tensor([[-0.0024]])
# Sample Index: 227, Predicted Mean: tensor([[0.6324]]), Target Value: 0.6854101175708407, difference: tensor([[-0.0530]])
# Sample Index: 228, Predicted Mean: tensor([[0.5470]]), Target Value: 0.5847184594318022, difference: tensor([[-0.0377]])
# Sample Index: 229, Predicted Mean: tensor([[0.6438]]), Target Value: 0.589704131175782, difference: tensor([[0.0541]])
# Sample Index: 230, Predicted Mean: tensor([[0.5959]]), Target Value: 0.5948165670345202, difference: tensor([[0.0011]])
# Sample Index: 231, Predicted Mean: tensor([[0.5898]]), Target Value: 0.5684429593692255, difference: tensor([[0.0214]])
# Sample Index: 232, Predicted Mean: tensor([[0.5804]]), Target Value: 0.6694405998542328, difference: tensor([[-0.0890]])
# Sample Index: 233, Predicted Mean: tensor([[0.6043]]), Target Value: 0.6873999230672958, difference: tensor([[-0.0831]])
# Sample Index: 234, Predicted Mean: tensor([[0.6308]]), Target Value: 0.690430528663874, difference: tensor([[-0.0596]])
# Sample Index: 235, Predicted Mean: tensor([[0.6563]]), Target Value: 0.6864999208587016, difference: tensor([[-0.0302]])
# Sample Index: 236, Predicted Mean: tensor([[0.6214]]), Target Value: 0.5452467368018081, difference: tensor([[0.0761]])
# Sample Index: 237, Predicted Mean: tensor([[0.6296]]), Target Value: 0.5477366968998697, difference: tensor([[0.0819]])
# Sample Index: 238, Predicted Mean: tensor([[0.6391]]), Target Value: 0.5373898923678341, difference: tensor([[0.1017]])
# Sample Index: 239, Predicted Mean: tensor([[0.5929]]), Target Value: 0.5395729498722696, difference: tensor([[0.0533]])
# Sample Index: 240, Predicted Mean: tensor([[0.5598]]), Target Value: 0.5501985894443913, difference: tensor([[0.0096]])
# Sample Index: 241, Predicted Mean: tensor([[0.6188]]), Target Value: 0.5546576494666244, difference: tensor([[0.0641]])
# Sample Index: 242, Predicted Mean: tensor([[0.1672]]), Target Value: 0.0204032709282721, difference: tensor([[0.1468]])
# Sample Index: 243, Predicted Mean: tensor([[0.3267]]), Target Value: 0.2284116801513623, difference: tensor([[0.0983]])
# Sample Index: 244, Predicted Mean: tensor([[0.2055]]), Target Value: 0.1145089466477217, difference: tensor([[0.0909]])
# Sample Index: 245, Predicted Mean: tensor([[0.2037]]), Target Value: 0.1396892231637378, difference: tensor([[0.0640]])
# Sample Index: 246, Predicted Mean: tensor([[0.2082]]), Target Value: 0.148604582465233, difference: tensor([[0.0596]])
# Sample Index: 247, Predicted Mean: tensor([[0.6334]]), Target Value: 0.683132274557729, difference: tensor([[-0.0497]])
# Sample Index: 248, Predicted Mean: tensor([[0.5980]]), Target Value: 0.6500431596151156, difference: tensor([[-0.0520]])
# Sample Index: 249, Predicted Mean: tensor([[0.6057]]), Target Value: 0.6827641754949092, difference: tensor([[-0.0771]])
# Sample Index: 250, Predicted Mean: tensor([[0.6312]]), Target Value: 0.6855628786819109, difference: tensor([[-0.0544]])
# Sample Index: 251, Predicted Mean: tensor([[0.6725]]), Target Value: 0.6887984694440968, difference: tensor([[-0.0163]])
# Sample Index: 252, Predicted Mean: tensor([[0.1683]]), Target Value: 0.0774294078022276, difference: tensor([[0.0909]])
# Sample Index: 253, Predicted Mean: tensor([[0.1885]]), Target Value: 0.1327477950866137, difference: tensor([[0.0557]])
# Sample Index: 254, Predicted Mean: tensor([[0.2017]]), Target Value: 0.0523986715304822, difference: tensor([[0.1493]])
# Sample Index: 255, Predicted Mean: tensor([[0.2076]]), Target Value: 0.1392507251551537, difference: tensor([[0.0684]])
# Sample Index: 256, Predicted Mean: tensor([[0.5717]]), Target Value: 0.6491479887067207, difference: tensor([[-0.0774]])
# Sample Index: 257, Predicted Mean: tensor([[0.6274]]), Target Value: 0.5673763923347052, difference: tensor([[0.0600]])
# Sample Index: 258, Predicted Mean: tensor([[0.5842]]), Target Value: 0.5753963506658912, difference: tensor([[0.0088]])
# Sample Index: 259, Predicted Mean: tensor([[0.5459]]), Target Value: 0.576105631547562, difference: tensor([[-0.0302]])
# Sample Index: 260, Predicted Mean: tensor([[0.6127]]), Target Value: 0.6711285641191758, difference: tensor([[-0.0585]])
# Sample Index: 261, Predicted Mean: tensor([[0.6056]]), Target Value: 0.6718912193649555, difference: tensor([[-0.0663]])
# Sample Index: 262, Predicted Mean: tensor([[0.5757]]), Target Value: 0.6773574904478292, difference: tensor([[-0.1016]])
# Sample Index: 263, Predicted Mean: tensor([[0.0691]]), Target Value: 0.0500743560106895, difference: tensor([[0.0190]])
# Sample Index: 264, Predicted Mean: tensor([[0.1017]]), Target Value: 0.0569955386393585, difference: tensor([[0.0447]])
# Sample Index: 265, Predicted Mean: tensor([[0.0987]]), Target Value: 0.0431011793893971, difference: tensor([[0.0556]])
# Sample Index: 266, Predicted Mean: tensor([[0.6743]]), Target Value: 0.587974065580529, difference: tensor([[0.0864]])
# Sample Index: 267, Predicted Mean: tensor([[0.6525]]), Target Value: 0.6822835761560151, difference: tensor([[-0.0297]])
# Sample Index: 268, Predicted Mean: tensor([[0.6690]]), Target Value: 0.58582482717749, difference: tensor([[0.0831]])
# Sample Index: 269, Predicted Mean: tensor([[0.6066]]), Target Value: 0.6970590725376014, difference: tensor([[-0.0904]])
# Sample Index: 270, Predicted Mean: tensor([[0.6498]]), Target Value: 0.6923609781864495, difference: tensor([[-0.0425]])
# Sample Index: 271, Predicted Mean: tensor([[0.6286]]), Target Value: 0.5499772698828709, difference: tensor([[0.0786]])
# Sample Index: 272, Predicted Mean: tensor([[0.6442]]), Target Value: 0.5436241101205157, difference: tensor([[0.1006]])
# Sample Index: 273, Predicted Mean: tensor([[0.5962]]), Target Value: 0.5546965299301347, difference: tensor([[0.0415]])
# Sample Index: 274, Predicted Mean: tensor([[0.0900]]), Target Value: 0.0486454414612059, difference: tensor([[0.0413]])
# Sample Index: 275, Predicted Mean: tensor([[0.1240]]), Target Value: 0.1267815994640477, difference: tensor([[-0.0027]])
# Sample Index: 276, Predicted Mean: tensor([[0.6170]]), Target Value: 0.5857657012655245, difference: tensor([[0.0312]])
# Sample Index: 277, Predicted Mean: tensor([[0.5924]]), Target Value: 0.6015863689236047, difference: tensor([[-0.0092]])
# Sample Index: 278, Predicted Mean: tensor([[0.6621]]), Target Value: 0.7004950472271096, difference: tensor([[-0.0384]])
# Sample Index: 279, Predicted Mean: tensor([[0.6642]]), Target Value: 0.5400542393969064, difference: tensor([[0.1241]])
# Sample Index: 280, Predicted Mean: tensor([[0.0909]]), Target Value: 0.0504185286344261, difference: tensor([[0.0405]])
# Sample Index: 281, Predicted Mean: tensor([[0.6114]]), Target Value: 0.6699929785103768, difference: tensor([[-0.0586]])
# Sample Index: 282, Predicted Mean: tensor([[0.6302]]), Target Value: 0.5874548158400389, difference: tensor([[0.0427]])
# Sample Index: 283, Predicted Mean: tensor([[0.0530]]), Target Value: 0.0340277297435249, difference: tensor([[0.0189]])
# Sample Index: 284, Predicted Mean: tensor([[0.0797]]), Target Value: 0.1971027593790026, difference: tensor([[-0.1174]])
# Sample Index: 285, Predicted Mean: tensor([[0.0414]]), Target Value: 0.0624199484330763, difference: tensor([[-0.0210]])
# Sample Index: 286, Predicted Mean: tensor([[0.1133]]), Target Value: 0.2153867161505602, difference: tensor([[-0.1021]])
# Sample Index: 287, Predicted Mean: tensor([[0.0983]]), Target Value: 0.1932316623773735, difference: tensor([[-0.0950]])
# Sample Index: 288, Predicted Mean: tensor([[0.1269]]), Target Value: 0.2132633371575224, difference: tensor([[-0.0864]])
# Sample Index: 289, Predicted Mean: tensor([[0.0530]]), Target Value: 0.0856137346426213, difference: tensor([[-0.0326]])
# Sample Index: 290, Predicted Mean: tensor([[0.1133]]), Target Value: 0.170006272942153, difference: tensor([[-0.0567]])
# Sample Index: 291, Predicted Mean: tensor([[0.0567]]), Target Value: 0.0710058889331467, difference: tensor([[-0.0143]])
# Sample Index: 292, Predicted Mean: tensor([[0.0567]]), Target Value: 0.0689630087224902, difference: tensor([[-0.0123]])
# Sample Index: 293, Predicted Mean: tensor([[0.0797]]), Target Value: 0.2101375992520172, difference: tensor([[-0.1305]])
# Sample Index: 294, Predicted Mean: tensor([[0.0983]]), Target Value: 0.2126909013716992, difference: tensor([[-0.1144]])
# Sample Index: 295, Predicted Mean: tensor([[0.0414]]), Target Value: 0.0620746980997517, difference: tensor([[-0.0207]])
# Sample Index: 296, Predicted Mean: tensor([[0.1220]]), Target Value: 0.0086368096903729, difference: tensor([[0.1133]])
# Sample Index: 297, Predicted Mean: tensor([[0.1931]]), Target Value: 0.0067195254350213, difference: tensor([[0.1864]])
# Sample Index: 298, Predicted Mean: tensor([[0.0879]]), Target Value: 0.0, difference: tensor([[0.0879]])
# Sample Index: 299, Predicted Mean: tensor([[0.0865]]), Target Value: 0.0, difference: tensor([[0.0865]])
# Sample Index: 300, Predicted Mean: tensor([[0.4022]]), Target Value: 0.8601658810095743, difference: tensor([[-0.4579]])
# Sample Index: 301, Predicted Mean: tensor([[0.7147]]), Target Value: 0.8603091655980527, difference: tensor([[-0.1457]])
# Sample Index: 302, Predicted Mean: tensor([[0.5487]]), Target Value: 0.8617793377201697, difference: tensor([[-0.3130]])
# Sample Index: 303, Predicted Mean: tensor([[0.6543]]), Target Value: 0.8604673004099865, difference: tensor([[-0.2062]])
# Sample Index: 304, Predicted Mean: tensor([[0.9135]]), Target Value: 0.996141751403246, difference: tensor([[-0.0826]])
# Sample Index: 305, Predicted Mean: tensor([[0.7877]]), Target Value: 0.8577099751359096, difference: tensor([[-0.0700]])
# Sample Index: 306, Predicted Mean: tensor([[0.9431]]), Target Value: 0.9947426195392818, difference: tensor([[-0.0517]])
# Sample Index: 307, Predicted Mean: tensor([[0.2320]]), Target Value: 0.1539651100020268, difference: tensor([[0.0780]])
# Sample Index: 308, Predicted Mean: tensor([[0.2630]]), Target Value: 0.1580172142184868, difference: tensor([[0.1050]])
# Sample Index: 309, Predicted Mean: tensor([[0.2358]]), Target Value: 0.1700206097020122, difference: tensor([[0.0658]])
# Sample Index: 310, Predicted Mean: tensor([[0.7103]]), Target Value: 0.8586680152274994, difference: tensor([[-0.1484]])
# Sample Index: 311, Predicted Mean: tensor([[0.7917]]), Target Value: 0.8584797786112633, difference: tensor([[-0.0667]])
# Sample Index: 312, Predicted Mean: tensor([[0.9270]]), Target Value: 0.9954718859181751, difference: tensor([[-0.0685]])
# Sample Index: 313, Predicted Mean: tensor([[0.9554]]), Target Value: 0.9955850687023512, difference: tensor([[-0.0401]])
# Sample Index: 314, Predicted Mean: tensor([[0.0360]]), Target Value: 0.015644911089304, difference: tensor([[0.0203]])
# Sample Index: 315, Predicted Mean: tensor([[0.0343]]), Target Value: 0.0, difference: tensor([[0.0343]])
# Sample Index: 316, Predicted Mean: tensor([[0.5407]]), Target Value: 0.8531650040436757, difference: tensor([[-0.3125]])
# Sample Index: 317, Predicted Mean: tensor([[0.8271]]), Target Value: 0.8597520815397675, difference: tensor([[-0.0327]])
# Sample Index: 318, Predicted Mean: tensor([[0.0681]]), Target Value: 0.0, difference: tensor([[0.0681]])
# Sample Index: 319, Predicted Mean: tensor([[0.6825]]), Target Value: 0.8596336811095124, difference: tensor([[-0.1771]])
# Sample Index: 320, Predicted Mean: tensor([[0.4261]]), Target Value: 0.8562534491650764, difference: tensor([[-0.4301]])
# Sample Index: 321, Predicted Mean: tensor([[0.1509]]), Target Value: 0.4010263973892122, difference: tensor([[-0.2501]])
# Sample Index: 322, Predicted Mean: tensor([[0.1593]]), Target Value: 0.4177896329387809, difference: tensor([[-0.2585]])
# Sample Index: 323, Predicted Mean: tensor([[0.3035]]), Target Value: 0.4169218095768908, difference: tensor([[-0.1135]])
# Sample Index: 324, Predicted Mean: tensor([[0.2457]]), Target Value: 0.2824834312520847, difference: tensor([[-0.0368]])
# Sample Index: 325, Predicted Mean: tensor([[0.1509]]), Target Value: 0.3390049124556985, difference: tensor([[-0.1881]])
# Sample Index: 326, Predicted Mean: tensor([[0.1976]]), Target Value: 0.4008516249397443, difference: tensor([[-0.2033]])
# Sample Index: 327, Predicted Mean: tensor([[0.1147]]), Target Value: 0.415953456533701, difference: tensor([[-0.3012]])
# Sample Index: 328, Predicted Mean: tensor([[0.1593]]), Target Value: 0.407016616526156, difference: tensor([[-0.2477]])
# Sample Index: 329, Predicted Mean: tensor([[0.3035]]), Target Value: 0.3939594804995508, difference: tensor([[-0.0905]])
# Sample Index: 330, Predicted Mean: tensor([[0.2457]]), Target Value: 0.2721405966205686, difference: tensor([[-0.0265]])
# Sample Index: 331, Predicted Mean: tensor([[0.1976]]), Target Value: 0.3983611175348275, difference: tensor([[-0.2008]])
# Sample Index: 332, Predicted Mean: tensor([[0.1147]]), Target Value: 0.4080993531643227, difference: tensor([[-0.2934]])
# Sample Index: 333, Predicted Mean: tensor([[0.2836]]), Target Value: 0.2655447127959365, difference: tensor([[0.0181]])
# Sample Index: 334, Predicted Mean: tensor([[0.1877]]), Target Value: 0.2837064831698038, difference: tensor([[-0.0960]])
# Sample Index: 335, Predicted Mean: tensor([[0.2633]]), Target Value: 0.2807435217856345, difference: tensor([[-0.0174]])
# Sample Index: 336, Predicted Mean: tensor([[0.2591]]), Target Value: 0.2787958036140243, difference: tensor([[-0.0197]])
# Sample Index: 337, Predicted Mean: tensor([[0.2274]]), Target Value: 0.2843117926289363, difference: tensor([[-0.0569]])
# Sample Index: 338, Predicted Mean: tensor([[0.2210]]), Target Value: 0.2841114437234489, difference: tensor([[-0.0631]])
# Sample Index: 339, Predicted Mean: tensor([[0.1977]]), Target Value: 0.2960350454284038, difference: tensor([[-0.0983]])
# Sample Index: 340, Predicted Mean: tensor([[0.2433]]), Target Value: 0.2827576676971846, difference: tensor([[-0.0394]])
# Sample Index: 341, Predicted Mean: tensor([[0.2353]]), Target Value: 0.2877511155064723, difference: tensor([[-0.0524]])
# Sample Index: 342, Predicted Mean: tensor([[0.2466]]), Target Value: 0.2933306904328779, difference: tensor([[-0.0468]])
# Sample Index: 343, Predicted Mean: tensor([[0.0117]]), Target Value: 0.0, difference: tensor([[0.0117]])
# Sample Index: 344, Predicted Mean: tensor([[0.1321]]), Target Value: 0.3458903075533313, difference: tensor([[-0.2138]])
# Sample Index: 345, Predicted Mean: tensor([[0.2151]]), Target Value: 0.3874570217851016, difference: tensor([[-0.1724]])
# Sample Index: 346, Predicted Mean: tensor([[0.0117]]), Target Value: 0.0196920949923785, difference: tensor([[-0.0080]])
# Sample Index: 347, Predicted Mean: tensor([[0.0084]]), Target Value: 0.0089432341215499, difference: tensor([[-0.0005]])
# Sample Index: 348, Predicted Mean: tensor([[0.0134]]), Target Value: 0.022341034333195, difference: tensor([[-0.0089]])
# Sample Index: 349, Predicted Mean: tensor([[0.1321]]), Target Value: 0.327383610251754, difference: tensor([[-0.1953]])
# Sample Index: 350, Predicted Mean: tensor([[0.2151]]), Target Value: 0.3801769677619429, difference: tensor([[-0.1651]])
# Sample Index: 351, Predicted Mean: tensor([[0.0084]]), Target Value: 0.001397469138631, difference: tensor([[0.0070]])
# Sample Index: 352, Predicted Mean: tensor([[0.0134]]), Target Value: 0.0689026172884765, difference: tensor([[-0.0555]])
# Sample Index: 353, Predicted Mean: tensor([[0.2639]]), Target Value: 0.4034639757393106, difference: tensor([[-0.1396]])
# Sample Index: 354, Predicted Mean: tensor([[0.2253]]), Target Value: 0.4247627694897035, difference: tensor([[-0.1994]])
# Sample Index: 355, Predicted Mean: tensor([[0.1623]]), Target Value: 0.4275914544797695, difference: tensor([[-0.2653]])
# Sample Index: 356, Predicted Mean: tensor([[0.2605]]), Target Value: 0.27439736363575, difference: tensor([[-0.0139]])
# Sample Index: 357, Predicted Mean: tensor([[0.2888]]), Target Value: 0.3108910588617269, difference: tensor([[-0.0221]])
# Sample Index: 358, Predicted Mean: tensor([[0.2294]]), Target Value: 0.3086133333617515, difference: tensor([[-0.0792]])
# Sample Index: 359, Predicted Mean: tensor([[0.2156]]), Target Value: 0.3735260235111572, difference: tensor([[-0.1580]])
# Sample Index: 360, Predicted Mean: tensor([[0.2175]]), Target Value: 0.3858329168278516, difference: tensor([[-0.1683]])
# Sample Index: 361, Predicted Mean: tensor([[0.2156]]), Target Value: 0.3829793658388775, difference: tensor([[-0.1674]])
# Sample Index: 362, Predicted Mean: tensor([[0.1841]]), Target Value: 0.3673930024947701, difference: tensor([[-0.1833]])
# Sample Index: 363, Predicted Mean: tensor([[0.1431]]), Target Value: 0.3565894364263439, difference: tensor([[-0.2135]])
# Sample Index: 364, Predicted Mean: tensor([[0.2175]]), Target Value: 0.4040319862000811, difference: tensor([[-0.1865]])
# Sample Index: 365, Predicted Mean: tensor([[0.1841]]), Target Value: 0.3287071918507727, difference: tensor([[-0.1446]])
# Sample Index: 366, Predicted Mean: tensor([[0.1431]]), Target Value: 0.3473105113195355, difference: tensor([[-0.2042]])
# Sample Index: 367, Predicted Mean: tensor([[0.2406]]), Target Value: 0.4279342500361445, difference: tensor([[-0.1873]])
# Sample Index: 368, Predicted Mean: tensor([[0.2390]]), Target Value: 0.4430641446860117, difference: tensor([[-0.2040]])
# Sample Index: 369, Predicted Mean: tensor([[0.2358]]), Target Value: 0.4327237966543864, difference: tensor([[-0.1969]])
# Sample Index: 370, Predicted Mean: tensor([[0.2358]]), Target Value: 0.3966716505233049, difference: tensor([[-0.1609]])
# Sample Index: 371, Predicted Mean: tensor([[0.2603]]), Target Value: 0.3569087868980341, difference: tensor([[-0.0966]])
# Sample Index: 372, Predicted Mean: tensor([[0.2143]]), Target Value: 0.3847381024187867, difference: tensor([[-0.1705]])
# Sample Index: 373, Predicted Mean: tensor([[0.2603]]), Target Value: 0.41645006605475, difference: tensor([[-0.1561]])
# Sample Index: 374, Predicted Mean: tensor([[0.2143]]), Target Value: 0.4166315878467785, difference: tensor([[-0.2023]])
# Sample Index: 375, Predicted Mean: tensor([[0.0184]]), Target Value: 0.0033320438536757, difference: tensor([[0.0151]])
# Sample Index: 376, Predicted Mean: tensor([[0.0372]]), Target Value: 0.0477039979908273, difference: tensor([[-0.0105]])
# Sample Index: 377, Predicted Mean: tensor([[0.0184]]), Target Value: 0.0985727271855348, difference: tensor([[-0.0802]])
# Sample Index: 378, Predicted Mean: tensor([[0.0217]]), Target Value: 0.0967354850947874, difference: tensor([[-0.0751]])
# Sample Index: 379, Predicted Mean: tensor([[0.0217]]), Target Value: 0.0271923907201512, difference: tensor([[-0.0055]])
# Sample Index: 380, Predicted Mean: tensor([[0.2210]]), Target Value: 0.382544210857987, difference: tensor([[-0.1615]])
# Sample Index: 381, Predicted Mean: tensor([[0.2810]]), Target Value: 0.2613888939212934, difference: tensor([[0.0196]])
# Sample Index: 382, Predicted Mean: tensor([[0.0372]]), Target Value: 0.102954471421685, difference: tensor([[-0.0657]])
# Sample Index: 383, Predicted Mean: tensor([[0.0659]]), Target Value: 0.1410745765954606, difference: tensor([[-0.0752]])
# Sample Index: 384, Predicted Mean: tensor([[0.0470]]), Target Value: 0.1682801118916992, difference: tensor([[-0.1213]])
# Sample Index: 385, Predicted Mean: tensor([[0.0732]]), Target Value: 0.2095772314478328, difference: tensor([[-0.1364]])
# Sample Index: 386, Predicted Mean: tensor([[0.0573]]), Target Value: 0.0311465535275214, difference: tensor([[0.0262]])
# Sample Index: 387, Predicted Mean: tensor([[0.0561]]), Target Value: 0.0855891606755972, difference: tensor([[-0.0295]])
# Sample Index: 388, Predicted Mean: tensor([[0.0373]]), Target Value: 0.148200786942184, difference: tensor([[-0.1109]])
# Sample Index: 389, Predicted Mean: tensor([[0.2932]]), Target Value: 0.0, difference: tensor([[0.2932]])
# Sample Index: 390, Predicted Mean: tensor([[0.1590]]), Target Value: 0.4555476480562445, difference: tensor([[-0.2966]])
# Sample Index: 391, Predicted Mean: tensor([[0.0460]]), Target Value: 0.1086686632810422, difference: tensor([[-0.0626]])
# Sample Index: 392, Predicted Mean: tensor([[0.1511]]), Target Value: 0.4596242734766004, difference: tensor([[-0.3086]])
# Sample Index: 393, Predicted Mean: tensor([[0.3162]]), Target Value: 0.5990169004401452, difference: tensor([[-0.2828]])
# Sample Index: 394, Predicted Mean: tensor([[0.1351]]), Target Value: 0.4593961590577718, difference: tensor([[-0.3243]])
# Sample Index: 395, Predicted Mean: tensor([[0.1449]]), Target Value: 0.4659694284630029, difference: tensor([[-0.3211]])
# Sample Index: 396, Predicted Mean: tensor([[0.1330]]), Target Value: 0.4692923302045566, difference: tensor([[-0.3363]])
# Sample Index: 397, Predicted Mean: tensor([[0.3522]]), Target Value: 0.7387963758190307, difference: tensor([[-0.3866]])
# Sample Index: 398, Predicted Mean: tensor([[0.1247]]), Target Value: 0.4732459630580788, difference: tensor([[-0.3486]])
# Sample Index: 399, Predicted Mean: tensor([[0.3139]]), Target Value: 0.7470726192265764, difference: tensor([[-0.4331]])
# ...
# Sample Index: 8795, Predicted Mean: tensor([[0.6369]]), Target Value: 0.7002659909402799, difference: tensor([[-0.0633]])
# Sample Index: 8796, Predicted Mean: tensor([[0.1905]]), Target Value: 0.0627482931929979, difference: tensor([[0.1278]])
# Sample Index: 8797, Predicted Mean: tensor([[0.2170]]), Target Value: 0.2897335892748788, difference: tensor([[-0.0727]])
# Sample Index: 8798, Predicted Mean: tensor([[0.3833]]), Target Value: 0.4443880491071938, difference: tensor([[-0.0611]])
# Sample Index: 8799, Predicted Mean: tensor([[0.1505]]), Target Value: 0.2226901339113643, difference: tensor([[-0.0722]])
# Sample Index: 8800, Predicted Mean: tensor([[0.3061]]), Target Value: 0.3193897917889197, difference: tensor([[-0.0132]])
# Sample Index: 8801, Predicted Mean: tensor([[0.9257]]), Target Value: 0.9158186646151067, difference: tensor([[0.0098]])
# Sample Index: 8802, Predicted Mean: tensor([[0.3972]]), Target Value: 0.3623783440065472, difference: tensor([[0.0348]])
# Sample Index: 8803, Predicted Mean: tensor([[0.3232]]), Target Value: 0.3789936235479293, difference: tensor([[-0.0558]])
# Sample Index: 8804, Predicted Mean: tensor([[0.4333]]), Target Value: 0.3745895735490088, difference: tensor([[0.0587]])
# Sample Index: 8805, Predicted Mean: tensor([[0.4419]]), Target Value: 0.4347723691002118, difference: tensor([[0.0071]])
# Sample Index: 8806, Predicted Mean: tensor([[0.4237]]), Target Value: 0.4194288473125285, difference: tensor([[0.0043]])
# Sample Index: 8807, Predicted Mean: tensor([[0.4220]]), Target Value: 0.4044778433500611, difference: tensor([[0.0176]])
# Sample Index: 8808, Predicted Mean: tensor([[0.3209]]), Target Value: 0.3793527773580018, difference: tensor([[-0.0585]])
# Sample Index: 8809, Predicted Mean: tensor([[0.9353]]), Target Value: 0.9154673611615388, difference: tensor([[0.0198]])
# Sample Index: 8810, Predicted Mean: tensor([[0.9373]]), Target Value: 0.9112988218577476, difference: tensor([[0.0260]])
# Sample Index: 8811, Predicted Mean: tensor([[0.9376]]), Target Value: 0.9007675686072092, difference: tensor([[0.0369]])
# Sample Index: 8812, Predicted Mean: tensor([[0.8904]]), Target Value: 0.9160757637906232, difference: tensor([[-0.0257]])
# Sample Index: 8813, Predicted Mean: tensor([[0.9568]]), Target Value: 0.9072107487081256, difference: tensor([[0.0496]])
# Sample Index: 8814, Predicted Mean: tensor([[0.9657]]), Target Value: 0.91724350432064, difference: tensor([[0.0485]])
# Sample Index: 8815, Predicted Mean: tensor([[0.9103]]), Target Value: 0.9239908857360986, difference: tensor([[-0.0137]])
# Sample Index: 8816, Predicted Mean: tensor([[0.9199]]), Target Value: 0.9274038282263491, difference: tensor([[-0.0075]])
# Sample Index: 8817, Predicted Mean: tensor([[0.9415]]), Target Value: 0.9246974178214868, difference: tensor([[0.0168]])
# Sample Index: 8818, Predicted Mean: tensor([[0.9312]]), Target Value: 0.9215788637001476, difference: tensor([[0.0097]])
# Sample Index: 8819, Predicted Mean: tensor([[0.9238]]), Target Value: 0.922236331057384, difference: tensor([[0.0016]])
# Sample Index: 8820, Predicted Mean: tensor([[0.9248]]), Target Value: 0.925723851934426, difference: tensor([[-0.0009]])
# Sample Index: 8821, Predicted Mean: tensor([[0.9424]]), Target Value: 0.9255982462303568, difference: tensor([[0.0168]])
# Sample Index: 8822, Predicted Mean: tensor([[0.9512]]), Target Value: 0.9262517884093412, difference: tensor([[0.0249]])
# Sample Index: 8823, Predicted Mean: tensor([[0.9319]]), Target Value: 0.9262439380528368, difference: tensor([[0.0057]])
# Sample Index: 8824, Predicted Mean: tensor([[0.9269]]), Target Value: 0.9210587775817368, difference: tensor([[0.0058]])
# Sample Index: 8825, Predicted Mean: tensor([[0.9376]]), Target Value: 0.926420571074184, difference: tensor([[0.0111]])
# Sample Index: 8826, Predicted Mean: tensor([[0.9486]]), Target Value: 0.9250604968098112, difference: tensor([[0.0235]])
# Sample Index: 8827, Predicted Mean: tensor([[0.9548]]), Target Value: 0.9230135163513112, difference: tensor([[0.0318]])
# Sample Index: 8828, Predicted Mean: tensor([[0.9373]]), Target Value: 0.9228957610037466, difference: tensor([[0.0144]])
# Sample Index: 8829, Predicted Mean: tensor([[0.9433]]), Target Value: 0.9185780649263734, difference: tensor([[0.0247]])
# Sample Index: 8830, Predicted Mean: tensor([[0.9553]]), Target Value: 0.9249643299426336, difference: tensor([[0.0304]])
# Sample Index: 8831, Predicted Mean: tensor([[0.9603]]), Target Value: 0.92602216548159, difference: tensor([[0.0343]])
# Sample Index: 8832, Predicted Mean: tensor([[0.9429]]), Target Value: 0.9160738012014972, difference: tensor([[0.0268]])
# Sample Index: 8833, Predicted Mean: tensor([[0.9539]]), Target Value: 0.9204582253091568, difference: tensor([[0.0334]])
# Sample Index: 8834, Predicted Mean: tensor([[0.9533]]), Target Value: 0.9243441517787928, difference: tensor([[0.0289]])
# Sample Index: 8835, Predicted Mean: tensor([[0.9570]]), Target Value: 0.9230390300099504, difference: tensor([[0.0339]])
# Sample Index: 8836, Predicted Mean: tensor([[0.2669]]), Target Value: 0.6652980878494145, difference: tensor([[-0.3984]])
# Sample Index: 8837, Predicted Mean: tensor([[0.2554]]), Target Value: 0.6481764603135041, difference: tensor([[-0.3928]])
# Sample Index: 8838, Predicted Mean: tensor([[0.4242]]), Target Value: 0.6651940706257323, difference: tensor([[-0.2410]])
# Sample Index: 8839, Predicted Mean: tensor([[0.3069]]), Target Value: 0.6608194594637028, difference: tensor([[-0.3540]])
# Sample Index: 8840, Predicted Mean: tensor([[0.4035]]), Target Value: 0.5154190814690373, difference: tensor([[-0.1119]])
# Sample Index: 8841, Predicted Mean: tensor([[0.2902]]), Target Value: 0.6702163361993676, difference: tensor([[-0.3800]])
# Sample Index: 8842, Predicted Mean: tensor([[0.3626]]), Target Value: 0.6486729953624019, difference: tensor([[-0.2860]])
# Sample Index: 8843, Predicted Mean: tensor([[0.4665]]), Target Value: 0.6503117572826776, difference: tensor([[-0.1838]])
# Sample Index: 8844, Predicted Mean: tensor([[0.0121]]), Target Value: 0.0599256963756866, difference: tensor([[-0.0478]])
# Sample Index: 8845, Predicted Mean: tensor([[0.0031]]), Target Value: 0.0544638108378097, difference: tensor([[-0.0514]])
# Sample Index: 8846, Predicted Mean: tensor([[0.0115]]), Target Value: 0.0, difference: tensor([[0.0115]])
# Sample Index: 8847, Predicted Mean: tensor([[0.0320]]), Target Value: 0.0, difference: tensor([[0.0320]])
# Sample Index: 8848, Predicted Mean: tensor([[0.0031]]), Target Value: 0.0, difference: tensor([[0.0031]])
# Sample Index: 8849, Predicted Mean: tensor([[0.0020]]), Target Value: 0.0, difference: tensor([[0.0020]])
# Sample Index: 8850, Predicted Mean: tensor([[0.0023]]), Target Value: 0.0, difference: tensor([[0.0023]])
# Sample Index: 8851, Predicted Mean: tensor([[0.3311]]), Target Value: 0.6598931173961937, difference: tensor([[-0.3288]])
# Sample Index: 8852, Predicted Mean: tensor([[0.3571]]), Target Value: 0.6429716739511434, difference: tensor([[-0.2859]])
# Sample Index: 8853, Predicted Mean: tensor([[0.4518]]), Target Value: 0.505388288445649, difference: tensor([[-0.0536]])
# Sample Index: 8854, Predicted Mean: tensor([[0.1911]]), Target Value: 0.6474385268020983, difference: tensor([[-0.4563]])
# Sample Index: 8855, Predicted Mean: tensor([[0.2160]]), Target Value: 0.6528258339531844, difference: tensor([[-0.4368]])
# Sample Index: 8856, Predicted Mean: tensor([[0.2326]]), Target Value: 0.6417882327081178, difference: tensor([[-0.4092]])
# Sample Index: 8857, Predicted Mean: tensor([[0.9432]]), Target Value: 0.9189764705189676, difference: tensor([[0.0242]])
# Sample Index: 8858, Predicted Mean: tensor([[0.9341]]), Target Value: 0.8893138984674142, difference: tensor([[0.0448]])
# Sample Index: 8859, Predicted Mean: tensor([[0.8830]]), Target Value: 0.916523234111369, difference: tensor([[-0.0335]])
# Sample Index: 8860, Predicted Mean: tensor([[0.9614]]), Target Value: 0.9161621177121706, difference: tensor([[0.0452]])
# Sample Index: 8861, Predicted Mean: tensor([[0.9707]]), Target Value: 0.9202011261336404, difference: tensor([[0.0505]])
# Sample Index: 8862, Predicted Mean: tensor([[0.0053]]), Target Value: 0.0525149598356134, difference: tensor([[-0.0472]])
# Sample Index: 8863, Predicted Mean: tensor([[0.0040]]), Target Value: 0.0, difference: tensor([[0.0040]])
# Sample Index: 8864, Predicted Mean: tensor([[0.0070]]), Target Value: 0.0, difference: tensor([[0.0070]])
# Sample Index: 8865, Predicted Mean: tensor([[0.0030]]), Target Value: 0.0498379882676422, difference: tensor([[-0.0469]])
# Sample Index: 8866, Predicted Mean: tensor([[0.0023]]), Target Value: 0.0184208615373746, difference: tensor([[-0.0162]])
# Sample Index: 8867, Predicted Mean: tensor([[0.0025]]), Target Value: 0.0402487777976217, difference: tensor([[-0.0378]])
# Sample Index: 8868, Predicted Mean: tensor([[0.5553]]), Target Value: 0.6519995839311052, difference: tensor([[-0.0967]])
# Sample Index: 8869, Predicted Mean: tensor([[0.5171]]), Target Value: 0.5045679261909481, difference: tensor([[0.0125]])
# Sample Index: 8870, Predicted Mean: tensor([[0.4499]]), Target Value: 0.6342499278748497, difference: tensor([[-0.1843]])
# Sample Index: 8871, Predicted Mean: tensor([[0.5437]]), Target Value: 0.6667523663918388, difference: tensor([[-0.1230]])
# Sample Index: 8872, Predicted Mean: tensor([[0.5683]]), Target Value: 0.6421375735725597, difference: tensor([[-0.0738]])
# Sample Index: 8873, Predicted Mean: tensor([[0.9431]]), Target Value: 0.9154084834877564, difference: tensor([[0.0277]])
# Sample Index: 8874, Predicted Mean: tensor([[0.9188]]), Target Value: 0.9125097393485382, difference: tensor([[0.0062]])
# Sample Index: 8875, Predicted Mean: tensor([[0.9602]]), Target Value: 0.9081704547907782, difference: tensor([[0.0520]])
# Sample Index: 8876, Predicted Mean: tensor([[0.9414]]), Target Value: 0.9198243090214336, difference: tensor([[0.0216]])
# Sample Index: 8877, Predicted Mean: tensor([[0.9475]]), Target Value: 0.926469635802336, difference: tensor([[0.0210]])
# Sample Index: 8878, Predicted Mean: tensor([[0.9499]]), Target Value: 0.9198557104474506, difference: tensor([[0.0301]])
# Sample Index: 8879, Predicted Mean: tensor([[0.9547]]), Target Value: 0.9259338489709164, difference: tensor([[0.0287]])
# Sample Index: 8880, Predicted Mean: tensor([[0.9535]]), Target Value: 0.922308946855049, difference: tensor([[0.0312]])
# Sample Index: 8881, Predicted Mean: tensor([[0.9478]]), Target Value: 0.9268287896124082, difference: tensor([[0.0209]])
# Sample Index: 8882, Predicted Mean: tensor([[0.9573]]), Target Value: 0.9233471565027448, difference: tensor([[0.0339]])
# Sample Index: 8883, Predicted Mean: tensor([[0.9561]]), Target Value: 0.923527714702344, difference: tensor([[0.0325]])
# Sample Index: 8884, Predicted Mean: tensor([[0.9610]]), Target Value: 0.9208998078625245, difference: tensor([[0.0401]])
# Sample Index: 8885, Predicted Mean: tensor([[0.9633]]), Target Value: 0.9262301999289544, difference: tensor([[0.0371]])
# Sample Index: 8886, Predicted Mean: tensor([[0.0118]]), Target Value: 0.0151531506424535, difference: tensor([[-0.0034]])
# Sample Index: 8887, Predicted Mean: tensor([[0.0251]]), Target Value: 0.0, difference: tensor([[0.0251]])
# Sample Index: 8888, Predicted Mean: tensor([[0.0040]]), Target Value: 0.0602043840315898, difference: tensor([[-0.0562]])
# Sample Index: 8889, Predicted Mean: tensor([[0.0032]]), Target Value: 0.0455281425467733, difference: tensor([[-0.0423]])
# Sample Index: 8890, Predicted Mean: tensor([[0.0060]]), Target Value: 0.0474691431924652, difference: tensor([[-0.0414]])
# Sample Index: 8891, Predicted Mean: tensor([[0.4728]]), Target Value: 0.5167124277031231, difference: tensor([[-0.0440]])
# Sample Index: 8892, Predicted Mean: tensor([[0.3176]]), Target Value: 0.662968494556759, difference: tensor([[-0.3454]])
# Sample Index: 8893, Predicted Mean: tensor([[0.4227]]), Target Value: 0.6709189431065039, difference: tensor([[-0.2482]])
# Sample Index: 8894, Predicted Mean: tensor([[0.5471]]), Target Value: 0.6438371757557441, difference: tensor([[-0.0968]])
# Sample Index: 8895, Predicted Mean: tensor([[0.8925]]), Target Value: 0.8923932008062316, difference: tensor([[7.2598e-05]])
# Sample Index: 8896, Predicted Mean: tensor([[0.9544]]), Target Value: 0.9198184212540552, difference: tensor([[0.0346]])
# Sample Index: 8897, Predicted Mean: tensor([[0.9645]]), Target Value: 0.9106668681591504, difference: tensor([[0.0538]])
# Sample Index: 8898, Predicted Mean: tensor([[0.9435]]), Target Value: 0.924000698681729, difference: tensor([[0.0195]])
# Sample Index: 8899, Predicted Mean: tensor([[0.9444]]), Target Value: 0.9192551581748706, difference: tensor([[0.0251]])
# Sample Index: 8900, Predicted Mean: tensor([[0.9537]]), Target Value: 0.9203797217441136, difference: tensor([[0.0333]])
# Sample Index: 8901, Predicted Mean: tensor([[0.0261]]), Target Value: 0.0, difference: tensor([[0.0261]])
# Sample Index: 8902, Predicted Mean: tensor([[0.0133]]), Target Value: 0.0, difference: tensor([[0.0133]])
# Sample Index: 8903, Predicted Mean: tensor([[0.0070]]), Target Value: 0.0, difference: tensor([[0.0070]])
# Sample Index: 8904, Predicted Mean: tensor([[0.0144]]), Target Value: 0.0, difference: tensor([[0.0144]])
# Sample Index: 8905, Predicted Mean: tensor([[0.4281]]), Target Value: 0.5093801947280931, difference: tensor([[-0.0813]])
# Sample Index: 8906, Predicted Mean: tensor([[0.4967]]), Target Value: 0.4933556545136606, difference: tensor([[0.0034]])
# Sample Index: 8907, Predicted Mean: tensor([[0.5089]]), Target Value: 0.6472128290525992, difference: tensor([[-0.1383]])
# Sample Index: 8908, Predicted Mean: tensor([[0.9224]]), Target Value: 0.8769868761665138, difference: tensor([[0.0454]])
# Sample Index: 8909, Predicted Mean: tensor([[0.9423]]), Target Value: 0.91265889612212, difference: tensor([[0.0296]])
# Sample Index: 8910, Predicted Mean: tensor([[0.9359]]), Target Value: 0.9197811320606596, difference: tensor([[0.0161]])
# Sample Index: 8911, Predicted Mean: tensor([[0.9490]]), Target Value: 0.914701951402368, difference: tensor([[0.0343]])
# Sample Index: 8912, Predicted Mean: tensor([[0.9308]]), Target Value: 0.9176988249978902, difference: tensor([[0.0131]])
# Sample Index: 8913, Predicted Mean: tensor([[0.9435]]), Target Value: 0.9171571503990924, difference: tensor([[0.0264]])
# Sample Index: 8914, Predicted Mean: tensor([[0.0090]]), Target Value: 0.0, difference: tensor([[0.0090]])
# Sample Index: 8915, Predicted Mean: tensor([[0.0036]]), Target Value: 0.0, difference: tensor([[0.0036]])
# Sample Index: 8916, Predicted Mean: tensor([[0.0025]]), Target Value: 0.0, difference: tensor([[0.0025]])
# Sample Index: 8917, Predicted Mean: tensor([[0.3916]]), Target Value: 0.6465769501757499, difference: tensor([[-0.2550]])
# Sample Index: 8918, Predicted Mean: tensor([[0.3997]]), Target Value: 0.6243290398425219, difference: tensor([[-0.2246]])
# Sample Index: 8919, Predicted Mean: tensor([[0.9742]]), Target Value: 0.9129199204758888, difference: tensor([[0.0612]])
# Sample Index: 8920, Predicted Mean: tensor([[0.9528]]), Target Value: 0.9215788637001476, difference: tensor([[0.0313]])
# Sample Index: 8921, Predicted Mean: tensor([[0.9539]]), Target Value: 0.922907536538503, difference: tensor([[0.0310]])
# Sample Index: 8922, Predicted Mean: tensor([[0.9525]]), Target Value: 0.9263342171526364, difference: tensor([[0.0262]])
# Sample Index: 8923, Predicted Mean: tensor([[0.9377]]), Target Value: 0.9239889231469725, difference: tensor([[0.0137]])
# Sample Index: 8924, Predicted Mean: tensor([[0.0049]]), Target Value: 0.0135928922872209, difference: tensor([[-0.0086]])
# Sample Index: 8925, Predicted Mean: tensor([[0.0018]]), Target Value: 0.0, difference: tensor([[0.0018]])
# Sample Index: 8926, Predicted Mean: tensor([[0.4849]]), Target Value: 0.6377924012474216, difference: tensor([[-0.1529]])
# Sample Index: 8927, Predicted Mean: tensor([[0.0086]]), Target Value: 0.0056188926679632, difference: tensor([[0.0029]])

# %%
less_1=[x for x in diff_list if abs(x)<0.1]
len(less_1),len(less_1)/len(diff_list)
# Out:
# (5543, 0.620855734767025)

# %%
np.mean([abs(x.item()) for x in diff_list])
# Out:
# 0.759040851101336
