# %%
import pickle

import pandas as pd
import numpy as np
import torch
from torch import nn
from torch_geometric.data import Data
from torch_geometric.nn import TransformerConv, TopKPooling
from torch_geometric.nn import global_mean_pool as gap, global_max_pool as gmp
from torch_geometric.loader import DataLoader
from blitz.utils import variational_estimator
from blitz.modules import BayesianLinear
from torch.optim.lr_scheduler import StepLR
import os
import sys
import random

loger_dir = os.path.abspath('/home/ubuntu/project/mayang/LOGER')
sys.path.append(loger_dir)
from core.models.DGP import DeepGPModel
from core.models.DKL import DKLGPModel
from sql import Sql, _global
from core import database, Sql, Plan, load
import ast
import re
import torch.nn.functional as F

# 获取 QPE 目录的绝对路径
qpe_dir = os.path.abspath('/home/ubuntu/project/rainbow')

# 将 QPE 目录添加到 sys.path
sys.path.append(qpe_dir)

# 现在尝试导入 TreeBuilder 类
from QPE.sql2fea import TreeBuilder


def clean_expression(expr):
    """清理表达式中的多余空格和括号"""
    # 移除首尾的空格
    expr = expr.strip()

    # 移除最外层的括号，如果存在
    if expr.startswith('('):
        expr = expr[1:].strip()
    if expr.endswith(')'):
        expr = expr[:-1].strip()

    return expr


def split_cmp_expression(cmp, num):
    '''将含有 OR 或 AND 的表达式分割并提取每个子表达式，并保持原来的编号'''

    # 移除最外层的括号
    cmp = cmp.strip()
    if cmp.startswith('(') and cmp.endswith(')'):
        cmp = cmp[1:-1].strip()

    # 按 OR 和 AND 分割
    parts = re.split(r'(\s+OR\s+|\s+AND\s+)', cmp)

    results = []
    current_num = num

    for part in parts:
        part = clean_expression(part)  # 清理表达式

        # 忽略分隔符 'OR' 和 'AND'
        if part in ['OR', 'AND']:
            continue

        # 递归处理有内部括号的部分
        if part.startswith('(') and part.endswith(')'):
            nested_result = split_cmp_expression(part, current_num)
            results.extend(nested_result)
        else:
            results.append((part, current_num))

    return results


def parse_attribute_config(index_str):
    '''处理输入的configuration，转化成cols/attribute的形式'''
    # 将字符串转换为列表
    index_list = ast.literal_eval(index_str)

    table_cols_list = []
    for index in index_list:
        # 去掉 I() 的部分，提取表名和列名
        index_content = index[4:-1]  # 去掉前面的 'I(' 和后面的 ')'
        table_cols = index_content.split(',')
        table_cols_list.append(table_cols)

    return table_cols_list


def swap_join_condition(condition: str) -> str:
    '''防止同一个连接条件，左右连接条件不一样而无法识别'''
    # 找到等号的位置
    equal_index = condition.find('=')

    # 如果没有找到等号，返回原字符串
    if equal_index == -1:
        return condition

    # 拆分等号两边的条件，并去掉左右空格
    left_side = condition[:equal_index].strip()
    right_side = condition[equal_index + 1:].strip()

    # 交换等式两边的条件
    swapped_condition = f"{right_side} = {left_side}"

    return swapped_condition


def has_text_expression(cmp: str) -> bool:
    '''判断cmp中有没有文本'''
    # 使用正则表达式查找被引号包围的文本
    pattern = r"'[^']*'"

    # 查找匹配的内容
    match = re.search(pattern, cmp)

    # 如果找到了匹配内容，返回 True；否则返回 False
    return match is not None


def convert_between_expression(cmp: str) -> str:
    '''转换 BETWEEN 表达式'''
    match = re.match(r"([\w\.]+)\.(\w+)\s*BETWEEN\s*(.*)\s*AND\s*(.*)", cmp)

    if not match:
        print('The input string is not a valid BETWEEN expression. cmp', cmp)
        return cmp.split('.')
        # raise ValueError("The input string is not a valid BETWEEN expression.")

    table_name, column, lower_bound, upper_bound = match.groups()

    # 检查值是否是数字
    if lower_bound.strip().isdigit() and upper_bound.strip().isdigit():
        new_expression = f"(({column} >= {lower_bound.strip()}) AND ({column} <= {upper_bound.strip()}))"
    else:
        new_expression = f"(({column})::text >= {lower_bound.strip()}::text) AND (({column})::text <= {upper_bound.strip()}::text)"

    return table_name, new_expression[:-1]


def convert_to_text_comparison(cmp: str):
    '''转化cmp与plan中的谓词表示，处理 IN 和复杂的 OR 语句。'''

    # 去除外部括号和空白
    cmp = cmp.strip()
    if cmp.startswith('(') and cmp.endswith(')'):
        cmp = cmp[1:-1].strip()

    # 处理 OR 语句，切割并处理第一个部分
    if ' OR ' in cmp:
        first_or_index = cmp.index(' OR ')
        first_part = cmp[:first_or_index].strip()
        return convert_to_text_comparison(first_part)

    # 处理 AND 语句，切割并处理第一个部分
    if ' AND ' in cmp:
        first_and_index = cmp.index(' AND ')
        first_part = cmp[:first_and_index].strip()
        return convert_to_text_comparison(first_part)

    # 处理 '=' 和 IN 语句
    match_eq = re.match(r"\(?\s*([\w\.]+)\.(\w+)\s*(=|<>|<|>|<=|>=)\s*'([^']*)'\s*\)?", cmp)
    match_in = re.match(r"\(?\s*([\w\.]+)\.(\w+)\s*IN\s*\((.*?)\)\s*\)?", cmp, re.DOTALL)

    if match_eq:
        # 处理 '=' 等值比较的情况
        table_name, column, operator, value = match_eq.groups()
        new_expression = f"(({column})::text {operator} '{value}'::text)"
        return table_name, new_expression

    elif match_in:
        # 处理 'IN' 语句，提取表名、列名以及 IN 中的值列表
        table_name, column, values = match_in.groups()

        # 使用正则提取 IN 中的值，允许值跨多行
        value_list = re.findall(r"'(.*?)'", values)
        if not value_list:
            raise ValueError("在 IN 表达式中未找到有效值。")

        # 单个值的情况：转化为等值比较
        if len(value_list) == 1:
            new_expression = f"(({column})::text = '{value_list[0]}'::text)"
        else:
            # 多个值的情况：转化为 ANY 比较
            formatted_values = ','.join(f"'{v}'" for v in value_list)
            new_expression = f"(({column})::text = ANY ('{{{formatted_values}}}'::text[]))"

        return table_name, new_expression

    # 无法匹配时，抛出错误
    print(f"无法匹配的输入: {cmp}")  # 调试信息
    raise ValueError("输入字符串不是有效的比较表达式。")


def trim_parentheses_and_spaces(input_str: str) -> str:
    # 去除开头的空格
    trimmed_str = input_str.lstrip()
    # 如果开头是 '('，则去除它
    if trimmed_str.startswith('('):
        trimmed_str = trimmed_str[1:].lstrip()  # 去掉 '(' 以及后面的空格
    return trimmed_str


def transform_sql_like_condition(sql_condition):
    '''处理LIKE和NOT LIKE条件'''
    # 匹配 `AND` 和 `OR`
    sql_condition = trim_parentheses_and_spaces(sql_condition)
    conditions = re.split(r"(?i) AND | OR ", sql_condition)
    # print(conditions)

    # 转换每个 LIKE 和 NOT LIKE 条件为 Postgres 的格式
    transformed_clauses = []
    for condition in conditions:
        condition = condition.strip()
        table_name = condition.split('.')[0]
        col_name = condition.split()[0][len(table_name) + 1:]
        if 'not like' in condition.lower():
            transformed_clause = f"(({col_name})::text !~~ {condition.split('not like')[1].strip().rstrip(')')}::text)"
        elif 'like' in condition.lower():
            transformed_clause = f"(({col_name})::text ~~ {condition.split('like')[1].strip().rstrip(')')}::text)"
            # print("condition.split('like')[1].strip()",condition.split('like')[1].strip())
        else:
            continue

        transformed_clauses.append(transformed_clause)

    # 返回表名和第一个转换后的条件
    return table_name, transformed_clauses[0]


# def delete_left_table_cond(sql_condition):
#     # 使用正则表达式匹配表名和列名
#     match = re.match(r"[\w\.]+\.(\w+)\s*=\s*(.*)", sql_condition)

#     if not match:
#         raise ValueError("The input string is not a valid comparison expression.")

#     # 提取列名和右侧表达式
#     column = match.group(1)
#     right_side = match.group(2)

#     return f"{column} = {right_side.strip()}"
def delete_left_table_cond(sql_condition):
    # 扩展正则表达式，支持更多运算符并处理可能的括号
    match = re.match(r"[\w\.]+\.(\w+)\s*(=|<>|<|>|<=|>=)\s*(.*)", sql_condition)

    if not match:
        print('sql_condition', sql_condition)
        raise ValueError("The input string is not a valid comparison expression.")

    # 提取列名、运算符和右侧表达式
    column = match.group(1)
    operator = match.group(2)
    right_side = match.group(3)

    # 返回去掉表名前缀的表达式
    return f"{column} {operator} {right_side.strip()}"


def dgl_node_and_edge_vectorization(sql_query, config_index, plan, attribute_dict):
    num_edge_features = 15
    sql_instance = Sql(sql_query)

    # 构建异构图
    g, data_dict, node_indexes, edge_lists = sql_instance.to_hetero_graph_dgl()
    # 处理edge_list中一个语句存在很多and、or语句的情况
    edge_list = []
    for cmp, num_table in edge_lists:
        if 'BETWEEN' in cmp:
            edge_list += [(cmp, num_table)]
        elif 'OR' in cmp or 'AND' in cmp:
            cmp_split = split_cmp_expression(cmp, num_table)
            edge_list += cmp_split
        else:
            edge_list += [(cmp, num_table)]
    # 构建 node feature
    filter_features = g.ndata['filter']
    edge_features = g.ndata['edge']
    onehot_features = g.ndata['onehot']
    others_features = g.ndata['others'].view(g.ndata['filter'].shape[0], -1)

    # 假设两个特征的维度是相同的
    combined_features = torch.cat((filter_features, edge_features, onehot_features, others_features), dim=1)
    g.ndata['feature'] = combined_features

    # 构建 edge feature
    tree_builder = TreeBuilder()
    tree_builder.set_configruations(config_index)
    tree_builder.set_table_to_alias_dict(sql_query)
    # 准备您的 SQL 执行计划数据，这里是一个示例
    execution_plan = ast.literal_eval(plan)[0]['Plan']

    # 特征化执行计划
    features = tree_builder.plan_to_feature_tree(execution_plan, current_height=0)

    # 提取对应operator vector
    operator_vector_dict = tree_builder.get_operator_vector()
    # 建立cmp与plan_operator的映射关系
    tables = []
    operator_vectors_cmp1 = []
    operator_vectors_cmp2 = []
    get_keys = []
    for cmp, table_num in edge_list:
        flag = False
        # print('cmp:',cmp)
        if table_num == 1:
            if 'like' in cmp and has_text_expression(cmp):
                try:
                    table, cmp_in_op = transform_sql_like_condition(cmp)
                except:
                    print('error process like_cmp:', cmp)
            elif 'BETWEEN' in cmp:
                table, cmp_in_op = convert_between_expression(cmp)
            elif has_text_expression(cmp):
                table, cmp_in_op = convert_to_text_comparison(cmp)
            else:
                table, cmp_in_op = cmp.split('.')

        for key in operator_vector_dict:
            if table_num == 1:
                table_op, key_op = key.split('_47_')
                if cmp_in_op in key and table == table_op:
                    tables.append(table)
                    operator_vectors_cmp1.append(operator_vector_dict[key])
                    flag = True
                    break
            # print(key)
            elif cmp in key or swap_join_condition(cmp) in key or delete_left_table_cond(
                    cmp) in key or delete_left_table_cond(swap_join_condition(cmp)) in key:
                get_keys.append(cmp)
                operator_vectors_cmp2.append(operator_vector_dict[key])
                operator_vectors_cmp2.append(operator_vector_dict[key])
                flag = True
                break
        if not flag:
            # 存在plan中不存在的cmp
            print('error cmp', cmp)
            if table_num == 2:
                print('add edge vector:', table_num)
                operator_vectors_cmp2.append(torch.zeros((1, num_edge_features)))
                operator_vectors_cmp2.append(torch.zeros((1, num_edge_features)))
    # print('cmp',len(edge_list))
    # print(len(operator_vectors_cmp1),len(operator_vectors_cmp2))
    # 合并每一条边的向量
    # 这个sql没有join关系：
    if len(operator_vectors_cmp1):
        vector_cmp1 = torch.cat(operator_vectors_cmp1, dim=0)
        vector_cmp2 = torch.cat(operator_vectors_cmp2, dim=0)
        vector_edge = torch.cat((vector_cmp2, vector_cmp1), dim=0)
    else:
        vector_edge = torch.cat(operator_vectors_cmp2, dim=0)
    # 添加自环
    for t in tables:
        new_u = torch.tensor([node_indexes['~' + t]])  # 自环的起点
        new_v = torch.tensor([node_indexes['~' + t]])  # 自环的终点
        g.add_edges(new_u, new_v)
    g.edata['feature'] = vector_edge

    # 构建configuration特征
    configuration_vector = [0] * len(attribute_dict)
    for attrs in parse_attribute_config(config_index):
        for p in range(len(attrs)):
            # 获得在indexed_attribute中的位置
            attr = attrs[p]
            if attr[:2] == 'C ':
                attr = attr[2:]
            attr_p = attribute_dict[attr]
            configuration_vector[attr_p] += 1 / (p + 1)
    g.global_data = {"configuration_vector": torch.tensor(configuration_vector)}
    return g


def dgl_to_pyg(dgl_graph, label):
    """将 DGL 图转换为 PyG 格式."""
    x = dgl_graph.ndata['feature']  # 节点特征
    edge_index = torch.stack(dgl_graph.edges()).long()  # 边索引 (转换为 PyG 格式)
    edge_attr = dgl_graph.edata['feature']  # 边特征
    configuration_vector = dgl_graph.global_data['configuration_vector']  # configuration_vector
    batch = torch.zeros(dgl_graph.number_of_nodes(), dtype=torch.long)  # 所有节点归为同一批次
    label_tensor = torch.tensor(label, dtype=torch.float32)  # 根据需要使用 float32 或其他类型
    return Data(x=x, edge_index=edge_index, edge_attr=edge_attr, configuration_vector=configuration_vector,
                y=label_tensor, batch=batch)


class GraphEncoder(nn.Module):
    """图编码模块，基于 TransformerConv,添加了残差连接。"""

    def __init__(self, in_feats, edge_feats, embedding_size, num_layers=3, top_k_every_n=3, top_k_ratio=0.5, n_heads=4,
                 dropout_rate=0.5):
        super(GraphEncoder, self).__init__()
        self.embedding_size = embedding_size
        self.top_k_every_n = top_k_every_n
        self.edge_dim = edge_feats
        self.n_heads = n_heads

        # 第一层 TransformerConv
        self.conv1 = TransformerConv(in_feats, self.embedding_size, heads=n_heads, dropout=dropout_rate,
                                     edge_dim=edge_feats, beta=True)
        self.transf1 = nn.Linear(self.embedding_size * n_heads, self.embedding_size)
        self.bn1 = nn.BatchNorm1d(self.embedding_size)

        # 其他 TransformerConv 层及 TopKPooling
        self.conv_layers = nn.ModuleList()
        self.transf_layers = nn.ModuleList()
        self.bn_layers = nn.ModuleList()
        self.pooling_layers = nn.ModuleList()

        for _ in range(num_layers):
            self.conv_layers.append(
                TransformerConv(self.embedding_size, self.embedding_size, heads=n_heads, dropout=dropout_rate,
                                edge_dim=edge_feats, beta=True))
            self.transf_layers.append(nn.Linear(self.embedding_size * n_heads, self.embedding_size))
            self.bn_layers.append(nn.BatchNorm1d(self.embedding_size))
            self.pooling_layers.append(TopKPooling(self.embedding_size, ratio=top_k_ratio))

    def forward(self, x, edge_attr, edge_index, batch_index):
        # 残差连接的初始输入
        residual = x

        # 第一个 TransformerConv 层及线性变换
        x = self.conv1(x, edge_index, edge_attr)
        x = torch.relu(self.transf1(x.view(-1, self.embedding_size * self.n_heads)))
        x = self.bn1(x)

        # 添加残差连接，将初始输入加入 x
        if residual.shape == x.shape:
            x = x + residual  # 进行残差连接

        global_representation = []

        for i, conv_layer in enumerate(self.conv_layers):
            # 每一层的残差输入
            residual = x

            # TransformerConv 和线性变换
            x = conv_layer(x, edge_index, edge_attr)
            x = torch.relu(self.transf_layers[i](x.view(-1, self.embedding_size * self.n_heads)))  # 确保形状匹配
            x = self.bn_layers[i](x)

            # 残差连接
            if residual.shape == x.shape:
                x = x + residual  # 进行残差连接

            if i % self.top_k_every_n == 0 or i == len(self.conv_layers) - 1:
                x, edge_index, edge_attr, batch_index, _, _ = self.pooling_layers[i](
                    x, edge_index, edge_attr, batch_index
                )
                global_representation.append(torch.cat([
                    gmp(x, batch_index),
                    gap(x, batch_index)
                ], dim=1))

        # 将全局表示相加作为最终输出
        x = sum(global_representation)

        return x


@variational_estimator
class ImprovementPredictionModelGNN(nn.Module):
    """使用图卷积神经网络进行预测，基于图编码，并增加多层贝叶斯线性层，融合配置向量."""

    def __init__(self, in_feats, edge_feats, graph_embedding_size, hidden_dim=128, num_layers=3):
        print('start ImprovementPredictionModelGNN')
        super(ImprovementPredictionModelGNN, self).__init__()

        # 图编码器
        self.graph_encoder = GraphEncoder(in_feats, edge_feats, graph_embedding_size)

        # 定义贝叶斯线性层
        input_dim = graph_embedding_size * 2
        self.blinear1 = BayesianLinear(input_dim, hidden_dim, prior_sigma_1=1)
        self.batch_norm1 = nn.BatchNorm1d(hidden_dim)

        # 中间的隐藏层
        self.layers = nn.ModuleList()
        self.batch_norms = nn.ModuleList()
        for _ in range(num_layers - 1):
            self.layers.append(BayesianLinear(hidden_dim, hidden_dim, prior_sigma_1=1))
            self.batch_norms.append(nn.BatchNorm1d(hidden_dim))

        # 最后一层，隐藏层到输出维度

        self.blinear_out = BayesianLinear(hidden_dim, 1, prior_sigma_1=1)  # 输出为单个值

    def forward(self, x, edge_attr, edge_index, batch_index):
        # 通过图编码器获取图的嵌入表示
        graph_embedding = self.graph_encoder(x, edge_attr, edge_index, batch_index)

        # 第一个贝叶斯线性层
        x_ = self.blinear1(graph_embedding)
        x_ = self.batch_norm1(x_)
        x_ = F.leaky_relu(x_)

        # 中间贝叶斯线性层
        for layer, batch_norm in zip(self.layers, self.batch_norms):
            x_ = layer(x_)
            x_ = batch_norm(x_)
            x_ = F.leaky_relu(x_)

        # 最后一层输出预测值
        output = self.blinear_out(x_)
        prediction = F.sigmoid(output)  # 保证输出非负数

        return prediction

    def predict(self, x, edge_attr, edge_index, batch_index):
        """在预测时调用"""
        self.eval()  # 设置为评估模式
        with torch.no_grad():
            prediction = self.forward(x, edge_attr, edge_index, batch_index)
        return prediction


def evaluate_regression(regressor,
                        X,
                        y,
                        samples=50,
                        std_multiplier=2):
    preds = [regressor(*X) for i in range(samples)]
    preds = torch.stack(preds)
    means = preds.mean(axis=0)
    stds = preds.std(axis=0)
    ci_upper = means + (std_multiplier * stds)
    ci_lower = means - (std_multiplier * stds)
    ic_acc = (ci_lower <= y) * (ci_upper >= y)
    ic_acc = ic_acc.float().mean()
    return ic_acc, (ci_upper >= y).float().mean(), (ci_lower <= y).float().mean()


def load_sql_graphs_pyg(csv_path, dbname, user, password, host, port, start_idx=0, end_idx=8877):
    """
    从指定的 CSV 文件加载 SQL 查询，并将它们转换为 PyG 图数据。

    参数:
    - csv_path (str): CSV 文件路径。
    - dbname (str): 数据库名称。
    - user (str): 数据库用户。
    - password (str): 数据库密码。
    - host (str): 数据库主机地址。
    - port (str): 数据库端口。
    - start_idx (int): SQL 查询的起始索引。
    - end_idx (int): SQL 查询的结束索引。

    返回:
    - sql_graphs_pyg (list): PyG 数据列表。
    """
    print('start load_sql_graphs_pyg')
    # 读取 CSV 数据
    df = pd.read_csv(csv_path).iloc[start_idx:, :]
    # df = pd.read_csv(csv_path).iloc[start_idx:, :].sample(n=3200, random_state=42)
    # 设置数据库连接
    database.setup(dbname=dbname, user=user, password=password, host=host, port=port, cache=False)
    sql_graphs_pyg = []
    # 创建index的vector
    attribute_num = 0
    attribute_dict = {}
    for x in df['index'].values:
        for attrs in parse_attribute_config(x):
            for attr in attrs:
                if attr[:2] == 'C ':
                    attr = attr[2:]
                if attr not in attribute_dict:
                    attribute_dict[attr] = attribute_num
                    attribute_num += 1

    query_list = df['query'].values
    quey_config_list = df['index'].values
    query_plans = df['query_plan_no_index'].values
    for i in range(df.shape[0]):
        # if cnt % 50 == 0:
        #     print(cnt)
        print(i)
        g = dgl_node_and_edge_vectorization(query_list[i], quey_config_list[i], query_plans[i], attribute_dict)
        # 转换为 PyG 数据
        pyg_data = dgl_to_pyg(g, df['label'].values[i])
        sql_graphs_pyg.append(pyg_data)

    return sql_graphs_pyg, df['label'].values, len(attribute_dict)


def calculate_qerror_list(pred_list, valid_list):
    y_pred_list = [1 - x for x in pred_list]
    y_valid_list = [1 - x for x in valid_list]
    q_errors = []
    for pred, valid in zip(y_pred_list, y_valid_list):
        pred = pred + 1e-4  # 避免除零错误
        valid = valid + 1e-4

        q_error = max(pred / valid, valid / pred)
        q_errors.append(q_error)
    # 计算均值
    mean_q_error = np.mean(q_errors)

    # 计算 90% 和 95% 分位数
    percentile_90 = np.percentile(q_errors, 90)
    percentile_95 = np.percentile(q_errors, 95)

    # 输出结果
    print(f"Mean QError: {mean_q_error}")
    print(f"90th Percentile QError: {percentile_90}")
    print(f"95th Percentile QError: {percentile_95}")
    print(f"Max QError: {max(q_errors)}")

    return q_errors

# %%
def main():
    data_loader_file = '/tmp/data_loader.pkl'
    data_loader = None

    # 检查是否已有保存的DataLoader
    if not os.path.exists(data_loader_file):
        # 读取数据并设置数据库
        sql_graphs_pyg, label_list, config_vector_size = load_sql_graphs_pyg(
            csv_path='/home/ubuntu/project/mayang/Classification/process_data/job/job_train_8935.csv',
            dbname='imdbload',
            user='postgres',
            password='password',
            host='127.0.0.1',
            port='5432',
            start_idx=7
        )

        print('len(label_list) 需要是batch_size的倍数:', len(label_list))
        print('config_vector_size len:',config_vector_size)

        # 创建 PyG DataLoader
        data_loader = DataLoader(sql_graphs_pyg, batch_size=64, shuffle=True)

        # 保存DataLoader到磁盘
        with open(data_loader_file, 'wb') as f:
            pickle.dump(data_loader, f)

        print('Data loaded and saved to disk.')
    else:
        # 从磁盘加载DataLoader
        with open(data_loader_file, 'rb') as f:
            data_loader = pickle.load(f)

        print('DataLoader loaded from disk.')

    # 初始化模型
    model = ImprovementPredictionModelGNN(
        data_loader.dataset[0].x.shape[1],
        data_loader.dataset[0].edge_attr.shape[1],
        graph_embedding_size=32,
    )

    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = torch.nn.MSELoss()  # 均方误差损失函数
    # 初始化学习率调度器
    scheduler = StepLR(optimizer, step_size=10, gamma=0.5)  # 每10个epoch将学习率减半

    model.train()

    print('start DeepApproximateMLL')
    iteration = 0
    for epoch in range(50):
        total_loss = 0
        for batch_idx, batch in enumerate(data_loader):
            optimizer.zero_grad()

            target = batch.y.view(-1, 1)

            inputs = (batch.x, batch.edge_attr, batch.edge_index, batch.batch)

            loss = model.sample_elbo(
                inputs=inputs,
                labels=target,
                criterion=criterion,
                sample_nbr=10,
                complexity_cost_weight=0.01 / len(data_loader)
            )

            iteration += 1
            if iteration % 100 == 0:
                ic_acc, under_ci_upper, over_ci_lower = evaluate_regression(model,
                                                                            inputs,
                                                                            target,
                                                                            samples=25,
                                                                            std_multiplier=3)

                print("CI acc: {:.2f}, CI upper acc: {:.2f}, CI lower acc: {:.2f}".format(ic_acc, under_ci_upper,
                                                                                          over_ci_lower))
                print("Loss: {:.4f}".format(loss))

            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            print("Epoch %d batch_idx%d loss:" % (epoch + 1, batch_idx), loss.item())

        print(f'Epoch {epoch + 1}, Loss: {total_loss:.4f}')

        if (epoch + 1) % 20 == 0:
            for param_group in optimizer.param_groups:
                param_group['lr'] *= 0.5  # 将学习率减半

        # 随机抽取 20 个样本进行预测
        sample_indices = random.sample(range(len(data_loader.dataset)), 50)
        min_diff = []
        for idx in sample_indices:
            sample_batch = data_loader.dataset[idx]
            sample_x = sample_batch.x
            sample_edge_attr = sample_batch.edge_attr
            sample_edge_index = sample_batch.edge_index

            # 获取对应的 target 值
            target_value = sample_batch.y
            model.eval()
            with torch.no_grad():
                pred_mean = model.predict(sample_x, sample_edge_attr, sample_edge_index, sample_batch.batch)
            print(
                f'Sample Index: {idx}, Predicted Mean: {pred_mean}, Target Value: {target_value}, difference: {pred_mean - target_value}')
            if abs(pred_mean - target_value) < 0.1:
                min_diff.append(pred_mean - target_value)

        print('the number of samples < 0.1:', len(min_diff))

        if (epoch + 1) % 10 == 0:
            print('*************** Testing *****************')
            diff_list = []
            pred_list = []
            label_list = []
            for idx in range(len(data_loader.dataset)):
                sample_batch = data_loader.dataset[idx]
                sample_x = sample_batch.x
                sample_edge_attr = sample_batch.edge_attr
                sample_edge_index = sample_batch.edge_index

                # 获取对应的 target 值
                target_value = sample_batch.y.item()
                label_list.append(target_value)
                # print(target_value)
                model.eval()
                with torch.no_grad():
                    pred_mean = model.predict(sample_x, sample_edge_attr, sample_edge_index,
                                              sample_batch.batch).item()
                    pred_list.append(pred_mean)
                # print(
                #     f'Sample Index: {idx}, Predicted Mean: {pred_mean}, Target Value: {target_value}, difference: {pred_mean - target_value}')
                diff_list.append(pred_mean - target_value)

            q_errors = calculate_qerror_list(pred_list, label_list)
            print(q_errors[:10])
            less_1=[x for x in diff_list if abs(x)<0.1]
            print(f'total distance number: {len(less_1)} / {len(diff_list)}, ratio: {100*len(less_1)/len(diff_list)}')


if __name__ == "__main__":
    main()
# Out:
# DataLoader loaded from disk.
# start ImprovementPredictionModelGNN
# start DeepApproximateMLL
# Epoch 1 batch_idx0 loss: 19.42452049255371
# Epoch 1 batch_idx1 loss: 19.415769577026367
# Epoch 1 batch_idx2 loss: 19.405372619628906
# Epoch 1 batch_idx3 loss: 19.434322357177734
# Epoch 1 batch_idx4 loss: 19.399093627929688
# Epoch 1 batch_idx5 loss: 19.402299880981445
# Epoch 1 batch_idx6 loss: 19.40715980529785
# Epoch 1 batch_idx7 loss: 19.410778045654297
# Epoch 1 batch_idx8 loss: 19.400609970092773
# Epoch 1 batch_idx9 loss: 19.379764556884766
# Epoch 1 batch_idx10 loss: 19.387189865112305
# Epoch 1 batch_idx11 loss: 19.379230499267578
# Epoch 1 batch_idx12 loss: 19.384624481201172
# Epoch 1 batch_idx13 loss: 19.397672653198242
# Epoch 1 batch_idx14 loss: 19.38651466369629
# Epoch 1 batch_idx15 loss: 19.384721755981445
# Epoch 1 batch_idx16 loss: 19.403005599975586
# Epoch 1 batch_idx17 loss: 19.360544204711914
# Epoch 1 batch_idx18 loss: 19.39038848876953
# Epoch 1 batch_idx19 loss: 19.376665115356445
# Epoch 1 batch_idx20 loss: 19.351787567138672
# Epoch 1 batch_idx21 loss: 19.35698699951172
# Epoch 1 batch_idx22 loss: 19.37228012084961
# Epoch 1 batch_idx23 loss: 19.364091873168945
# Epoch 1 batch_idx24 loss: 19.359676361083984
# Epoch 1 batch_idx25 loss: 19.37295150756836
# Epoch 1 batch_idx26 loss: 19.35856819152832
# Epoch 1 batch_idx27 loss: 19.37694549560547
# Epoch 1 batch_idx28 loss: 19.370346069335938
# Epoch 1 batch_idx29 loss: 19.37741470336914
# Epoch 1 batch_idx30 loss: 19.371904373168945
# Epoch 1 batch_idx31 loss: 19.376705169677734
# Sample Index: 2529, Predicted Mean: tensor([[0.4113]]), Target Value: 0.4725029170513153, difference: tensor([[-0.0612]])
# Sample Index: 209, Predicted Mean: tensor([[0.4275]]), Target Value: 0.5446609854698181, difference: tensor([[-0.1172]])
# Sample Index: 3703, Predicted Mean: tensor([[0.3998]]), Target Value: 0.0, difference: tensor([[0.3998]])
# Sample Index: 2766, Predicted Mean: tensor([[0.6330]]), Target Value: 0.6067826747894287, difference: tensor([[0.0262]])
# Sample Index: 1921, Predicted Mean: tensor([[0.3996]]), Target Value: 0.8464364409446716, difference: tensor([[-0.4468]])
# Sample Index: 6272, Predicted Mean: tensor([[0.4164]]), Target Value: 0.3461371660232544, difference: tensor([[0.0703]])
# Sample Index: 3795, Predicted Mean: tensor([[0.4197]]), Target Value: 0.9492891430854797, difference: tensor([[-0.5296]])
# Sample Index: 2111, Predicted Mean: tensor([[0.5817]]), Target Value: 0.9967525005340576, difference: tensor([[-0.4150]])
# Sample Index: 7656, Predicted Mean: tensor([[0.4075]]), Target Value: 0.1682145595550537, difference: tensor([[0.2393]])
# Sample Index: 409, Predicted Mean: tensor([[0.3935]]), Target Value: 0.8479958772659302, difference: tensor([[-0.4545]])
# Sample Index: 2053, Predicted Mean: tensor([[0.4021]]), Target Value: 0.7435439825057983, difference: tensor([[-0.3414]])
# Sample Index: 7999, Predicted Mean: tensor([[0.3858]]), Target Value: 0.0, difference: tensor([[0.3858]])
# Sample Index: 7094, Predicted Mean: tensor([[0.3791]]), Target Value: 0.07206994295120239, difference: tensor([[0.3070]])
# Sample Index: 5239, Predicted Mean: tensor([[0.4086]]), Target Value: 0.4160827696323395, difference: tensor([[-0.0075]])
# Sample Index: 7097, Predicted Mean: tensor([[0.3799]]), Target Value: 0.0, difference: tensor([[0.3799]])
# Sample Index: 286, Predicted Mean: tensor([[0.4034]]), Target Value: 0.21538671851158142, difference: tensor([[0.1881]])
# Sample Index: 4659, Predicted Mean: tensor([[0.4274]]), Target Value: 0.0, difference: tensor([[0.4274]])
# Sample Index: 2145, Predicted Mean: tensor([[0.5827]]), Target Value: 0.0, difference: tensor([[0.5827]])
# Sample Index: 1328, Predicted Mean: tensor([[0.4265]]), Target Value: 0.448381632566452, difference: tensor([[-0.0219]])
# Sample Index: 2133, Predicted Mean: tensor([[0.5797]]), Target Value: 0.9829745888710022, difference: tensor([[-0.4033]])
# Sample Index: 5459, Predicted Mean: tensor([[0.4068]]), Target Value: 0.0, difference: tensor([[0.4068]])
# Sample Index: 7252, Predicted Mean: tensor([[0.3793]]), Target Value: 0.2018696814775467, difference: tensor([[0.1774]])
# Sample Index: 6014, Predicted Mean: tensor([[0.4231]]), Target Value: 0.7019978761672974, difference: tensor([[-0.2789]])
# Sample Index: 3332, Predicted Mean: tensor([[0.4049]]), Target Value: 0.12292438745498657, difference: tensor([[0.2820]])
# Sample Index: 7327, Predicted Mean: tensor([[0.3935]]), Target Value: 0.19792528450489044, difference: tensor([[0.1956]])
# Sample Index: 5679, Predicted Mean: tensor([[0.4891]]), Target Value: 0.8156945705413818, difference: tensor([[-0.3266]])
# Sample Index: 1022, Predicted Mean: tensor([[0.4147]]), Target Value: 0.028683923184871674, difference: tensor([[0.3860]])
# Sample Index: 2349, Predicted Mean: tensor([[0.4294]]), Target Value: 0.6882362365722656, difference: tensor([[-0.2588]])
# Sample Index: 7145, Predicted Mean: tensor([[0.3803]]), Target Value: 0.42841437458992004, difference: tensor([[-0.0481]])
# Sample Index: 3172, Predicted Mean: tensor([[0.4071]]), Target Value: 0.38538363575935364, difference: tensor([[0.0217]])
# Sample Index: 2576, Predicted Mean: tensor([[0.4113]]), Target Value: 0.42041128873825073, difference: tensor([[-0.0091]])
# Sample Index: 459, Predicted Mean: tensor([[0.3927]]), Target Value: 0.028587887063622475, difference: tensor([[0.3641]])
# Sample Index: 6008, Predicted Mean: tensor([[0.4219]]), Target Value: 0.744756817817688, difference: tensor([[-0.3228]])
# Sample Index: 3799, Predicted Mean: tensor([[0.4159]]), Target Value: 0.9479536414146423, difference: tensor([[-0.5321]])
# Sample Index: 1633, Predicted Mean: tensor([[0.4021]]), Target Value: 0.8440032005310059, difference: tensor([[-0.4419]])
# Sample Index: 7532, Predicted Mean: tensor([[0.4251]]), Target Value: 0.0, difference: tensor([[0.4251]])
# Sample Index: 7976, Predicted Mean: tensor([[0.3881]]), Target Value: 0.7324506640434265, difference: tensor([[-0.3444]])
# Sample Index: 6906, Predicted Mean: tensor([[0.4586]]), Target Value: 0.971199631690979, difference: tensor([[-0.5126]])
# Sample Index: 3952, Predicted Mean: tensor([[0.4156]]), Target Value: 0.949749231338501, difference: tensor([[-0.5341]])
# Sample Index: 6087, Predicted Mean: tensor([[0.4210]]), Target Value: 0.7056527733802795, difference: tensor([[-0.2846]])
# Sample Index: 1088, Predicted Mean: tensor([[0.3849]]), Target Value: 0.0, difference: tensor([[0.3849]])
# Sample Index: 7487, Predicted Mean: tensor([[0.4267]]), Target Value: 0.8129389882087708, difference: tensor([[-0.3862]])
# Sample Index: 6556, Predicted Mean: tensor([[0.3950]]), Target Value: 0.14997237920761108, difference: tensor([[0.2450]])
# Sample Index: 8648, Predicted Mean: tensor([[0.4080]]), Target Value: 0.0, difference: tensor([[0.4080]])
# Sample Index: 3552, Predicted Mean: tensor([[0.3933]]), Target Value: 0.028338313102722168, difference: tensor([[0.3650]])
# Sample Index: 264, Predicted Mean: tensor([[0.4277]]), Target Value: 0.056995537132024765, difference: tensor([[0.3707]])
# Sample Index: 2278, Predicted Mean: tensor([[0.4225]]), Target Value: 0.41966554522514343, difference: tensor([[0.0029]])
# Sample Index: 3570, Predicted Mean: tensor([[0.3936]]), Target Value: 0.11734438687562943, difference: tensor([[0.2763]])
# the number of samples < 0.1: 9
# Epoch 2 batch_idx0 loss: 19.32326889038086
# Epoch 2 batch_idx1 loss: 19.303363800048828
# Epoch 2 batch_idx2 loss: 19.296810150146484
# Epoch 2 batch_idx3 loss: 19.30837059020996
# Epoch 2 batch_idx4 loss: 19.302860260009766
# Epoch 2 batch_idx5 loss: 19.286357879638672
# Epoch 2 batch_idx6 loss: 19.307336807250977
# Epoch 2 batch_idx7 loss: 19.28281021118164
# Epoch 2 batch_idx8 loss: 19.279706954956055
# Epoch 2 batch_idx123 loss: 19.216289520263672
# Epoch 2 batch_idx124 loss: 19.22418975830078
# Epoch 2 batch_idx125 loss: 19.22456169128418
# Epoch 2 batch_idx126 loss: 19.216291427612305
# Epoch 2 batch_idx127 loss: 19.20627212524414
# Epoch 2 batch_idx128 loss: 19.183094024658203
# Epoch 2 batch_idx129 loss: 19.221296310424805
# Epoch 2 batch_idx130 loss: 19.2255859375
# Epoch 2 batch_idx131 loss: 19.23208999633789
# Epoch 2 batch_idx132 loss: 19.227264404296875
# Epoch 2 batch_idx133 loss: 19.225772857666016
# Epoch 2 batch_idx134 loss: 19.20370864868164
# Epoch 2 batch_idx135 loss: 19.204540252685547
# Epoch 2 batch_idx136 loss: 19.219970703125
# Epoch 2 batch_idx137 loss: 19.220733642578125
# Epoch 2 batch_idx138 loss: 19.231922149658203
# Epoch 2 batch_idx139 loss: 19.175174713134766
# Epoch 2, Loss: 2695.9542
# Sample Index: 5610, Predicted Mean: tensor([[0.5523]]), Target Value: 0.6880993843078613, difference: tensor([[-0.1358]])
# Sample Index: 1100, Predicted Mean: tensor([[0.3953]]), Target Value: 0.6207618117332458, difference: tensor([[-0.2255]])
# Sample Index: 640, Predicted Mean: tensor([[0.4763]]), Target Value: 0.5577124357223511, difference: tensor([[-0.0814]])
# Sample Index: 8658, Predicted Mean: tensor([[0.4305]]), Target Value: 0.23718135058879852, difference: tensor([[0.1933]])
# Sample Index: 4455, Predicted Mean: tensor([[0.4473]]), Target Value: 0.9303603172302246, difference: tensor([[-0.4831]])
# Sample Index: 3642, Predicted Mean: tensor([[0.3659]]), Target Value: 0.5184335708618164, difference: tensor([[-0.1526]])
# Sample Index: 3279, Predicted Mean: tensor([[0.4206]]), Target Value: 0.3716420531272888, difference: tensor([[0.0490]])
# Sample Index: 3587, Predicted Mean: tensor([[0.3630]]), Target Value: 0.2783271372318268, difference: tensor([[0.0847]])
# Sample Index: 6292, Predicted Mean: tensor([[0.3938]]), Target Value: 0.0, difference: tensor([[0.3938]])
# Sample Index: 620, Predicted Mean: tensor([[0.4774]]), Target Value: 0.6287501454353333, difference: tensor([[-0.1514]])
# Sample Index: 1088, Predicted Mean: tensor([[0.3970]]), Target Value: 0.0, difference: tensor([[0.3970]])
# Sample Index: 2962, Predicted Mean: tensor([[0.3686]]), Target Value: 0.5267809629440308, difference: tensor([[-0.1581]])
# Sample Index: 2922, Predicted Mean: tensor([[0.7695]]), Target Value: 0.549892783164978, difference: tensor([[0.2197]])
# Sample Index: 4752, Predicted Mean: tensor([[0.3942]]), Target Value: 0.9970893263816833, difference: tensor([[-0.6029]])
# Sample Index: 846, Predicted Mean: tensor([[0.3241]]), Target Value: 0.9952570199966431, difference: tensor([[-0.6711]])
# Sample Index: 1414, Predicted Mean: tensor([[0.3898]]), Target Value: 0.5902541279792786, difference: tensor([[-0.2004]])
# Sample Index: 2818, Predicted Mean: tensor([[0.7722]]), Target Value: 0.9767654538154602, difference: tensor([[-0.2045]])
# Sample Index: 8406, Predicted Mean: tensor([[0.3607]]), Target Value: 0.41268256306648254, difference: tensor([[-0.0520]])
# Sample Index: 6505, Predicted Mean: tensor([[0.3943]]), Target Value: 0.3353959023952484, difference: tensor([[0.0589]])
# Sample Index: 7112, Predicted Mean: tensor([[0.3068]]), Target Value: 0.3826960027217865, difference: tensor([[-0.0759]])
# Sample Index: 2454, Predicted Mean: tensor([[0.4559]]), Target Value: 0.396212637424469, difference: tensor([[0.0597]])
# Sample Index: 7352, Predicted Mean: tensor([[0.5931]]), Target Value: 0.08882773667573929, difference: tensor([[0.5043]])
# Sample Index: 590, Predicted Mean: tensor([[0.4737]]), Target Value: 0.39300140738487244, difference: tensor([[0.0807]])
# Sample Index: 360, Predicted Mean: tensor([[0.4597]]), Target Value: 0.38583290576934814, difference: tensor([[0.0738]])
# Sample Index: 812, Predicted Mean: tensor([[0.3321]]), Target Value: 0.0, difference: tensor([[0.3321]])
# Sample Index: 7781, Predicted Mean: tensor([[0.3462]]), Target Value: 0.4710797071456909, difference: tensor([[-0.1249]])
# Sample Index: 878, Predicted Mean: tensor([[0.3236]]), Target Value: 0.21174634993076324, difference: tensor([[0.1119]])
# Sample Index: 2234, Predicted Mean: tensor([[0.2548]]), Target Value: 0.0, difference: tensor([[0.2548]])
# Sample Index: 481, Predicted Mean: tensor([[0.4020]]), Target Value: 0.24220705032348633, difference: tensor([[0.1598]])
# Sample Index: 5331, Predicted Mean: tensor([[0.5287]]), Target Value: 0.1744922697544098, difference: tensor([[0.3542]])
# Sample Index: 3979, Predicted Mean: tensor([[0.4503]]), Target Value: 0.9508655071258545, difference: tensor([[-0.5006]])
# Sample Index: 200, Predicted Mean: tensor([[0.4719]]), Target Value: 0.746159553527832, difference: tensor([[-0.2743]])
# Sample Index: 6900, Predicted Mean: tensor([[0.6529]]), Target Value: 0.9089705348014832, difference: tensor([[-0.2560]])
# Sample Index: 639, Predicted Mean: tensor([[0.4750]]), Target Value: 0.5563527345657349, difference: tensor([[-0.0814]])
# Sample Index: 226, Predicted Mean: tensor([[0.4687]]), Target Value: 0.5930460095405579, difference: tensor([[-0.1243]])
# Sample Index: 2176, Predicted Mean: tensor([[0.5381]]), Target Value: 0.0, difference: tensor([[0.5381]])
# Sample Index: 5007, Predicted Mean: tensor([[0.3978]]), Target Value: 0.996961236000061, difference: tensor([[-0.5992]])
# Sample Index: 4892, Predicted Mean: tensor([[0.3992]]), Target Value: 0.9964284300804138, difference: tensor([[-0.5972]])
# Sample Index: 6476, Predicted Mean: tensor([[0.3933]]), Target Value: 0.0, difference: tensor([[0.3933]])
# Sample Index: 149, Predicted Mean: tensor([[0.3416]]), Target Value: 0.061915572732686996, difference: tensor([[0.2797]])
# Sample Index: 5828, Predicted Mean: tensor([[0.5562]]), Target Value: 0.6646713614463806, difference: tensor([[-0.1084]])
# Sample Index: 372, Predicted Mean: tensor([[0.4573]]), Target Value: 0.38473808765411377, difference: tensor([[0.0726]])
# Sample Index: 3743, Predicted Mean: tensor([[0.4290]]), Target Value: 0.7940762639045715, difference: tensor([[-0.3651]])
# Sample Index: 1492, Predicted Mean: tensor([[0.3914]]), Target Value: 0.030710019171237946, difference: tensor([[0.3606]])
# Sample Index: 3027, Predicted Mean: tensor([[0.3703]]), Target Value: 0.4947855770587921, difference: tensor([[-0.1245]])
# Sample Index: 4228, Predicted Mean: tensor([[0.3705]]), Target Value: 0.11969747394323349, difference: tensor([[0.2508]])
# Sample Index: 7879, Predicted Mean: tensor([[0.4800]]), Target Value: 0.7553394436836243, difference: tensor([[-0.2753]])
# Sample Index: 268, Predicted Mean: tensor([[0.4695]]), Target Value: 0.5858248472213745, difference: tensor([[-0.1163]])
# Sample Index: 4860, Predicted Mean: tensor([[0.3958]]), Target Value: 0.9963809251785278, difference: tensor([[-0.6005]])
# Sample Index: 3581, Predicted Mean: tensor([[0.3618]]), Target Value: 0.0, difference: tensor([[0.3618]])
# the number of samples < 0.1: 11
# Epoch 3 batch_idx0 loss: 19.22484016418457
# Epoch 3 batch_idx1 loss: 19.20956039428711
# Epoch 3 batch_idx2 loss: 19.23406982421875
# Epoch 3 batch_idx3 loss: 19.203380584716797
# Epoch 3 batch_idx4 loss: 19.207229614257812
# Epoch 3 batch_idx5 loss: 19.230932235717773
# Epoch 3 batch_idx6 loss: 19.22191047668457
# Epoch 3 batch_idx7 loss: 19.214990615844727
# Epoch 3 batch_idx8 loss: 19.222782135009766
# Epoch 3 batch_idx9 loss: 19.205509185791016
# Epoch 3 batch_idx10 loss: 19.23468589782715
# Epoch 3 batch_idx11 loss: 19.212085723876953
# Epoch 3 batch_idx12 loss: 19.217145919799805
# Epoch 3 batch_idx13 loss: 19.196088790893555
# Epoch 3 batch_idx14 loss: 19.223388671875
# Epoch 3 batch_idx15 loss: 19.210086822509766
# Epoch 3 batch_idx16 loss: 19.200031280517578
# Epoch 3 batch_idx17 loss: 19.20907974243164
# Epoch 3 batch_idx18 loss: 19.20233726501465
# CI acc: 0.00, CI upper acc: 0.41, CI lower acc: 0.59
# Loss: 19.1934
# Epoch 3 batch_idx19 loss: 19.193401336669922
# Epoch 3 batch_idx20 loss: 19.185007095336914
# Epoch 3 batch_idx21 loss: 19.213010787963867
# Epoch 3 batch_idx22 loss: 19.231060028076172
# Epoch 3 batch_idx23 loss: 19.195453643798828
# Epoch 3 batch_idx24 loss: 19.198793411254883
# Epoch 3 batch_idx25 loss: 19.17852020263672
# Epoch 3 batch_idx26 loss: 19.168901443481445
# Epoch 3 batch_idx27 loss: 19.159894943237305
# Epoch 3 batch_idx28 loss: 19.196125030517578
# Epoch 3 batch_idx29 loss: 19.21133041381836
# Epoch 3 batch_idx30 loss: 19.21941566467285
# Epoch 3 batch_idx31 loss: 19.196269989013672
# Epoch 3 batch_idx32 loss: 19.196645736694336
# Epoch 3 batch_idx33 loss: 19.1826229095459
# Epoch 3 batch_idx34 loss: 19.1635799407959
# Epoch 3 batch_idx35 loss: 19.19972038269043
# Epoch 3 batch_idx36 loss: 19.205963134765625
# Epoch 3 batch_idx37 loss: 19.19043731689453
# Epoch 3 batch_idx38 loss: 19.2007999420166
# Epoch 3 batch_idx39 loss: 19.181909561157227
# Epoch 3 batch_idx40 loss: 19.219377517700195
# Epoch 3 batch_idx99 loss: 19.14171600341797
# Epoch 3 batch_idx100 loss: 19.14716339111328
# Epoch 3 batch_idx101 loss: 19.15714454650879
# Epoch 3 batch_idx102 loss: 19.13101577758789
# Epoch 3 batch_idx103 loss: 19.14668083190918
# Epoch 3 batch_idx104 loss: 19.132047653198242
# Epoch 3 batch_idx105 loss: 19.148658752441406
# Epoch 3 batch_idx106 loss: 19.156513214111328
# Epoch 3 batch_idx107 loss: 19.144092559814453
# Epoch 3 batch_idx108 loss: 19.1265811920166
# Epoch 3 batch_idx109 loss: 19.12750816345215
# Epoch 3 batch_idx110 loss: 19.11833953857422
# Epoch 3 batch_idx111 loss: 19.150882720947266
# Epoch 3 batch_idx112 loss: 19.151966094970703
# Epoch 3 batch_idx113 loss: 19.125219345092773
# Epoch 3 batch_idx114 loss: 19.13021469116211
# Epoch 3 batch_idx115 loss: 19.148086547851562
# Epoch 3 batch_idx116 loss: 19.139827728271484
# Epoch 3 batch_idx117 loss: 19.127843856811523
# Epoch 3 batch_idx118 loss: 19.154809951782227
# CI acc: 0.03, CI upper acc: 0.44, CI lower acc: 0.59
# Loss: 19.1268
# Epoch 3 batch_idx119 loss: 19.12679672241211
# Epoch 3 batch_idx120 loss: 19.114490509033203
# Epoch 3 batch_idx121 loss: 19.137893676757812
# Epoch 3 batch_idx122 loss: 19.15372657775879
# Epoch 3 batch_idx123 loss: 19.12264633178711
# Epoch 3 batch_idx124 loss: 19.171104431152344
# Epoch 3 batch_idx125 loss: 19.120868682861328
# Epoch 3 batch_idx126 loss: 19.13520622253418
# Epoch 3 batch_idx127 loss: 19.133420944213867
# Epoch 3 batch_idx128 loss: 19.13974380493164
# Epoch 3 batch_idx129 loss: 19.127527236938477
# Epoch 3 batch_idx130 loss: 19.141517639160156
# Epoch 3 batch_idx131 loss: 19.14463233947754
# Epoch 3 batch_idx132 loss: 19.12657928466797
# Epoch 3 batch_idx133 loss: 19.13861656188965
# Epoch 3 batch_idx134 loss: 19.118650436401367
# Epoch 3 batch_idx135 loss: 19.146116256713867
# Epoch 3 batch_idx136 loss: 19.14222526550293
# Epoch 3 batch_idx137 loss: 19.154447555541992
# Epoch 3 batch_idx138 loss: 19.12217903137207
# Epoch 3 batch_idx139 loss: 19.130895614624023
# Epoch 3, Loss: 2683.8776
# Sample Index: 2154, Predicted Mean: tensor([[0.4926]]), Target Value: 0.612491250038147, difference: tensor([[-0.1199]])
# Sample Index: 2786, Predicted Mean: tensor([[0.7109]]), Target Value: 0.24966327846050262, difference: tensor([[0.4613]])
# Sample Index: 5259, Predicted Mean: tensor([[0.7087]]), Target Value: 0.9546017646789551, difference: tensor([[-0.2459]])
# Sample Index: 6947, Predicted Mean: tensor([[0.6504]]), Target Value: 0.010679570026695728, difference: tensor([[0.6397]])
# Sample Index: 7810, Predicted Mean: tensor([[0.4199]]), Target Value: 0.5213783383369446, difference: tensor([[-0.1015]])
# Sample Index: 6699, Predicted Mean: tensor([[0.4528]]), Target Value: 0.0, difference: tensor([[0.4528]])
# Sample Index: 8620, Predicted Mean: tensor([[0.1417]]), Target Value: 0.0, difference: tensor([[0.1417]])
# Sample Index: 1055, Predicted Mean: tensor([[0.4447]]), Target Value: 0.6705406308174133, difference: tensor([[-0.2259]])
# Sample Index: 32, Predicted Mean: tensor([[0.3675]]), Target Value: 0.019761640578508377, difference: tensor([[0.3478]])
# Sample Index: 6764, Predicted Mean: tensor([[0.4511]]), Target Value: 0.0, difference: tensor([[0.4511]])
# Sample Index: 4841, Predicted Mean: tensor([[0.5079]]), Target Value: 0.9961733818054199, difference: tensor([[-0.4883]])
# Sample Index: 1409, Predicted Mean: tensor([[0.5209]]), Target Value: 0.049367520958185196, difference: tensor([[0.4715]])
# Sample Index: 6942, Predicted Mean: tensor([[0.6538]]), Target Value: 0.9966899156570435, difference: tensor([[-0.3429]])
# Sample Index: 2488, Predicted Mean: tensor([[0.4154]]), Target Value: 0.18337318301200867, difference: tensor([[0.2321]])
# Sample Index: 113, Predicted Mean: tensor([[0.2274]]), Target Value: 0.022128095850348473, difference: tensor([[0.2052]])
# Sample Index: 8228, Predicted Mean: tensor([[0.4914]]), Target Value: 0.7935940027236938, difference: tensor([[-0.3022]])
# Sample Index: 7857, Predicted Mean: tensor([[0.5994]]), Target Value: 0.010983363725244999, difference: tensor([[0.5884]])
# Sample Index: 5339, Predicted Mean: tensor([[0.7066]]), Target Value: 0.7031923532485962, difference: tensor([[0.0034]])
# Sample Index: 4472, Predicted Mean: tensor([[0.6775]]), Target Value: 0.940837562084198, difference: tensor([[-0.2633]])
# Sample Index: 4808, Predicted Mean: tensor([[0.5047]]), Target Value: 0.019866758957505226, difference: tensor([[0.4849]])
# Sample Index: 2367, Predicted Mean: tensor([[0.2416]]), Target Value: 0.05442071333527565, difference: tensor([[0.1871]])
# Sample Index: 8006, Predicted Mean: tensor([[0.3770]]), Target Value: 0.6237356066703796, difference: tensor([[-0.2468]])
# Sample Index: 2278, Predicted Mean: tensor([[0.3498]]), Target Value: 0.41966554522514343, difference: tensor([[-0.0699]])
# Sample Index: 5849, Predicted Mean: tensor([[0.5301]]), Target Value: 0.5733436942100525, difference: tensor([[-0.0432]])
# Sample Index: 7099, Predicted Mean: tensor([[0.4062]]), Target Value: 0.06163165718317032, difference: tensor([[0.3446]])
# Sample Index: 4324, Predicted Mean: tensor([[0.4006]]), Target Value: 0.011320894584059715, difference: tensor([[0.3893]])
# Sample Index: 4503, Predicted Mean: tensor([[0.6770]]), Target Value: 0.9397799968719482, difference: tensor([[-0.2628]])
# Sample Index: 8449, Predicted Mean: tensor([[0.3214]]), Target Value: 0.11890601366758347, difference: tensor([[0.2025]])
# Sample Index: 7736, Predicted Mean: tensor([[0.4186]]), Target Value: 0.47677645087242126, difference: tensor([[-0.0582]])
# Sample Index: 4777, Predicted Mean: tensor([[0.5081]]), Target Value: 0.0, difference: tensor([[0.5081]])
# Sample Index: 4208, Predicted Mean: tensor([[0.3969]]), Target Value: 0.20925688743591309, difference: tensor([[0.1876]])
# Sample Index: 555, Predicted Mean: tensor([[0.1150]]), Target Value: 0.0, difference: tensor([[0.1150]])
# Sample Index: 1339, Predicted Mean: tensor([[0.3314]]), Target Value: 0.2070206254720688, difference: tensor([[0.1244]])
# Sample Index: 4930, Predicted Mean: tensor([[0.5061]]), Target Value: 0.9967842102050781, difference: tensor([[-0.4906]])
# Sample Index: 7156, Predicted Mean: tensor([[0.4035]]), Target Value: 0.46665439009666443, difference: tensor([[-0.0631]])
# Sample Index: 8480, Predicted Mean: tensor([[0.3652]]), Target Value: 0.7267147898674011, difference: tensor([[-0.3615]])
# Sample Index: 4369, Predicted Mean: tensor([[0.2384]]), Target Value: 0.0, difference: tensor([[0.2384]])
# Sample Index: 4388, Predicted Mean: tensor([[0.6764]]), Target Value: 0.9325289130210876, difference: tensor([[-0.2561]])
# Sample Index: 4919, Predicted Mean: tensor([[0.5130]]), Target Value: 0.0, difference: tensor([[0.5130]])
# Sample Index: 627, Predicted Mean: tensor([[0.6455]]), Target Value: 0.06198551878333092, difference: tensor([[0.5836]])
# Sample Index: 5573, Predicted Mean: tensor([[0.5283]]), Target Value: 0.8292065262794495, difference: tensor([[-0.3010]])
# Sample Index: 6546, Predicted Mean: tensor([[0.4522]]), Target Value: 0.0, difference: tensor([[0.4522]])
# Sample Index: 8827, Predicted Mean: tensor([[0.5951]]), Target Value: 0.9230135083198547, difference: tensor([[-0.3279]])
# Sample Index: 7051, Predicted Mean: tensor([[0.4046]]), Target Value: 0.4609149992465973, difference: tensor([[-0.0563]])
# Sample Index: 6876, Predicted Mean: tensor([[0.4541]]), Target Value: 0.01296159252524376, difference: tensor([[0.4411]])
# Sample Index: 3412, Predicted Mean: tensor([[0.4308]]), Target Value: 0.33823269605636597, difference: tensor([[0.0926]])
# Sample Index: 3872, Predicted Mean: tensor([[0.6774]]), Target Value: 0.8690319061279297, difference: tensor([[-0.1917]])
# Sample Index: 75, Predicted Mean: tensor([[0.2319]]), Target Value: 0.06884396821260452, difference: tensor([[0.1630]])
# Sample Index: 1944, Predicted Mean: tensor([[0.4519]]), Target Value: 0.6075395345687866, difference: tensor([[-0.1556]])
# Sample Index: 8256, Predicted Mean: tensor([[0.4906]]), Target Value: 0.7779175043106079, difference: tensor([[-0.2873]])
# the number of samples < 0.1: 7
# Epoch 4 batch_idx0 loss: 19.134328842163086
# Epoch 4 batch_idx1 loss: 19.115949630737305
# Epoch 4 batch_idx2 loss: 19.113643646240234
# Epoch 4 batch_idx3 loss: 19.128971099853516
# Epoch 4 batch_idx4 loss: 19.110248565673828
# Epoch 4 batch_idx5 loss: 19.11717987060547
# Epoch 4 batch_idx6 loss: 19.12290382385254
# Epoch 4 batch_idx7 loss: 19.118976593017578
# Epoch 4 batch_idx8 loss: 19.10761833190918
# Epoch 4 batch_idx9 loss: 19.11989402770996
# Epoch 4 batch_idx10 loss: 19.114534378051758
# Epoch 4 batch_idx11 loss: 19.10803985595703
# Epoch 4 batch_idx12 loss: 19.106250762939453
# Epoch 4 batch_idx13 loss: 19.119983673095703
# Epoch 4 batch_idx14 loss: 19.09270668029785
# Epoch 4 batch_idx15 loss: 19.114274978637695
# Epoch 4 batch_idx16 loss: 19.125761032104492
# Epoch 4 batch_idx17 loss: 19.095314025878906
# Epoch 4 batch_idx131 loss: 19.045900344848633
# Epoch 4 batch_idx132 loss: 19.05910873413086
# Epoch 4 batch_idx133 loss: 19.023805618286133
# Epoch 4 batch_idx134 loss: 19.051259994506836
# Epoch 4 batch_idx135 loss: 19.02999496459961
# Epoch 4 batch_idx136 loss: 19.0368595123291
# Epoch 4 batch_idx137 loss: 19.040660858154297
# Epoch 4 batch_idx138 loss: 19.03360939025879
# Epoch 4 batch_idx139 loss: 19.045658111572266
# Epoch 4, Loss: 2671.5120
# Sample Index: 8897, Predicted Mean: tensor([[0.5939]]), Target Value: 0.9106668829917908, difference: tensor([[-0.3168]])
# Sample Index: 187, Predicted Mean: tensor([[0.2477]]), Target Value: 0.293877512216568, difference: tensor([[-0.0462]])
# Sample Index: 5965, Predicted Mean: tensor([[0.6591]]), Target Value: 0.6046230792999268, difference: tensor([[0.0545]])
# Sample Index: 1329, Predicted Mean: tensor([[0.2685]]), Target Value: 0.2066967934370041, difference: tensor([[0.0618]])
# Sample Index: 3871, Predicted Mean: tensor([[0.6803]]), Target Value: 0.9424993991851807, difference: tensor([[-0.2622]])
# Sample Index: 2647, Predicted Mean: tensor([[0.6146]]), Target Value: 0.04975757375359535, difference: tensor([[0.5648]])
# Sample Index: 7222, Predicted Mean: tensor([[0.3809]]), Target Value: 0.0261861402541399, difference: tensor([[0.3547]])
# Sample Index: 5843, Predicted Mean: tensor([[0.6626]]), Target Value: 0.14833718538284302, difference: tensor([[0.5143]])
# Sample Index: 8208, Predicted Mean: tensor([[0.4128]]), Target Value: 0.6163944602012634, difference: tensor([[-0.2036]])
# Sample Index: 4943, Predicted Mean: tensor([[0.6866]]), Target Value: 0.9965246915817261, difference: tensor([[-0.3099]])
# Sample Index: 4612, Predicted Mean: tensor([[0.5146]]), Target Value: 0.2641308307647705, difference: tensor([[0.2505]])
# Sample Index: 1388, Predicted Mean: tensor([[0.5689]]), Target Value: 0.7306436896324158, difference: tensor([[-0.1617]])
# Sample Index: 5288, Predicted Mean: tensor([[0.6862]]), Target Value: 0.4273768663406372, difference: tensor([[0.2588]])
# Sample Index: 8348, Predicted Mean: tensor([[0.4240]]), Target Value: 0.025805873796343803, difference: tensor([[0.3982]])
# Sample Index: 6684, Predicted Mean: tensor([[0.4493]]), Target Value: 0.0, difference: tensor([[0.4493]])
# Sample Index: 5379, Predicted Mean: tensor([[0.6895]]), Target Value: 0.012541496194899082, difference: tensor([[0.6770]])
# Sample Index: 6186, Predicted Mean: tensor([[0.5446]]), Target Value: 0.8870584964752197, difference: tensor([[-0.3425]])
# Sample Index: 5746, Predicted Mean: tensor([[0.6664]]), Target Value: 0.8131951689720154, difference: tensor([[-0.1468]])
# Sample Index: 5587, Predicted Mean: tensor([[0.6624]]), Target Value: 0.8298203349113464, difference: tensor([[-0.1674]])
# Sample Index: 1241, Predicted Mean: tensor([[0.4668]]), Target Value: 0.626008152961731, difference: tensor([[-0.1592]])
# Sample Index: 4002, Predicted Mean: tensor([[0.5594]]), Target Value: 0.7645554542541504, difference: tensor([[-0.2052]])
# Sample Index: 2843, Predicted Mean: tensor([[0.6698]]), Target Value: 0.811892032623291, difference: tensor([[-0.1421]])
# Sample Index: 1891, Predicted Mean: tensor([[0.4681]]), Target Value: 0.27687910199165344, difference: tensor([[0.1912]])
# Sample Index: 3027, Predicted Mean: tensor([[0.2843]]), Target Value: 0.4947855770587921, difference: tensor([[-0.2104]])
# Sample Index: 8507, Predicted Mean: tensor([[0.3505]]), Target Value: 0.6847704648971558, difference: tensor([[-0.3342]])
# Sample Index: 5090, Predicted Mean: tensor([[0.6869]]), Target Value: 0.05185404792428017, difference: tensor([[0.6351]])
# Sample Index: 3249, Predicted Mean: tensor([[0.2341]]), Target Value: 0.34767308831214905, difference: tensor([[-0.1136]])
# Sample Index: 3299, Predicted Mean: tensor([[0.2355]]), Target Value: 0.24977464973926544, difference: tensor([[-0.0143]])
# Sample Index: 7054, Predicted Mean: tensor([[0.3777]]), Target Value: 0.500490128993988, difference: tensor([[-0.1228]])
# Sample Index: 8495, Predicted Mean: tensor([[0.3493]]), Target Value: 0.32181304693222046, difference: tensor([[0.0275]])
# Sample Index: 5073, Predicted Mean: tensor([[0.6874]]), Target Value: 0.9814502000808716, difference: tensor([[-0.2941]])
# Sample Index: 449, Predicted Mean: tensor([[0.3343]]), Target Value: 0.2455846220254898, difference: tensor([[0.0887]])
# Sample Index: 7514, Predicted Mean: tensor([[0.3097]]), Target Value: 0.0, difference: tensor([[0.3097]])
# Sample Index: 6276, Predicted Mean: tensor([[0.4840]]), Target Value: 0.3565483093261719, difference: tensor([[0.1275]])
# Sample Index: 2299, Predicted Mean: tensor([[0.2902]]), Target Value: 0.0, difference: tensor([[0.2902]])
# Sample Index: 781, Predicted Mean: tensor([[0.1983]]), Target Value: 0.28777849674224854, difference: tensor([[-0.0895]])
# ...
# Epoch 30 batch_idx45 loss: 17.437108993530273
# Epoch 30 batch_idx46 loss: 17.412626266479492
# Epoch 30 batch_idx47 loss: 17.438739776611328
# Epoch 30 batch_idx48 loss: 17.436826705932617
# Epoch 30 batch_idx49 loss: 17.419719696044922
# Epoch 30 batch_idx50 loss: 17.4466495513916
# Epoch 30 batch_idx51 loss: 17.418041229248047
# Epoch 30 batch_idx52 loss: 17.42160415649414
# Epoch 30 batch_idx53 loss: 17.410112380981445
# Epoch 30 batch_idx54 loss: 17.414348602294922
# Epoch 30 batch_idx55 loss: 17.4178466796875
# Epoch 30 batch_idx56 loss: 17.42104721069336
# Epoch 30 batch_idx57 loss: 17.413373947143555
# Epoch 30 batch_idx58 loss: 17.419801712036133
# Epoch 30 batch_idx59 loss: 17.40536880493164
# Epoch 30 batch_idx60 loss: 17.421995162963867
# Epoch 30 batch_idx61 loss: 17.41265869140625
# Epoch 30 batch_idx62 loss: 17.43325424194336
# Epoch 30 batch_idx63 loss: 17.409889221191406
# Epoch 30 batch_idx64 loss: 17.409915924072266
# Epoch 30 batch_idx65 loss: 17.415645599365234
# Epoch 30 batch_idx66 loss: 17.418216705322266
# Epoch 30 batch_idx67 loss: 17.417221069335938
# Epoch 30 batch_idx68 loss: 17.430118560791016
# Epoch 30 batch_idx69 loss: 17.42118263244629
# Epoch 30 batch_idx128 loss: 17.387109756469727
# Epoch 30 batch_idx129 loss: 17.40508270263672
# Epoch 30 batch_idx130 loss: 17.414936065673828
# Epoch 30 batch_idx131 loss: 17.4090633392334
# Epoch 30 batch_idx132 loss: 17.381444931030273
# Epoch 30 batch_idx133 loss: 17.406566619873047
# Epoch 30 batch_idx134 loss: 17.399219512939453
# Epoch 30 batch_idx135 loss: 17.415618896484375
# Epoch 30 batch_idx136 loss: 17.402917861938477
# Epoch 30 batch_idx137 loss: 17.40692710876465
# Epoch 30 batch_idx138 loss: 17.410417556762695
# CI acc: 0.00, CI upper acc: 0.31, CI lower acc: 0.69
# Loss: 17.3709
# Epoch 30 batch_idx139 loss: 17.37093734741211
# Epoch 30, Loss: 2438.4441
# Sample Index: 1324, Predicted Mean: tensor([[0.2098]]), Target Value: 0.012659003026783466, difference: tensor([[0.1972]])
# Sample Index: 7968, Predicted Mean: tensor([[0.2779]]), Target Value: 0.7571853399276733, difference: tensor([[-0.4793]])
# Sample Index: 203, Predicted Mean: tensor([[0.5691]]), Target Value: 0.782740592956543, difference: tensor([[-0.2136]])
# Sample Index: 2296, Predicted Mean: tensor([[0.3994]]), Target Value: 0.0220009908080101, difference: tensor([[0.3774]])
# Sample Index: 271, Predicted Mean: tensor([[0.5622]]), Target Value: 0.5499772429466248, difference: tensor([[0.0122]])
# Sample Index: 5480, Predicted Mean: tensor([[0.4012]]), Target Value: 0.8996191024780273, difference: tensor([[-0.4984]])
# Sample Index: 5044, Predicted Mean: tensor([[0.6886]]), Target Value: 0.016854971647262573, difference: tensor([[0.6718]])
# Sample Index: 3208, Predicted Mean: tensor([[0.2127]]), Target Value: 0.0, difference: tensor([[0.2127]])
# Sample Index: 6726, Predicted Mean: tensor([[0.4444]]), Target Value: 0.6936467289924622, difference: tensor([[-0.2493]])
# Sample Index: 4081, Predicted Mean: tensor([[0.5117]]), Target Value: 0.7350859642028809, difference: tensor([[-0.2234]])
# Sample Index: 6295, Predicted Mean: tensor([[0.4474]]), Target Value: 0.0, difference: tensor([[0.4474]])
# Sample Index: 2070, Predicted Mean: tensor([[0.5701]]), Target Value: 0.6852583289146423, difference: tensor([[-0.1151]])
# Sample Index: 2231, Predicted Mean: tensor([[0.0981]]), Target Value: 0.0, difference: tensor([[0.0981]])
# Sample Index: 8059, Predicted Mean: tensor([[0.2546]]), Target Value: 0.0, difference: tensor([[0.2546]])
# Sample Index: 3871, Predicted Mean: tensor([[0.6070]]), Target Value: 0.9424993991851807, difference: tensor([[-0.3355]])
# Sample Index: 1595, Predicted Mean: tensor([[0.5681]]), Target Value: 0.7826723456382751, difference: tensor([[-0.2146]])
# Sample Index: 5279, Predicted Mean: tensor([[0.6850]]), Target Value: 0.8685336709022522, difference: tensor([[-0.1835]])
# Sample Index: 580, Predicted Mean: tensor([[0.0915]]), Target Value: 0.1356993317604065, difference: tensor([[-0.0441]])
# Sample Index: 5562, Predicted Mean: tensor([[0.5989]]), Target Value: 0.8241223096847534, difference: tensor([[-0.2252]])
# Sample Index: 2789, Predicted Mean: tensor([[0.6529]]), Target Value: 0.7244632244110107, difference: tensor([[-0.0716]])
# Sample Index: 3721, Predicted Mean: tensor([[0.4915]]), Target Value: 0.0, difference: tensor([[0.4915]])
# Sample Index: 4669, Predicted Mean: tensor([[0.4167]]), Target Value: 0.03266783803701401, difference: tensor([[0.3840]])
# Sample Index: 1384, Predicted Mean: tensor([[0.4466]]), Target Value: 0.6647034883499146, difference: tensor([[-0.2181]])
# Sample Index: 8639, Predicted Mean: tensor([[0.0516]]), Target Value: 0.0, difference: tensor([[0.0516]])
# Sample Index: 4497, Predicted Mean: tensor([[0.6057]]), Target Value: 0.9319126605987549, difference: tensor([[-0.3262]])
# Sample Index: 5213, Predicted Mean: tensor([[0.6843]]), Target Value: 0.9572355151176453, difference: tensor([[-0.2729]])
# Sample Index: 5989, Predicted Mean: tensor([[0.5995]]), Target Value: 0.6745845079421997, difference: tensor([[-0.0751]])
# Sample Index: 2615, Predicted Mean: tensor([[0.5478]]), Target Value: 0.8671099543571472, difference: tensor([[-0.3193]])
# Sample Index: 1961, Predicted Mean: tensor([[0.5672]]), Target Value: 0.5966917872428894, difference: tensor([[-0.0295]])
# Sample Index: 8148, Predicted Mean: tensor([[0.4350]]), Target Value: 0.05759717524051666, difference: tensor([[0.3774]])
# Sample Index: 2664, Predicted Mean: tensor([[0.5437]]), Target Value: 0.24773705005645752, difference: tensor([[0.2960]])
# Sample Index: 518, Predicted Mean: tensor([[0.2962]]), Target Value: 0.24733909964561462, difference: tensor([[0.0488]])
# Sample Index: 347, Predicted Mean: tensor([[0.3061]]), Target Value: 0.008943234570324421, difference: tensor([[0.2971]])
# Sample Index: 2215, Predicted Mean: tensor([[0.0947]]), Target Value: 0.0717860758304596, difference: tensor([[0.0229]])
# Sample Index: 843, Predicted Mean: tensor([[0.4833]]), Target Value: 0.8433873653411865, difference: tensor([[-0.3601]])
# Sample Index: 7471, Predicted Mean: tensor([[0.5191]]), Target Value: 0.29490941762924194, difference: tensor([[0.2241]])
# Sample Index: 7426, Predicted Mean: tensor([[0.5195]]), Target Value: 0.504836916923523, difference: tensor([[0.0146]])
# Sample Index: 5366, Predicted Mean: tensor([[0.6812]]), Target Value: 0.8703629374504089, difference: tensor([[-0.1892]])
# Sample Index: 45, Predicted Mean: tensor([[0.5948]]), Target Value: 0.07965763658285141, difference: tensor([[0.5151]])
# Sample Index: 3236, Predicted Mean: tensor([[0.2387]]), Target Value: 0.3378085196018219, difference: tensor([[-0.0992]])
# Sample Index: 5228, Predicted Mean: tensor([[0.6790]]), Target Value: 0.012057974003255367, difference: tensor([[0.6670]])
# Sample Index: 208, Predicted Mean: tensor([[0.5682]]), Target Value: 0.5390348434448242, difference: tensor([[0.0292]])
# Sample Index: 932, Predicted Mean: tensor([[0.5005]]), Target Value: 0.6134284734725952, difference: tensor([[-0.1130]])
# Sample Index: 6859, Predicted Mean: tensor([[0.4409]]), Target Value: 0.0, difference: tensor([[0.4409]])
# Sample Index: 7049, Predicted Mean: tensor([[0.2208]]), Target Value: 0.4200003147125244, difference: tensor([[-0.1992]])
# Sample Index: 7657, Predicted Mean: tensor([[0.1817]]), Target Value: 0.16178341209888458, difference: tensor([[0.0199]])
# Sample Index: 7793, Predicted Mean: tensor([[0.4096]]), Target Value: 0.045862119644880295, difference: tensor([[0.3637]])
# Sample Index: 4976, Predicted Mean: tensor([[0.7641]]), Target Value: 0.9963846206665039, difference: tensor([[-0.2323]])
# Sample Index: 3163, Predicted Mean: tensor([[0.2083]]), Target Value: 0.31658703088760376, difference: tensor([[-0.1083]])
# Sample Index: 7062, Predicted Mean: tensor([[0.2200]]), Target Value: 0.4947565495967865, difference: tensor([[-0.2748]])
# the number of samples < 0.1: 13
# *************** Testing *****************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 144>()
#     141             print(f'total distance number: {len(less_1)} / {len(diff_list)}, ratio: {100*len(less_1)/len(diff_list)}')
#     144 if __name__ == "__main__":
# --> 145     main()
#
# Input In [2], in main()
#     129 model.eval()
#     130 with torch.no_grad():
# --> 131     pred_mean = model.predict(sample_x, sample_edge_attr, sample_edge_index,
#     132                               sample_batch.batch).item()
#     133     pred_list.append(pred_mean)
#     134 # print(
#     135 #     f'Sample Index: {idx}, Predicted Mean: {pred_mean}, Target Value: {target_value}, difference: {pred_mean - target_value}')
#
# Input In [1], in ImprovementPredictionModelGNN.predict(self, x, edge_attr, edge_index, batch_index)
#     517 self.eval()  # 设置为评估模式
#     518 with torch.no_grad():
# --> 519     prediction = self.forward(x, edge_attr, edge_index, batch_index)
#     520 return prediction
#
# Input In [1], in ImprovementPredictionModelGNN.forward(self, x, edge_attr, edge_index, batch_index)
#     494 def forward(self, x, edge_attr, edge_index, batch_index):
#     495     # 通过图编码器获取图的嵌入表示
# --> 496     graph_embedding = self.graph_encoder(x, edge_attr, edge_index, batch_index)
#     498     # 第一个贝叶斯线性层
#     499     x_ = self.blinear1(graph_embedding)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Input In [1], in GraphEncoder.forward(self, x, edge_attr, edge_index, batch_index)
#     450         x = x + residual  # 进行残差连接
#     452     if i % self.top_k_every_n == 0 or i == len(self.conv_layers) - 1:
# --> 453         x, edge_index, edge_attr, batch_index, _, _ = self.pooling_layers[i](
#     454             x, edge_index, edge_attr, batch_index
#     455         )
#     456         global_representation.append(torch.cat([
#     457             gmp(x, batch_index),
#     458             gap(x, batch_index)
#     459         ], dim=1))
#     461 # 将全局表示相加作为最终输出
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/anaconda3/envs/test/lib/python3.8/site-packages/torch_geometric/nn/pool/topk_pool.py:115, in TopKPooling.forward(self, x, edge_index, edge_attr, batch, attn)
#     112     batch = edge_index.new_zeros(x.size(0))
#     114 attn = x if attn is None else attn
# --> 115 select_out = self.select(attn, batch)
#     117 perm = select_out.node_index
#     118 score = select_out.weight
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/anaconda3/envs/test/lib/python3.8/site-packages/torch_geometric/nn/pool/select/topk.py:140, in SelectTopK.forward(self, x, batch)
#     133     score = softmax(score, batch)
#     135 node_index = topk(score, self.ratio, batch, self.min_score)
#     137 return SelectOutput(
#     138     node_index=node_index,
#     139     num_nodes=x.size(0),
# --> 140     cluster_index=torch.arange(node_index.size(0), device=x.device),
#     141     num_clusters=node_index.size(0),
#     142     weight=score[node_index],
#     143 )
#
# KeyboardInterrupt:
